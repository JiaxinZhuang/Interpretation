# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Import module

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

import torch
import os
import sys
from torchsummary import summary
from torchvision import transforms                                                                                                                                        
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import accuracy_score
mpl.rcParams['figure.dpi'] = 600
from PIL import Image
import pickle
import numpy as np

import sys
sys.path.append("../../../src/")
sys.path.append("../..")
import model
from datasets import imagenet
import config
from aux.utils import obtain_features_map, load_imgs, zscore, extract_valid, \
     get_gt_pred_specific_class, get_differ
from aux.visualization import visualize_features_map, plot_differ
from utils.function import recreate_image

# %% [markdown]
# ## Hyperparameter

# %%
resume = "050-0"
# model_dir = "/home/lincolnzjx/Desktop/Interpretation/saved/models"
# generated_dir = "/home/lincolnzjx/Desktop/saved/generated/"
model_dir = "/data15/jiaxin/myCode/Interpretation/saved/models"
generated_dir = "/data15/jiaxin/myCode/saved/generated/"
root = "/data15/Public/Datasets/"
backbone = "vgg16"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Load modal from dict

# %%
# model
net = model.Network(backbone=backbone, num_classes=1000)
net.to(device)

# resume from model
resume_exp = resume.split("-")[0]
resume_epoch = resume.split("-")[1]
print("Resume from model from exp: {} at epoch {}".format(resume_exp, resume_epoch))
resume_path = os.path.join(model_dir, str(resume_exp), str(resume_epoch))
ckpt = torch.load(resume_path, map_location=device)
net.load_state_dict(ckpt) 

# Class & data
batch_size = 256
num_workers = 6
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
reverse_mean = [-0.485, -0.456, -0.406]
reverse_std = [1/0.229, 1/0.224, 1/0.225]
# Out:
# > Use original fc
# Resume from model from exp: 037 at epoch 0

# %% [markdown]
# ## Load Swap, RGB->GBR

# %%
gbr_class_y_true_y_pred_acc = {}
for class_index in range(1000):
    # Load data
    train_transform = transforms.Compose([                                                                                                                                
        transforms.Resize((224, 224), interpolation=Image.BILINEAR),                                                                                              
        transforms.ToTensor(),                                                                                                                                            
        transforms.Normalize(mean, std)                                                                                                                                   
           ])         
    trainset = imagenet.ImageNet(root=root, 
                                 is_train=True, transform=train_transform)
    len_specific_category = len(trainset.targets_imgs_dict[class_index])
    print(len_specific_category)
    trainset.set_data([class_index], len_specific_category)
    trainloader = torch.utils.data.DataLoader(trainset,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              num_workers=num_workers,
                                              pin_memory=True)
    y_true, y_pred, acc = get_gt_pred_specific_class(net, 
                                                     trainloader,
                                                     order=[1,2,0],
                                                     device=device)
    print("class_index:{}, Acc1 {}".format(class_index, acc))
    gbr_class_y_true_y_pred_acc[class_index] = [y_true, y_pred, acc]
# Out:
# 1300
# Len of new dataset is :1300
# class_index:0, Acc1 0.2523076923076923
# 1300
# Len of new dataset is :1300
# class_index:1, Acc1 0.16153846153846155
# 1300
# Len of new dataset is :1300
# class_index:2, Acc1 0.31461538461538463
# 1300
# Len of new dataset is :1300
# class_index:3, Acc1 0.4707692307692308
# 1300
# Len of new dataset is :1300
# class_index:4, Acc1 0.5838461538461538
# 1300
# Len of new dataset is :1300
# class_index:5, Acc1 0.4930769230769231
# 1300
# Len of new dataset is :1300
# class_index:6, Acc1 0.4869230769230769
# 1300
# Len of new dataset is :1300
# class_index:7, Acc1 0.23153846153846153
# 1300
# Len of new dataset is :1300
# class_index:8, Acc1 0.16923076923076924
# 1300
# Len of new dataset is :1300
# class_index:9, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:10, Acc1 0.06230769230769231
# 1300
# Len of new dataset is :1300
# class_index:11, Acc1 0.010769230769230769
# 1300
# Len of new dataset is :1300
# class_index:12, Acc1 0.14307692307692307
# 1300
# Len of new dataset is :1300
# class_index:13, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:14, Acc1 0.11384615384615385
# 1300
# Len of new dataset is :1300
# class_index:15, Acc1 0.010769230769230769
# 1300
# Len of new dataset is :1300
# class_index:16, Acc1 0.2876923076923077
# 1300
# Len of new dataset is :1300
# class_index:17, Acc1 0.2815384615384615
# 1300
# Len of new dataset is :1300
# class_index:18, Acc1 0.4907692307692308
# 1300
# Len of new dataset is :1300
# class_index:19, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:20, Acc1 0.6076923076923076
# 1300
# Len of new dataset is :1300
# class_index:21, Acc1 0.35846153846153844
# 1300
# Len of new dataset is :1300
# class_index:22, Acc1 0.26615384615384613
# 1300
# Len of new dataset is :1300
# class_index:23, Acc1 0.40307692307692305
# 1300
# Len of new dataset is :1300
# class_index:24, Acc1 0.88
# 1300
# Len of new dataset is :1300
# class_index:25, Acc1 0.002307692307692308
# 1300
# Len of new dataset is :1300
# class_index:26, Acc1 0.2907692307692308
# 1300
# Len of new dataset is :1300
# class_index:27, Acc1 0.040769230769230766
# 1300
# Len of new dataset is :1300
# class_index:28, Acc1 0.24
# 1300
# Len of new dataset is :1300
# class_index:29, Acc1 0.7815384615384615
# 1300
# Len of new dataset is :1300
# class_index:30, Acc1 0.3153846153846154
# 1300
# Len of new dataset is :1300
# class_index:31, Acc1 0.45384615384615384
# 1300
# Len of new dataset is :1300
# class_index:32, Acc1 0.44846153846153847
# 1300
# Len of new dataset is :1300
# class_index:33, Acc1 0.1823076923076923
# 1300
# Len of new dataset is :1300
# class_index:34, Acc1 0.2423076923076923
# 1300
# Len of new dataset is :1300
# class_index:35, Acc1 0.18846153846153846
# 1300
# Len of new dataset is :1300
# class_index:36, Acc1 0.33
# 1300
# Len of new dataset is :1300
# class_index:37, Acc1 0.07692307692307693
# 1300
# Len of new dataset is :1300
# class_index:38, Acc1 0.5215384615384615
# 1300
# Len of new dataset is :1300
# class_index:39, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:40, Acc1 0.4469230769230769
# 1300
# Len of new dataset is :1300
# class_index:41, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:42, Acc1 0.34384615384615386
# 1117
# Len of new dataset is :1117
# class_index:43, Acc1 0.26678603401969564
# 1300
# Len of new dataset is :1300
# class_index:44, Acc1 0.3038461538461538
# 1300
# Len of new dataset is :1300
# class_index:45, Acc1 0.2692307692307692
# 1300
# Len of new dataset is :1300
# class_index:46, Acc1 0.15461538461538463
# 1300
# Len of new dataset is :1300
# class_index:47, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:48, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:49, Acc1 0.3569230769230769
# 1300
# Len of new dataset is :1300
# class_index:50, Acc1 0.24769230769230768
# 1266
# Len of new dataset is :1266
# class_index:51, Acc1 0.8041074249605056
# 1300
# Len of new dataset is :1300
# class_index:52, Acc1 0.37153846153846154
# 1300
# Len of new dataset is :1300
# class_index:53, Acc1 0.23615384615384616
# 1300
# Len of new dataset is :1300
# class_index:54, Acc1 0.23307692307692307
# 1300
# Len of new dataset is :1300
# class_index:55, Acc1 0.12846153846153846
# 1300
# Len of new dataset is :1300
# class_index:56, Acc1 0.27384615384615385
# 1300
# Len of new dataset is :1300
# class_index:57, Acc1 0.2907692307692308
# 1300
# Len of new dataset is :1300
# class_index:58, Acc1 0.2630769230769231
# 1300
# Len of new dataset is :1300
# class_index:59, Acc1 0.3676923076923077
# 1300
# Len of new dataset is :1300
# class_index:60, Acc1 0.13
# 1300
# Len of new dataset is :1300
# class_index:61, Acc1 0.2923076923076923
# 1071
# Len of new dataset is :1071
# class_index:62, Acc1 0.17740429505135388
# 1300
# Len of new dataset is :1300
# class_index:63, Acc1 0.49153846153846154
# 1300
# Len of new dataset is :1300
# class_index:64, Acc1 0.12461538461538461
# 1300
# Len of new dataset is :1300
# class_index:65, Acc1 0.4576923076923077
# 1300
# Len of new dataset is :1300
# class_index:66, Acc1 0.42538461538461536
# 1300
# Len of new dataset is :1300
# class_index:67, Acc1 0.27
# 1300
# Len of new dataset is :1300
# class_index:68, Acc1 0.3192307692307692
# 1300
# Len of new dataset is :1300
# class_index:69, Acc1 0.7107692307692308
# 1300
# Len of new dataset is :1300
# class_index:70, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:71, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:72, Acc1 0.31153846153846154
# 1300
# Len of new dataset is :1300
# class_index:73, Acc1 0.47615384615384615
# 1300
# Len of new dataset is :1300
# class_index:74, Acc1 0.30615384615384617
# 1300
# Len of new dataset is :1300
# class_index:75, Acc1 0.5007692307692307
# 1300
# Len of new dataset is :1300
# class_index:76, Acc1 0.44846153846153847
# 1300
# Len of new dataset is :1300
# class_index:77, Acc1 0.49538461538461537
# 1300
# Len of new dataset is :1300
# class_index:78, Acc1 0.5638461538461539
# 1300
# Len of new dataset is :1300
# class_index:79, Acc1 0.4553846153846154
# 1300
# Len of new dataset is :1300
# class_index:80, Acc1 0.5476923076923077
# 1300
# Len of new dataset is :1300
# class_index:81, Acc1 0.56
# 1300
# Len of new dataset is :1300
# class_index:82, Acc1 0.35
# 1300
# Len of new dataset is :1300
# class_index:83, Acc1 0.5884615384615385
# 1300
# Len of new dataset is :1300
# class_index:84, Acc1 0.7084615384615385
# 1300
# Len of new dataset is :1300
# class_index:85, Acc1 0.546923076923077
# 1300
# Len of new dataset is :1300
# class_index:86, Acc1 0.3153846153846154
# 1300
# Len of new dataset is :1300
# class_index:87, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:88, Acc1 0.6676923076923077
# 1300
# Len of new dataset is :1300
# class_index:89, Acc1 0.7238461538461538
# 1300
# Len of new dataset is :1300
# class_index:90, Acc1 0.5215384615384615
# 1300
# Len of new dataset is :1300
# class_index:91, Acc1 0.11153846153846154
# 1300
# Len of new dataset is :1300
# class_index:92, Acc1 0.7230769230769231
# 1300
# Len of new dataset is :1300
# class_index:93, Acc1 0.2915384615384615
# 1300
# Len of new dataset is :1300
# class_index:94, Acc1 0.8115384615384615
# 1300
# Len of new dataset is :1300
# class_index:95, Acc1 0.3946153846153846
# 1300
# Len of new dataset is :1300
# class_index:96, Acc1 0.48
# 1300
# Len of new dataset is :1300
# class_index:97, Acc1 0.6907692307692308
# 1141
# Len of new dataset is :1141
# class_index:98, Acc1 0.5933391761612621
# 1300
# Len of new dataset is :1300
# class_index:99, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:100, Acc1 0.5784615384615385
# 1300
# Len of new dataset is :1300
# class_index:101, Acc1 0.6361538461538462
# 1300
# Len of new dataset is :1300
# class_index:102, Acc1 0.40076923076923077
# 1272
# Len of new dataset is :1272
# class_index:103, Acc1 0.43160377358490565
# 1300
# Len of new dataset is :1300
# class_index:104, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:105, Acc1 0.7684615384615384
# 1300
# Len of new dataset is :1300
# class_index:106, Acc1 0.6238461538461538
# 1300
# Len of new dataset is :1300
# class_index:107, Acc1 0.6953846153846154
# 1300
# Len of new dataset is :1300
# class_index:108, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:109, Acc1 0.7376923076923076
# 1300
# Len of new dataset is :1300
# class_index:110, Acc1 0.5030769230769231
# 1300
# Len of new dataset is :1300
# class_index:111, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:112, Acc1 0.22692307692307692
# 1300
# Len of new dataset is :1300
# class_index:113, Acc1 0.48307692307692307
# 1300
# Len of new dataset is :1300
# class_index:114, Acc1 0.33153846153846156
# 1300
# Len of new dataset is :1300
# class_index:115, Acc1 0.48307692307692307
# 1300
# Len of new dataset is :1300
# class_index:116, Acc1 0.5338461538461539
# 1300
# Len of new dataset is :1300
# class_index:117, Acc1 0.7884615384615384
# 1300
# Len of new dataset is :1300
# class_index:118, Acc1 0.07769230769230769
# 1300
# Len of new dataset is :1300
# class_index:119, Acc1 0.21923076923076923
# 1300
# Len of new dataset is :1300
# class_index:120, Acc1 0.4046153846153846
# 1300
# Len of new dataset is :1300
# class_index:121, Acc1 0.08538461538461538
# 1300
# Len of new dataset is :1300
# class_index:122, Acc1 0.21307692307692308
# 1300
# Len of new dataset is :1300
# class_index:123, Acc1 0.5269230769230769
# 1300
# Len of new dataset is :1300
# class_index:124, Acc1 0.19923076923076924
# 1300
# Len of new dataset is :1300
# class_index:125, Acc1 0.31153846153846154
# 1300
# Len of new dataset is :1300
# class_index:126, Acc1 0.5184615384615384
# 1300
# Len of new dataset is :1300
# class_index:127, Acc1 0.4530769230769231
# 1300
# Len of new dataset is :1300
# class_index:128, Acc1 0.676923076923077
# 1300
# Len of new dataset is :1300
# class_index:129, Acc1 0.7230769230769231
# 1300
# Len of new dataset is :1300
# class_index:130, Acc1 0.4115384615384615
# 1300
# Len of new dataset is :1300
# class_index:131, Acc1 0.44076923076923075
# 1300
# Len of new dataset is :1300
# class_index:132, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:133, Acc1 0.38
# 1300
# Len of new dataset is :1300
# class_index:134, Acc1 0.4715384615384615
# 1300
# Len of new dataset is :1300
# class_index:135, Acc1 0.6161538461538462
# 1300
# Len of new dataset is :1300
# class_index:136, Acc1 0.36
# 1300
# Len of new dataset is :1300
# class_index:137, Acc1 0.6238461538461538
# 1300
# Len of new dataset is :1300
# class_index:138, Acc1 0.62
# 1300
# Len of new dataset is :1300
# class_index:139, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:140, Acc1 0.4369230769230769
# 1300
# Len of new dataset is :1300
# class_index:141, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:142, Acc1 0.49538461538461537
# 1300
# Len of new dataset is :1300
# class_index:143, Acc1 0.36923076923076925
# 1300
# Len of new dataset is :1300
# class_index:144, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:145, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:146, Acc1 0.6315384615384615
# 1150
# Len of new dataset is :1150
# class_index:147, Acc1 0.3243478260869565
# 1300
# Len of new dataset is :1300
# class_index:148, Acc1 0.4753846153846154
# 1300
# Len of new dataset is :1300
# class_index:149, Acc1 0.7861538461538462
# 1300
# Len of new dataset is :1300
# class_index:150, Acc1 0.3769230769230769
# 1300
# Len of new dataset is :1300
# class_index:151, Acc1 0.46307692307692305
# 772
# Len of new dataset is :772
# class_index:152, Acc1 0.7797927461139896
# 1300
# Len of new dataset is :1300
# class_index:153, Acc1 0.8176923076923077
# 1300
# Len of new dataset is :1300
# class_index:154, Acc1 0.5838461538461538
# 1300
# Len of new dataset is :1300
# class_index:155, Acc1 0.5576923076923077
# 1300
# Len of new dataset is :1300
# class_index:156, Acc1 0.3
# 1300
# Len of new dataset is :1300
# class_index:157, Acc1 0.7853846153846153
# 860
# Len of new dataset is :860
# class_index:158, Acc1 0.43372093023255814
# 1300
# Len of new dataset is :1300
# class_index:159, Acc1 0.014615384615384615
# 1300
# Len of new dataset is :1300
# class_index:160, Acc1 0.6538461538461539
# 1300
# Len of new dataset is :1300
# class_index:161, Acc1 0.5307692307692308
# 1300
# Len of new dataset is :1300
# class_index:162, Acc1 0.21769230769230768
# 1300
# Len of new dataset is :1300
# class_index:163, Acc1 0.17461538461538462
# 1136
# Len of new dataset is :1136
# class_index:164, Acc1 0.5079225352112676
# 732
# Len of new dataset is :732
# class_index:165, Acc1 0.13387978142076504
# 1025
# Len of new dataset is :1025
# class_index:166, Acc1 0.26146341463414635
# 754
# Len of new dataset is :754
# class_index:167, Acc1 0.05172413793103448
# 1290
# Len of new dataset is :1290
# class_index:168, Acc1 0.006201550387596899
# 1300
# Len of new dataset is :1300
# class_index:169, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:170, Acc1 0.4338461538461538
# 1300
# Len of new dataset is :1300
# class_index:171, Acc1 0.6353846153846154
# 1300
# Len of new dataset is :1300
# class_index:172, Acc1 0.42923076923076925
# 1300
# Len of new dataset is :1300
# class_index:173, Acc1 0.13692307692307693
# 1300
# Len of new dataset is :1300
# class_index:174, Acc1 0.7192307692307692
# 738
# Len of new dataset is :738
# class_index:175, Acc1 0.10840108401084012
# 1300
# Len of new dataset is :1300
# class_index:176, Acc1 0.6330769230769231
# 1300
# Len of new dataset is :1300
# class_index:177, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:178, Acc1 0.7523076923076923
# 1300
# Len of new dataset is :1300
# class_index:179, Acc1 0.5023076923076923
# 1300
# Len of new dataset is :1300
# class_index:180, Acc1 0.3030769230769231
# 1258
# Len of new dataset is :1258
# class_index:181, Acc1 0.8354531001589826
# 1300
# Len of new dataset is :1300
# class_index:182, Acc1 0.1423076923076923
# 1273
# Len of new dataset is :1273
# class_index:183, Acc1 0.6535742340926944
# 1300
# Len of new dataset is :1300
# class_index:184, Acc1 0.003076923076923077
# 1300
# Len of new dataset is :1300
# class_index:185, Acc1 0.04923076923076923
# 1300
# Len of new dataset is :1300
# class_index:186, Acc1 0.07153846153846154
# 1300
# Len of new dataset is :1300
# class_index:187, Acc1 0.2676923076923077
# 977
# Len of new dataset is :977
# class_index:188, Acc1 0.5312180143295804
# 1300
# Len of new dataset is :1300
# class_index:189, Acc1 0.1076923076923077
# 936
# Len of new dataset is :936
# class_index:190, Acc1 0.7414529914529915
# 1300
# Len of new dataset is :1300
# class_index:191, Acc1 0.004615384615384616
# 1300
# Len of new dataset is :1300
# class_index:192, Acc1 0.4330769230769231
# 1300
# Len of new dataset is :1300
# class_index:193, Acc1 0.07
# 1156
# Len of new dataset is :1156
# class_index:194, Acc1 0.6271626297577855
# 1300
# Len of new dataset is :1300
# class_index:195, Acc1 0.6846153846153846
# 1300
# Len of new dataset is :1300
# class_index:196, Acc1 0.5638461538461539
# 1300
# Len of new dataset is :1300
# class_index:197, Acc1 0.536923076923077
# 1300
# Len of new dataset is :1300
# class_index:198, Acc1 0.5346153846153846
# 1300
# Len of new dataset is :1300
# class_index:199, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:200, Acc1 0.5907692307692308
# 1300
# Len of new dataset is :1300
# class_index:201, Acc1 0.0823076923076923
# 1300
# Len of new dataset is :1300
# class_index:202, Acc1 0.07923076923076923
# 1300
# Len of new dataset is :1300
# class_index:203, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:204, Acc1 0.4246153846153846
# 1300
# Len of new dataset is :1300
# class_index:205, Acc1 0.6169230769230769
# 1218
# Len of new dataset is :1218
# class_index:206, Acc1 0.6773399014778325
# 1300
# Len of new dataset is :1300
# class_index:207, Acc1 0.18461538461538463
# 1300
# Len of new dataset is :1300
# class_index:208, Acc1 0.4176923076923077
# 1300
# Len of new dataset is :1300
# class_index:209, Acc1 0.12230769230769231
# 1300
# Len of new dataset is :1300
# class_index:210, Acc1 0.47
# 1300
# Len of new dataset is :1300
# class_index:211, Acc1 0.0038461538461538464
# 1300
# Len of new dataset is :1300
# class_index:212, Acc1 0.6153846153846154
# 1300
# Len of new dataset is :1300
# class_index:213, Acc1 0.015384615384615385
# 1300
# Len of new dataset is :1300
# class_index:214, Acc1 0.06076923076923077
# 1300
# Len of new dataset is :1300
# class_index:215, Acc1 0.018461538461538463
# 1300
# Len of new dataset is :1300
# class_index:216, Acc1 0.4969230769230769
# 1300
# Len of new dataset is :1300
# class_index:217, Acc1 0.6269230769230769
# 1300
# Len of new dataset is :1300
# class_index:218, Acc1 0.0038461538461538464
# 1300
# Len of new dataset is :1300
# class_index:219, Acc1 0.5453846153846154
# 1300
# Len of new dataset is :1300
# class_index:220, Acc1 0.3415384615384615
# 969
# Len of new dataset is :969
# class_index:221, Acc1 0.34365325077399383
# 1300
# Len of new dataset is :1300
# class_index:222, Acc1 0.7376923076923076
# 1300
# Len of new dataset is :1300
# class_index:223, Acc1 0.6330769230769231
# 1300
# Len of new dataset is :1300
# class_index:224, Acc1 0.7569230769230769
# 1300
# Len of new dataset is :1300
# class_index:225, Acc1 0.04461538461538461
# 1300
# Len of new dataset is :1300
# class_index:226, Acc1 0.2653846153846154
# 1300
# Len of new dataset is :1300
# class_index:227, Acc1 0.41
# 1300
# Len of new dataset is :1300
# class_index:228, Acc1 0.8284615384615385
# 1300
# Len of new dataset is :1300
# class_index:229, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:230, Acc1 0.31153846153846154
# 1300
# Len of new dataset is :1300
# class_index:231, Acc1 0.18769230769230769
# 1300
# Len of new dataset is :1300
# class_index:232, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:233, Acc1 0.5515384615384615
# 1300
# Len of new dataset is :1300
# class_index:234, Acc1 0.012307692307692308
# 1300
# Len of new dataset is :1300
# class_index:235, Acc1 0.20846153846153845
# 1300
# Len of new dataset is :1300
# class_index:236, Acc1 0.09153846153846154
# 1300
# Len of new dataset is :1300
# class_index:237, Acc1 0.29615384615384616
# 1300
# Len of new dataset is :1300
# class_index:238, Acc1 0.11538461538461539
# 1300
# Len of new dataset is :1300
# class_index:239, Acc1 0.1076923076923077
# 1300
# Len of new dataset is :1300
# class_index:240, Acc1 0.10692307692307693
# 1300
# Len of new dataset is :1300
# class_index:241, Acc1 0.09769230769230769
# 1300
# Len of new dataset is :1300
# class_index:242, Acc1 0.17384615384615384
# 1300
# Len of new dataset is :1300
# class_index:243, Acc1 0.2553846153846154
# 1300
# Len of new dataset is :1300
# class_index:244, Acc1 0.4684615384615385
# 1300
# Len of new dataset is :1300
# class_index:245, Acc1 0.62
# 1300
# Len of new dataset is :1300
# class_index:246, Acc1 0.6392307692307693
# 1300
# Len of new dataset is :1300
# class_index:247, Acc1 0.4746153846153846
# 1300
# Len of new dataset is :1300
# class_index:248, Acc1 0.26615384615384613
# 1300
# Len of new dataset is :1300
# class_index:249, Acc1 0.5607692307692308
# 1300
# Len of new dataset is :1300
# class_index:250, Acc1 0.57
# 1300
# Len of new dataset is :1300
# class_index:251, Acc1 0.8353846153846154
# 954
# Len of new dataset is :954
# class_index:252, Acc1 0.7138364779874213
# 1300
# Len of new dataset is :1300
# class_index:253, Acc1 0.20307692307692307
# 1300
# Len of new dataset is :1300
# class_index:254, Acc1 0.7269230769230769
# 1300
# Len of new dataset is :1300
# class_index:255, Acc1 0.11923076923076924
# 1300
# Len of new dataset is :1300
# class_index:256, Acc1 0.6615384615384615
# 1300
# Len of new dataset is :1300
# class_index:257, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:258, Acc1 0.7684615384615384
# 1300
# Len of new dataset is :1300
# class_index:259, Acc1 0.5138461538461538
# 1300
# Len of new dataset is :1300
# class_index:260, Acc1 0.5338461538461539
# 1300
# Len of new dataset is :1300
# class_index:261, Acc1 0.82
# 1070
# Len of new dataset is :1070
# class_index:262, Acc1 0.23925233644859814
# 1300
# Len of new dataset is :1300
# class_index:263, Acc1 0.18
# 1300
# Len of new dataset is :1300
# class_index:264, Acc1 0.37384615384615383
# 1300
# Len of new dataset is :1300
# class_index:265, Acc1 0.5415384615384615
# 1300
# Len of new dataset is :1300
# class_index:266, Acc1 0.1946153846153846
# 1300
# Len of new dataset is :1300
# class_index:267, Acc1 0.5784615384615385
# 755
# Len of new dataset is :755
# class_index:268, Acc1 0.6728476821192053
# 1300
# Len of new dataset is :1300
# class_index:269, Acc1 0.5130769230769231
# 1300
# Len of new dataset is :1300
# class_index:270, Acc1 0.6853846153846154
# 1300
# Len of new dataset is :1300
# class_index:271, Acc1 0.21307692307692308
# 1300
# Len of new dataset is :1300
# class_index:272, Acc1 0.5338461538461539
# 1300
# Len of new dataset is :1300
# class_index:273, Acc1 0.14
# 1300
# Len of new dataset is :1300
# class_index:274, Acc1 0.016153846153846154
# 1300
# Len of new dataset is :1300
# class_index:275, Acc1 0.4176923076923077
# 1300
# Len of new dataset is :1300
# class_index:276, Acc1 0.48
# 1300
# Len of new dataset is :1300
# class_index:277, Acc1 0.040769230769230766
# 1300
# Len of new dataset is :1300
# class_index:278, Acc1 0.2123076923076923
# 1300
# Len of new dataset is :1300
# class_index:279, Acc1 0.7584615384615384
# 1300
# Len of new dataset is :1300
# class_index:280, Acc1 0.49538461538461537
# 1300
# Len of new dataset is :1300
# class_index:281, Acc1 0.5353846153846153
# 1300
# Len of new dataset is :1300
# class_index:282, Acc1 0.18
# 1300
# Len of new dataset is :1300
# class_index:283, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:284, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:285, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:286, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:287, Acc1 0.48307692307692307
# 1300
# Len of new dataset is :1300
# class_index:288, Acc1 0.44
# 1300
# Len of new dataset is :1300
# class_index:289, Acc1 0.8546153846153847
# 1300
# Len of new dataset is :1300
# class_index:290, Acc1 0.5653846153846154
# 1300
# Len of new dataset is :1300
# class_index:291, Acc1 0.3546153846153846
# 1300
# Len of new dataset is :1300
# class_index:292, Acc1 0.5553846153846154
# 1300
# Len of new dataset is :1300
# class_index:293, Acc1 0.49923076923076926
# 1300
# Len of new dataset is :1300
# class_index:294, Acc1 0.3123076923076923
# 1300
# Len of new dataset is :1300
# class_index:295, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:296, Acc1 0.7338461538461538
# 1300
# Len of new dataset is :1300
# class_index:297, Acc1 0.5961538461538461
# 1300
# Len of new dataset is :1300
# class_index:298, Acc1 0.38846153846153847
# 1300
# Len of new dataset is :1300
# class_index:299, Acc1 0.6484615384615384
# 1300
# Len of new dataset is :1300
# class_index:300, Acc1 0.6507692307692308
# 1300
# Len of new dataset is :1300
# class_index:301, Acc1 0.22230769230769232
# 1300
# Len of new dataset is :1300
# class_index:302, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:303, Acc1 0.4907692307692308
# 1300
# Len of new dataset is :1300
# class_index:304, Acc1 0.4330769230769231
# 1300
# Len of new dataset is :1300
# class_index:305, Acc1 0.2753846153846154
# 1300
# Len of new dataset is :1300
# class_index:306, Acc1 0.42846153846153845
# 1300
# Len of new dataset is :1300
# class_index:307, Acc1 0.6307692307692307
# 1300
# Len of new dataset is :1300
# class_index:308, Acc1 0.6976923076923077
# 1300
# Len of new dataset is :1300
# class_index:309, Acc1 0.3946153846153846
# 1300
# Len of new dataset is :1300
# class_index:310, Acc1 0.40076923076923077
# 1300
# Len of new dataset is :1300
# class_index:311, Acc1 0.36846153846153845
# 1300
# Len of new dataset is :1300
# class_index:312, Acc1 0.3792307692307692
# 1300
# Len of new dataset is :1300
# class_index:313, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:314, Acc1 0.17692307692307693
# 1300
# Len of new dataset is :1300
# class_index:315, Acc1 0.6476923076923077
# 1300
# Len of new dataset is :1300
# class_index:316, Acc1 0.36
# 1300
# Len of new dataset is :1300
# class_index:317, Acc1 0.5761538461538461
# 1300
# Len of new dataset is :1300
# class_index:318, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:319, Acc1 0.5261538461538462
# 1300
# Len of new dataset is :1300
# class_index:320, Acc1 0.5723076923076923
# 1300
# Len of new dataset is :1300
# class_index:321, Acc1 0.4846153846153846
# 1300
# Len of new dataset is :1300
# class_index:322, Acc1 0.5546153846153846
# 1300
# Len of new dataset is :1300
# class_index:323, Acc1 0.8223076923076923
# 1300
# Len of new dataset is :1300
# class_index:324, Acc1 0.9253846153846154
# 1300
# Len of new dataset is :1300
# class_index:325, Acc1 0.43538461538461537
# 1300
# Len of new dataset is :1300
# class_index:326, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:327, Acc1 0.6107692307692307
# 1300
# Len of new dataset is :1300
# class_index:328, Acc1 0.6723076923076923
# 1300
# Len of new dataset is :1300
# class_index:329, Acc1 0.37
# 1300
# Len of new dataset is :1300
# class_index:330, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:331, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:332, Acc1 0.8038461538461539
# 1300
# Len of new dataset is :1300
# class_index:333, Acc1 0.676923076923077
# 1300
# Len of new dataset is :1300
# class_index:334, Acc1 0.7230769230769231
# 1206
# Len of new dataset is :1206
# class_index:335, Acc1 0.2703150912106136
# 1300
# Len of new dataset is :1300
# class_index:336, Acc1 0.45076923076923076
# 1300
# Len of new dataset is :1300
# class_index:337, Acc1 0.3646153846153846
# 1300
# Len of new dataset is :1300
# class_index:338, Acc1 0.6553846153846153
# 1300
# Len of new dataset is :1300
# class_index:339, Acc1 0.1276923076923077
# 1300
# Len of new dataset is :1300
# class_index:340, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:341, Acc1 0.2976923076923077
# 1300
# Len of new dataset is :1300
# class_index:342, Acc1 0.45153846153846156
# 1300
# Len of new dataset is :1300
# class_index:343, Acc1 0.58
# 1300
# Len of new dataset is :1300
# class_index:344, Acc1 0.5492307692307692
# 1300
# Len of new dataset is :1300
# class_index:345, Acc1 0.3453846153846154
# 1300
# Len of new dataset is :1300
# class_index:346, Acc1 0.5692307692307692
# 1300
# Len of new dataset is :1300
# class_index:347, Acc1 0.5023076923076923
# 1300
# Len of new dataset is :1300
# class_index:348, Acc1 0.46153846153846156
# 1300
# Len of new dataset is :1300
# class_index:349, Acc1 0.6130769230769231
# 1300
# Len of new dataset is :1300
# class_index:350, Acc1 0.6392307692307693
# 1300
# Len of new dataset is :1300
# class_index:351, Acc1 0.3730769230769231
# 1300
# Len of new dataset is :1300
# class_index:352, Acc1 0.27692307692307694
# 1300
# Len of new dataset is :1300
# class_index:353, Acc1 0.58
# 1300
# Len of new dataset is :1300
# class_index:354, Acc1 0.4492307692307692
# 1300
# Len of new dataset is :1300
# class_index:355, Acc1 0.6
# 1300
# Len of new dataset is :1300
# class_index:356, Acc1 0.31
# 1300
# Len of new dataset is :1300
# class_index:357, Acc1 0.3707692307692308
# 1300
# Len of new dataset is :1300
# class_index:358, Acc1 0.4276923076923077
# 1300
# Len of new dataset is :1300
# class_index:359, Acc1 0.3523076923076923
# 1300
# Len of new dataset is :1300
# class_index:360, Acc1 0.4846153846153846
# 1300
# Len of new dataset is :1300
# class_index:361, Acc1 0.75
# 1300
# Len of new dataset is :1300
# class_index:362, Acc1 0.74
# 1300
# Len of new dataset is :1300
# class_index:363, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:364, Acc1 0.5915384615384616
# 1300
# Len of new dataset is :1300
# class_index:365, Acc1 0.2169230769230769
# 1300
# Len of new dataset is :1300
# class_index:366, Acc1 0.7469230769230769
# 1300
# Len of new dataset is :1300
# class_index:367, Acc1 0.2553846153846154
# 1300
# Len of new dataset is :1300
# class_index:368, Acc1 0.5046153846153846
# 1300
# Len of new dataset is :1300
# class_index:369, Acc1 0.4269230769230769
# 1300
# Len of new dataset is :1300
# class_index:370, Acc1 0.4707692307692308
# 1300
# Len of new dataset is :1300
# class_index:371, Acc1 0.24923076923076923
# 1300
# Len of new dataset is :1300
# class_index:372, Acc1 0.5007692307692307
# 1300
# Len of new dataset is :1300
# class_index:373, Acc1 0.3261538461538461
# 1300
# Len of new dataset is :1300
# class_index:374, Acc1 0.5815384615384616
# 1300
# Len of new dataset is :1300
# class_index:375, Acc1 0.63
# 1300
# Len of new dataset is :1300
# class_index:376, Acc1 0.1976923076923077
# 1300
# Len of new dataset is :1300
# class_index:377, Acc1 0.41846153846153844
# 1300
# Len of new dataset is :1300
# class_index:378, Acc1 0.15076923076923077
# 1300
# Len of new dataset is :1300
# class_index:379, Acc1 0.2953846153846154
# 1300
# Len of new dataset is :1300
# class_index:380, Acc1 0.2684615384615385
# 1300
# Len of new dataset is :1300
# class_index:381, Acc1 0.2469230769230769
# 1300
# Len of new dataset is :1300
# class_index:382, Acc1 0.2923076923076923
# 1300
# Len of new dataset is :1300
# class_index:383, Acc1 0.6538461538461539
# 1300
# Len of new dataset is :1300
# class_index:384, Acc1 0.5584615384615385
# 1300
# Len of new dataset is :1300
# class_index:385, Acc1 0.48538461538461536
# 1300
# Len of new dataset is :1300
# class_index:386, Acc1 0.3030769230769231
# 1300
# Len of new dataset is :1300
# class_index:387, Acc1 0.34615384615384615
# 1300
# Len of new dataset is :1300
# class_index:388, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:389, Acc1 0.6684615384615384
# 1165
# Len of new dataset is :1165
# class_index:390, Acc1 0.4068669527896996
# 1300
# Len of new dataset is :1300
# class_index:391, Acc1 0.48
# 969
# Len of new dataset is :969
# class_index:392, Acc1 0.47678018575851394
# 1300
# Len of new dataset is :1300
# class_index:393, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:394, Acc1 0.5223076923076924
# 1300
# Len of new dataset is :1300
# class_index:395, Acc1 0.4323076923076923
# 1300
# Len of new dataset is :1300
# class_index:396, Acc1 0.683076923076923
# 1300
# Len of new dataset is :1300
# class_index:397, Acc1 0.5161538461538462
# 1300
# Len of new dataset is :1300
# class_index:398, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:399, Acc1 0.6153846153846154
# 1300
# Len of new dataset is :1300
# class_index:400, Acc1 0.5323076923076923
# 1300
# Len of new dataset is :1300
# class_index:401, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:402, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:403, Acc1 0.6523076923076923
# 1300
# Len of new dataset is :1300
# class_index:404, Acc1 0.823076923076923
# 1300
# Len of new dataset is :1300
# class_index:405, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:406, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:407, Acc1 0.3546153846153846
# 1300
# Len of new dataset is :1300
# class_index:408, Acc1 0.6446153846153846
# 1292
# Len of new dataset is :1292
# class_index:409, Acc1 0.5712074303405573
# 1300
# Len of new dataset is :1300
# class_index:410, Acc1 0.48538461538461536
# 1300
# Len of new dataset is :1300
# class_index:411, Acc1 0.6730769230769231
# 1300
# Len of new dataset is :1300
# class_index:412, Acc1 0.5315384615384615
# 1300
# Len of new dataset is :1300
# class_index:413, Acc1 0.49153846153846154
# 1300
# Len of new dataset is :1300
# class_index:414, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:415, Acc1 0.08538461538461538
# 1300
# Len of new dataset is :1300
# class_index:416, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:417, Acc1 0.8123076923076923
# 1236
# Len of new dataset is :1236
# class_index:418, Acc1 0.5800970873786407
# 1300
# Len of new dataset is :1300
# class_index:419, Acc1 0.2815384615384615
# 1300
# Len of new dataset is :1300
# class_index:420, Acc1 0.5907692307692308
# 1300
# Len of new dataset is :1300
# class_index:421, Acc1 0.5215384615384615
# 1300
# Len of new dataset is :1300
# class_index:422, Acc1 0.6884615384615385
# 1300
# Len of new dataset is :1300
# class_index:423, Acc1 0.7376923076923076
# 1300
# Len of new dataset is :1300
# class_index:424, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:425, Acc1 0.7815384615384615
# 1199
# Len of new dataset is :1199
# class_index:426, Acc1 0.713094245204337
# 1300
# Len of new dataset is :1300
# class_index:427, Acc1 0.47923076923076924
# 1300
# Len of new dataset is :1300
# class_index:428, Acc1 0.5915384615384616
# 1300
# Len of new dataset is :1300
# class_index:429, Acc1 0.5992307692307692
# 1300
# Len of new dataset is :1300
# class_index:430, Acc1 0.42923076923076925
# 1300
# Len of new dataset is :1300
# class_index:431, Acc1 0.78
# 1300
# Len of new dataset is :1300
# class_index:432, Acc1 0.5038461538461538
# 1300
# Len of new dataset is :1300
# class_index:433, Acc1 0.5453846153846154
# 1300
# Len of new dataset is :1300
# class_index:434, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:435, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:436, Acc1 0.5892307692307692
# 1300
# Len of new dataset is :1300
# class_index:437, Acc1 0.8161538461538461
# 1300
# Len of new dataset is :1300
# class_index:438, Acc1 0.7446153846153846
# 1209
# Len of new dataset is :1209
# class_index:439, Acc1 0.5318444995864351
# 1300
# Len of new dataset is :1300
# class_index:440, Acc1 0.47692307692307695
# 1300
# Len of new dataset is :1300
# class_index:441, Acc1 0.28692307692307695
# 1300
# Len of new dataset is :1300
# class_index:442, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:443, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:444, Acc1 0.7276923076923076
# 1300
# Len of new dataset is :1300
# class_index:445, Acc1 0.27384615384615385
# 1300
# Len of new dataset is :1300
# class_index:446, Acc1 0.7161538461538461
# 1300
# Len of new dataset is :1300
# class_index:447, Acc1 0.5584615384615385
# 1300
# Len of new dataset is :1300
# class_index:448, Acc1 0.8
# 1300
# Len of new dataset is :1300
# class_index:449, Acc1 0.6376923076923077
# 1300
# Len of new dataset is :1300
# class_index:450, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:451, Acc1 0.6707692307692308
# 1300
# Len of new dataset is :1300
# class_index:452, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:453, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:454, Acc1 0.4523076923076923
# 1300
# Len of new dataset is :1300
# class_index:455, Acc1 0.693076923076923
# 1300
# Len of new dataset is :1300
# class_index:456, Acc1 0.5023076923076923
# 1300
# Len of new dataset is :1300
# class_index:457, Acc1 0.46
# 1300
# Len of new dataset is :1300
# class_index:458, Acc1 0.7515384615384615
# 1300
# Len of new dataset is :1300
# class_index:459, Acc1 0.5161538461538462
# 1300
# Len of new dataset is :1300
# class_index:460, Acc1 0.2553846153846154
# 1300
# Len of new dataset is :1300
# class_index:461, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:462, Acc1 0.6423076923076924
# 1300
# Len of new dataset is :1300
# class_index:463, Acc1 0.5476923076923077
# 1300
# Len of new dataset is :1300
# class_index:464, Acc1 0.37615384615384617
# 1176
# Len of new dataset is :1176
# class_index:465, Acc1 0.7219387755102041
# 1300
# Len of new dataset is :1300
# class_index:466, Acc1 0.9107692307692308
# 1300
# Len of new dataset is :1300
# class_index:467, Acc1 0.033846153846153845
# 1300
# Len of new dataset is :1300
# class_index:468, Acc1 0.42538461538461536
# 1300
# Len of new dataset is :1300
# class_index:469, Acc1 0.5015384615384615
# 1300
# Len of new dataset is :1300
# class_index:470, Acc1 0.5876923076923077
# 1300
# Len of new dataset is :1300
# class_index:471, Acc1 0.7269230769230769
# 1300
# Len of new dataset is :1300
# class_index:472, Acc1 0.62
# 1300
# Len of new dataset is :1300
# class_index:473, Acc1 0.5030769230769231
# 1300
# Len of new dataset is :1300
# class_index:474, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:475, Acc1 0.8115384615384615
# 1300
# Len of new dataset is :1300
# class_index:476, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:477, Acc1 0.6838461538461539
# 1300
# Len of new dataset is :1300
# class_index:478, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:479, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:480, Acc1 0.8238461538461539
# 1186
# Len of new dataset is :1186
# class_index:481, Acc1 0.6922428330522765
# 1300
# Len of new dataset is :1300
# class_index:482, Acc1 0.3476923076923077
# 1300
# Len of new dataset is :1300
# class_index:483, Acc1 0.7261538461538461
# 1300
# Len of new dataset is :1300
# class_index:484, Acc1 0.5976923076923077
# 1300
# Len of new dataset is :1300
# class_index:485, Acc1 0.5384615384615384
# 1300
# Len of new dataset is :1300
# class_index:486, Acc1 0.3546153846153846
# 1300
# Len of new dataset is :1300
# class_index:487, Acc1 0.49923076923076926
# 1300
# Len of new dataset is :1300
# class_index:488, Acc1 0.41923076923076924
# 1300
# Len of new dataset is :1300
# class_index:489, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:490, Acc1 0.5423076923076923
# 1194
# Len of new dataset is :1194
# class_index:491, Acc1 0.27554438860971525
# 1300
# Len of new dataset is :1300
# class_index:492, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:493, Acc1 0.6184615384615385
# 1300
# Len of new dataset is :1300
# class_index:494, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:495, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:496, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:497, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:498, Acc1 0.6938461538461539
# 1067
# Len of new dataset is :1067
# class_index:499, Acc1 0.4414245548266167
# 1300
# Len of new dataset is :1300
# class_index:500, Acc1 0.43153846153846154
# 1029
# Len of new dataset is :1029
# class_index:501, Acc1 0.6122448979591837
# 1300
# Len of new dataset is :1300
# class_index:502, Acc1 0.43538461538461537
# 1154
# Len of new dataset is :1154
# class_index:503, Acc1 0.634315424610052
# 1300
# Len of new dataset is :1300
# class_index:504, Acc1 0.5869230769230769
# 1300
# Len of new dataset is :1300
# class_index:505, Acc1 0.53
# 1300
# Len of new dataset is :1300
# class_index:506, Acc1 0.6846153846153846
# 1216
# Len of new dataset is :1216
# class_index:507, Acc1 0.6044407894736842
# 1300
# Len of new dataset is :1300
# class_index:508, Acc1 0.6623076923076923
# 1300
# Len of new dataset is :1300
# class_index:509, Acc1 0.45615384615384613
# 1300
# Len of new dataset is :1300
# class_index:510, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:511, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:512, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:513, Acc1 0.48307692307692307
# 1300
# Len of new dataset is :1300
# class_index:514, Acc1 0.5069230769230769
# 1300
# Len of new dataset is :1300
# class_index:515, Acc1 0.43923076923076926
# 1300
# Len of new dataset is :1300
# class_index:516, Acc1 0.4046153846153846
# 1300
# Len of new dataset is :1300
# class_index:517, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:518, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:519, Acc1 0.3323076923076923
# 1300
# Len of new dataset is :1300
# class_index:520, Acc1 0.8430769230769231
# 1187
# Len of new dataset is :1187
# class_index:521, Acc1 0.6764953664700927
# 1300
# Len of new dataset is :1300
# class_index:522, Acc1 0.5769230769230769
# 1300
# Len of new dataset is :1300
# class_index:523, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:524, Acc1 0.38769230769230767
# 1300
# Len of new dataset is :1300
# class_index:525, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:526, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:527, Acc1 0.5246153846153846
# 1300
# Len of new dataset is :1300
# class_index:528, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:529, Acc1 0.5084615384615384
# 1300
# Len of new dataset is :1300
# class_index:530, Acc1 0.7561538461538462
# 889
# Len of new dataset is :889
# class_index:531, Acc1 0.7435320584926884
# 1300
# Len of new dataset is :1300
# class_index:532, Acc1 0.7176923076923077
# 1300
# Len of new dataset is :1300
# class_index:533, Acc1 0.8607692307692307
# 1300
# Len of new dataset is :1300
# class_index:534, Acc1 0.61
# 1300
# Len of new dataset is :1300
# class_index:535, Acc1 0.7
# 1211
# Len of new dataset is :1211
# class_index:536, Acc1 0.3476465730800991
# 1300
# Len of new dataset is :1300
# class_index:537, Acc1 0.5123076923076924
# 1300
# Len of new dataset is :1300
# class_index:538, Acc1 0.5776923076923077
# 1300
# Len of new dataset is :1300
# class_index:539, Acc1 0.6015384615384616
# 1300
# Len of new dataset is :1300
# class_index:540, Acc1 0.6246153846153846
# 1300
# Len of new dataset is :1300
# class_index:541, Acc1 0.3823076923076923
# 1300
# Len of new dataset is :1300
# class_index:542, Acc1 0.27615384615384614
# 1300
# Len of new dataset is :1300
# class_index:543, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:544, Acc1 0.3130769230769231
# 1300
# Len of new dataset is :1300
# class_index:545, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:546, Acc1 0.7176923076923077
# 1300
# Len of new dataset is :1300
# class_index:547, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:548, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:549, Acc1 0.6853846153846154
# 1136
# Len of new dataset is :1136
# class_index:550, Acc1 0.6795774647887324
# 1153
# Len of new dataset is :1153
# class_index:551, Acc1 0.49522983521248914
# 1300
# Len of new dataset is :1300
# class_index:552, Acc1 0.7653846153846153
# 1300
# Len of new dataset is :1300
# class_index:553, Acc1 0.6561538461538462
# 1300
# Len of new dataset is :1300
# class_index:554, Acc1 0.5038461538461538
# 1300
# Len of new dataset is :1300
# class_index:555, Acc1 0.3453846153846154
# 1300
# Len of new dataset is :1300
# class_index:556, Acc1 0.5892307692307692
# 1300
# Len of new dataset is :1300
# class_index:557, Acc1 0.6292307692307693
# 1300
# Len of new dataset is :1300
# class_index:558, Acc1 0.3946153846153846
# 1300
# Len of new dataset is :1300
# class_index:559, Acc1 0.7423076923076923
# 1300
# Len of new dataset is :1300
# class_index:560, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:561, Acc1 0.7415384615384616
# 1300
# Len of new dataset is :1300
# class_index:562, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:563, Acc1 0.47615384615384615
# 1300
# Len of new dataset is :1300
# class_index:564, Acc1 0.7992307692307692
# 1300
# Len of new dataset is :1300
# class_index:565, Acc1 0.8076923076923077
# 1300
# Len of new dataset is :1300
# class_index:566, Acc1 0.6269230769230769
# 1222
# Len of new dataset is :1222
# class_index:567, Acc1 0.27086743044189854
# 1300
# Len of new dataset is :1300
# class_index:568, Acc1 0.41923076923076924
# 1300
# Len of new dataset is :1300
# class_index:569, Acc1 0.8338461538461538
# 1300
# Len of new dataset is :1300
# class_index:570, Acc1 0.6961538461538461
# 1300
# Len of new dataset is :1300
# class_index:571, Acc1 0.6646153846153846
# 1300
# Len of new dataset is :1300
# class_index:572, Acc1 0.7930769230769231
# 1300
# Len of new dataset is :1300
# class_index:573, Acc1 0.7215384615384616
# 1300
# Len of new dataset is :1300
# class_index:574, Acc1 0.7976923076923077
# 1300
# Len of new dataset is :1300
# class_index:575, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:576, Acc1 0.8584615384615385
# 1282
# Len of new dataset is :1282
# class_index:577, Acc1 0.6021840873634945
# 1300
# Len of new dataset is :1300
# class_index:578, Acc1 0.44384615384615383
# 1300
# Len of new dataset is :1300
# class_index:579, Acc1 0.6623076923076923
# 1300
# Len of new dataset is :1300
# class_index:580, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:581, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:582, Acc1 0.21076923076923076
# 1283
# Len of new dataset is :1283
# class_index:583, Acc1 0.730319563522993
# 1300
# Len of new dataset is :1300
# class_index:584, Acc1 0.5969230769230769
# 980
# Len of new dataset is :980
# class_index:585, Acc1 0.39693877551020407
# 1300
# Len of new dataset is :1300
# class_index:586, Acc1 0.8615384615384616
# 1300
# Len of new dataset is :1300
# class_index:587, Acc1 0.29923076923076924
# 1300
# Len of new dataset is :1300
# class_index:588, Acc1 0.556923076923077
# 1300
# Len of new dataset is :1300
# class_index:589, Acc1 0.6084615384615385
# 1034
# Len of new dataset is :1034
# class_index:590, Acc1 0.7050290135396519
# 1300
# Len of new dataset is :1300
# class_index:591, Acc1 0.6
# 1300
# Len of new dataset is :1300
# class_index:592, Acc1 0.7376923076923076
# 1300
# Len of new dataset is :1300
# class_index:593, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:594, Acc1 0.7669230769230769
# 1300
# Len of new dataset is :1300
# class_index:595, Acc1 0.6446153846153846
# 891
# Len of new dataset is :891
# class_index:596, Acc1 0.2760942760942761
# 1300
# Len of new dataset is :1300
# class_index:597, Acc1 0.6284615384615385
# 1300
# Len of new dataset is :1300
# class_index:598, Acc1 0.6292307692307693
# 1300
# Len of new dataset is :1300
# class_index:599, Acc1 0.43
# 1300
# Len of new dataset is :1300
# class_index:600, Acc1 0.42230769230769233
# 1300
# Len of new dataset is :1300
# class_index:601, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:602, Acc1 0.5776923076923077
# 1300
# Len of new dataset is :1300
# class_index:603, Acc1 0.7392307692307692
# 1300
# Len of new dataset is :1300
# class_index:604, Acc1 0.8207692307692308
# 1300
# Len of new dataset is :1300
# class_index:605, Acc1 0.7753846153846153
# 1300
# Len of new dataset is :1300
# class_index:606, Acc1 0.6615384615384615
# 1300
# Len of new dataset is :1300
# class_index:607, Acc1 0.4815384615384615
# 1300
# Len of new dataset is :1300
# class_index:608, Acc1 0.25769230769230766
# 1300
# Len of new dataset is :1300
# class_index:609, Acc1 0.8161538461538461
# 1285
# Len of new dataset is :1285
# class_index:610, Acc1 0.6747081712062257
# 1300
# Len of new dataset is :1300
# class_index:611, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:612, Acc1 0.6861538461538461
# 1300
# Len of new dataset is :1300
# class_index:613, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:614, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:615, Acc1 0.5823076923076923
# 1300
# Len of new dataset is :1300
# class_index:616, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:617, Acc1 0.6376923076923077
# 1300
# Len of new dataset is :1300
# class_index:618, Acc1 0.3515384615384615
# 1300
# Len of new dataset is :1300
# class_index:619, Acc1 0.49230769230769234
# 1300
# Len of new dataset is :1300
# class_index:620, Acc1 0.5484615384615384
# 1300
# Len of new dataset is :1300
# class_index:621, Acc1 0.65
# 1300
# Len of new dataset is :1300
# class_index:622, Acc1 0.6630769230769231
# 986
# Len of new dataset is :986
# class_index:623, Acc1 0.40466531440162273
# 1300
# Len of new dataset is :1300
# class_index:624, Acc1 0.5876923076923077
# 1300
# Len of new dataset is :1300
# class_index:625, Acc1 0.05692307692307692
# 1300
# Len of new dataset is :1300
# class_index:626, Acc1 0.5707692307692308
# 1300
# Len of new dataset is :1300
# class_index:627, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:628, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:629, Acc1 0.4323076923076923
# 1137
# Len of new dataset is :1137
# class_index:630, Acc1 0.41424802110817943
# 1272
# Len of new dataset is :1272
# class_index:631, Acc1 0.6171383647798742
# 1300
# Len of new dataset is :1300
# class_index:632, Acc1 0.5276923076923077
# 1300
# Len of new dataset is :1300
# class_index:633, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:634, Acc1 0.1123076923076923
# 1155
# Len of new dataset is :1155
# class_index:635, Acc1 0.7619047619047619
# 1300
# Len of new dataset is :1300
# class_index:636, Acc1 0.53
# 1300
# Len of new dataset is :1300
# class_index:637, Acc1 0.6569230769230769
# 1300
# Len of new dataset is :1300
# class_index:638, Acc1 0.26461538461538464
# 1300
# Len of new dataset is :1300
# class_index:639, Acc1 0.49846153846153846
# 1300
# Len of new dataset is :1300
# class_index:640, Acc1 0.8092307692307692
# 1300
# Len of new dataset is :1300
# class_index:641, Acc1 0.49846153846153846
# 1300
# Len of new dataset is :1300
# class_index:642, Acc1 0.4723076923076923
# 1300
# Len of new dataset is :1300
# class_index:643, Acc1 0.5546153846153846
# 1300
# Len of new dataset is :1300
# class_index:644, Acc1 0.4676923076923077
# 1300
# Len of new dataset is :1300
# class_index:645, Acc1 0.8715384615384615
# 1300
# Len of new dataset is :1300
# class_index:646, Acc1 0.8053846153846154
# 1300
# Len of new dataset is :1300
# class_index:647, Acc1 0.6484615384615384
# 1300
# Len of new dataset is :1300
# class_index:648, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:649, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:650, Acc1 0.49846153846153846
# 1300
# Len of new dataset is :1300
# class_index:651, Acc1 0.5607692307692308
# 1300
# Len of new dataset is :1300
# class_index:652, Acc1 0.5
# 1097
# Len of new dataset is :1097
# class_index:653, Acc1 0.7365542388331814
# 1300
# Len of new dataset is :1300
# class_index:654, Acc1 0.6615384615384615
# 1300
# Len of new dataset is :1300
# class_index:655, Acc1 0.3646153846153846
# 1300
# Len of new dataset is :1300
# class_index:656, Acc1 0.6523076923076923
# 1300
# Len of new dataset is :1300
# class_index:657, Acc1 0.6476923076923077
# 1300
# Len of new dataset is :1300
# class_index:658, Acc1 0.7238461538461538
# 1300
# Len of new dataset is :1300
# ...
#   warnings.warn(str(msg))
# class_index:782, Acc1 0.39384372533543804
# 1300
# Len of new dataset is :1300
# class_index:783, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:784, Acc1 0.4046153846153846
# 1300
# Len of new dataset is :1300
# class_index:785, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:786, Acc1 0.7584615384615384
# 1300
# Len of new dataset is :1300
# class_index:787, Acc1 0.4938461538461538
# 1300
# Len of new dataset is :1300
# class_index:788, Acc1 0.5146153846153846
# 1249
# Len of new dataset is :1249
# class_index:789, Acc1 0.611689351481185
# 1300
# Len of new dataset is :1300
# class_index:790, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:791, Acc1 0.71
# 1300
# Len of new dataset is :1300
# class_index:792, Acc1 0.39692307692307693
# 1300
# Len of new dataset is :1300
# class_index:793, Acc1 0.7107692307692308
# 1300
# Len of new dataset is :1300
# class_index:794, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:795, Acc1 0.63
# 1300
# Len of new dataset is :1300
# class_index:796, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:797, Acc1 0.6784615384615384
# 1162
# Len of new dataset is :1162
# class_index:798, Acc1 0.8278829604130808
# 1300
# Len of new dataset is :1300
# class_index:799, Acc1 0.6069230769230769
# 1300
# Len of new dataset is :1300
# class_index:800, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:801, Acc1 0.5769230769230769
# 1300
# Len of new dataset is :1300
# class_index:802, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:803, Acc1 0.35846153846153844
# 1300
# Len of new dataset is :1300
# class_index:804, Acc1 0.6538461538461539
# 1300
# Len of new dataset is :1300
# class_index:805, Acc1 0.6115384615384616
# 1300
# Len of new dataset is :1300
# class_index:806, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:807, Acc1 0.4453846153846154
# 1300
# Len of new dataset is :1300
# class_index:808, Acc1 0.5653846153846154
# 1300
# Len of new dataset is :1300
# class_index:809, Acc1 0.28615384615384615
# 1045
# Len of new dataset is :1045
# class_index:810, Acc1 0.4937799043062201
# 1004
# Len of new dataset is :1004
# class_index:811, Acc1 0.48804780876494025
# 1238
# Len of new dataset is :1238
# class_index:812, Acc1 0.7221324717285945
# 1300
# Len of new dataset is :1300
# class_index:813, Acc1 0.29923076923076924
# 1300
# Len of new dataset is :1300
# class_index:814, Acc1 0.6430769230769231
# 1300
# Len of new dataset is :1300
# class_index:815, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:816, Acc1 0.6438461538461538
# 1300
# Len of new dataset is :1300
# class_index:817, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:818, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:819, Acc1 0.6461538461538462
# 1300
# Len of new dataset is :1300
# class_index:820, Acc1 0.8269230769230769
# 1153
# Len of new dataset is :1153
# class_index:821, Acc1 0.803122289679098
# 1300
# Len of new dataset is :1300
# class_index:822, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:823, Acc1 0.5838461538461538
# 1300
# Len of new dataset is :1300
# class_index:824, Acc1 0.3830769230769231
# 1300
# Len of new dataset is :1300
# class_index:825, Acc1 0.6661538461538462
# 1084
# Len of new dataset is :1084
# class_index:826, Acc1 0.6374538745387454
# 1300
# Len of new dataset is :1300
# class_index:827, Acc1 0.4153846153846154
# 1300
# Len of new dataset is :1300
# class_index:828, Acc1 0.5207692307692308
# 1300
# Len of new dataset is :1300
# class_index:829, Acc1 0.8192307692307692
# 1300
# Len of new dataset is :1300
# class_index:830, Acc1 0.46076923076923076
# 1300
# Len of new dataset is :1300
# class_index:831, Acc1 0.7230769230769231
# 1300
# Len of new dataset is :1300
# class_index:832, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:833, Acc1 0.7623076923076924
# 1300
# Len of new dataset is :1300
# class_index:834, Acc1 0.39153846153846156
# 1300
# Len of new dataset is :1300
# class_index:835, Acc1 0.8084615384615385
# 1300
# Len of new dataset is :1300
# class_index:836, Acc1 0.3769230769230769
# 1300
# Len of new dataset is :1300
# class_index:837, Acc1 0.34923076923076923
# 1217
# Len of new dataset is :1217
# class_index:838, Acc1 0.30977814297452755
# 1300
# Len of new dataset is :1300
# class_index:839, Acc1 0.7223076923076923
# 1300
# Len of new dataset is :1300
# class_index:840, Acc1 0.6676923076923077
# 931
# Len of new dataset is :931
# class_index:841, Acc1 0.59828141783029
# 1300
# Len of new dataset is :1300
# class_index:842, Acc1 0.40923076923076923
# 1300
# Len of new dataset is :1300
# class_index:843, Acc1 0.7861538461538462
# 1300
# Len of new dataset is :1300
# class_index:844, Acc1 0.6376923076923077
# 1300
# Len of new dataset is :1300
# class_index:845, Acc1 0.5415384615384615
# 1300
# Len of new dataset is :1300
# class_index:846, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:847, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:848, Acc1 0.3638461538461538
# 1300
# Len of new dataset is :1300
# class_index:849, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:850, Acc1 0.6530769230769231
# 1300
# Len of new dataset is :1300
# class_index:851, Acc1 0.48615384615384616
# 1300
# Len of new dataset is :1300
# class_index:852, Acc1 0.2569230769230769
# 1300
# Len of new dataset is :1300
# class_index:853, Acc1 0.6576923076923077
# 1264
# Len of new dataset is :1264
# class_index:854, Acc1 0.7318037974683544
# 1300
# Len of new dataset is :1300
# class_index:855, Acc1 0.7223076923076923
# 1300
# Len of new dataset is :1300
# class_index:856, Acc1 0.4169230769230769
# 976
# Len of new dataset is :976
# class_index:857, Acc1 0.5604508196721312
# 1300
# Len of new dataset is :1300
# class_index:858, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:859, Acc1 0.5430769230769231
# 1250
# Len of new dataset is :1250
# class_index:860, Acc1 0.3344
# 1300
# Len of new dataset is :1300
# class_index:861, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:862, Acc1 0.3384615384615385
# 1300
# Len of new dataset is :1300
# class_index:863, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:864, Acc1 0.4553846153846154
# 1300
# Len of new dataset is :1300
# class_index:865, Acc1 0.4946153846153846
# 1300
# Len of new dataset is :1300
# class_index:866, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:867, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:868, Acc1 0.47923076923076924
# 1053
# Len of new dataset is :1053
# class_index:869, Acc1 0.6191832858499525
# 1300
# Len of new dataset is :1300
# class_index:870, Acc1 0.6953846153846154
# 1300
# Len of new dataset is :1300
# class_index:871, Acc1 0.6953846153846154
# 1160
# Len of new dataset is :1160
# class_index:872, Acc1 0.6991379310344827
# 1300
# Len of new dataset is :1300
# class_index:873, Acc1 0.8507692307692307
# 1300
# Len of new dataset is :1300
# class_index:874, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:875, Acc1 0.5261538461538462
# 1300
# Len of new dataset is :1300
# class_index:876, Acc1 0.22384615384615383
# 1300
# Len of new dataset is :1300
# class_index:877, Acc1 0.8215384615384616
# 1300
# Len of new dataset is :1300
# class_index:878, Acc1 0.6030769230769231
# 1300
# Len of new dataset is :1300
# class_index:879, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:880, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:881, Acc1 0.7161538461538461
# 1300
# Len of new dataset is :1300
# class_index:882, Acc1 0.49923076923076926
# 1300
# Len of new dataset is :1300
# class_index:883, Acc1 0.6892307692307692
# 1300
# Len of new dataset is :1300
# class_index:884, Acc1 0.6538461538461539
# 1062
# Len of new dataset is :1062
# class_index:885, Acc1 0.3681732580037665
# 1300
# Len of new dataset is :1300
# class_index:886, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:887, Acc1 0.6376923076923077
# 1300
# Len of new dataset is :1300
# class_index:888, Acc1 0.8076923076923077
# 1300
# Len of new dataset is :1300
# class_index:889, Acc1 0.38461538461538464
# 1300
# Len of new dataset is :1300
# class_index:890, Acc1 0.46
# 1137
# Len of new dataset is :1137
# class_index:891, Acc1 0.4678979771328056
# 1299
# Len of new dataset is :1299
# class_index:892, Acc1 0.6866820631254812
# 1300
# Len of new dataset is :1300
# class_index:893, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:894, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:895, Acc1 0.6730769230769231
# 1300
# Len of new dataset is :1300
# class_index:896, Acc1 0.6476923076923077
# 1300
# Len of new dataset is :1300
# class_index:897, Acc1 0.8269230769230769
# 1300
# Len of new dataset is :1300
# class_index:898, Acc1 0.43846153846153846
# 1300
# Len of new dataset is :1300
# class_index:899, Acc1 0.3030769230769231
# 1300
# Len of new dataset is :1300
# class_index:900, Acc1 0.8807692307692307
# 1055
# Len of new dataset is :1055
# class_index:901, Acc1 0.6919431279620853
# 1300
# Len of new dataset is :1300
# class_index:902, Acc1 0.49846153846153846
# 1300
# Len of new dataset is :1300
# class_index:903, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:904, Acc1 0.6692307692307692
# 1300
# Len of new dataset is :1300
# class_index:905, Acc1 0.7023076923076923
# 1213
# Len of new dataset is :1213
# class_index:906, Acc1 0.5276174773289365
# 1300
# Len of new dataset is :1300
# class_index:907, Acc1 0.5638461538461539
# 1300
# Len of new dataset is :1300
# class_index:908, Acc1 0.5192307692307693
# 1300
# Len of new dataset is :1300
# class_index:909, Acc1 0.3192307692307692
# 1300
# Len of new dataset is :1300
# class_index:910, Acc1 0.10461538461538461
# 1300
# Len of new dataset is :1300
# class_index:911, Acc1 0.3723076923076923
# 1300
# Len of new dataset is :1300
# class_index:912, Acc1 0.4546153846153846
# 1300
# Len of new dataset is :1300
# class_index:913, Acc1 0.43
# 1206
# Len of new dataset is :1206
# class_index:914, Acc1 0.7072968490878938
# 1300
# Len of new dataset is :1300
# class_index:915, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:916, Acc1 0.9161538461538462
# 1300
# Len of new dataset is :1300
# class_index:917, Acc1 0.5115384615384615
# 1300
# Len of new dataset is :1300
# class_index:918, Acc1 0.8361538461538461
# 1300
# Len of new dataset is :1300
# class_index:919, Acc1 0.7823076923076923
# 1300
# Len of new dataset is :1300
# class_index:920, Acc1 0.7269230769230769
# 1154
# Len of new dataset is :1154
# class_index:921, Acc1 0.6299826689774697
# 1300
# Len of new dataset is :1300
# class_index:922, Acc1 0.6761538461538461
# 1300
# Len of new dataset is :1300
# class_index:923, Acc1 0.24153846153846154
# 1300
# Len of new dataset is :1300
# class_index:924, Acc1 0.038461538461538464
# 1207
# Len of new dataset is :1207
# class_index:925, Acc1 0.1499585749792875
# 1149
# Len of new dataset is :1149
# class_index:926, Acc1 0.02959094865100087
# 1300
# Len of new dataset is :1300
# class_index:927, Acc1 0.44153846153846155
# 1300
# Len of new dataset is :1300
# class_index:928, Acc1 0.4207692307692308
# 1300
# Len of new dataset is :1300
# class_index:929, Acc1 0.3792307692307692
# 1300
# Len of new dataset is :1300
# class_index:930, Acc1 0.008461538461538461
# 1300
# Len of new dataset is :1300
# class_index:931, Acc1 0.09230769230769231
# 1300
# Len of new dataset is :1300
# class_index:932, Acc1 0.2076923076923077
# 1300
# Len of new dataset is :1300
# class_index:933, Acc1 0.09615384615384616
# 1300
# Len of new dataset is :1300
# class_index:934, Acc1 0.023076923076923078
# 1300
# Len of new dataset is :1300
# class_index:935, Acc1 0.03230769230769231
# 1300
# Len of new dataset is :1300
# class_index:936, Acc1 0.65
# 1300
# Len of new dataset is :1300
# class_index:937, Acc1 0.25
# 1300
# Len of new dataset is :1300
# class_index:938, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:939, Acc1 0.19076923076923077
# 1239
# Len of new dataset is :1239
# class_index:940, Acc1 0.04439063761097659
# 1300
# Len of new dataset is :1300
# class_index:941, Acc1 0.14846153846153845
# 1300
# Len of new dataset is :1300
# class_index:942, Acc1 0.07153846153846154
# 1300
# Len of new dataset is :1300
# class_index:943, Acc1 0.11846153846153847
# 1300
# Len of new dataset is :1300
# class_index:944, Acc1 0.55
# 1300
# Len of new dataset is :1300
# class_index:945, Acc1 0.3792307692307692
# 1125
# Len of new dataset is :1125
# class_index:946, Acc1 0.9173333333333333
# 1300
# Len of new dataset is :1300
# class_index:947, Acc1 0.43
# 1300
# Len of new dataset is :1300
# class_index:948, Acc1 0.21
# 1300
# Len of new dataset is :1300
# class_index:949, Acc1 0.2169230769230769
# 1300
# Len of new dataset is :1300
# class_index:950, Acc1 0.09769230769230769
# 1300
# Len of new dataset is :1300
# class_index:951, Acc1 0.052307692307692305
# 1300
# Len of new dataset is :1300
# class_index:952, Acc1 0.3953846153846154
# 1300
# Len of new dataset is :1300
# class_index:953, Acc1 0.4423076923076923
# 1300
# Len of new dataset is :1300
# class_index:954, Acc1 0.16
# 1300
# Len of new dataset is :1300
# class_index:955, Acc1 0.23923076923076922
# 1300
# Len of new dataset is :1300
# class_index:956, Acc1 0.5030769230769231
# 1300
# Len of new dataset is :1300
# class_index:957, Acc1 0.17923076923076922
# 1300
# Len of new dataset is :1300
# class_index:958, Acc1 0.6169230769230769
# 1300
# Len of new dataset is :1300
# class_index:959, Acc1 0.14692307692307693
# 1300
# Len of new dataset is :1300
# class_index:960, Acc1 0.16153846153846155
# 1300
# Len of new dataset is :1300
# class_index:961, Acc1 0.13384615384615384
# 1300
# Len of new dataset is :1300
# class_index:962, Acc1 0.026923076923076925
# 1300
# Len of new dataset is :1300
# class_index:963, Acc1 0.0
# 1300
# Len of new dataset is :1300
# class_index:964, Acc1 0.0038461538461538464
# 1300
# Len of new dataset is :1300
# class_index:965, Acc1 0.09153846153846154
# 1300
# Len of new dataset is :1300
# class_index:966, Acc1 0.28307692307692306
# 1300
# Len of new dataset is :1300
# class_index:967, Acc1 0.09923076923076923
# 1300
# Len of new dataset is :1300
# class_index:968, Acc1 0.55
# 1193
# Len of new dataset is :1193
# class_index:969, Acc1 0.30092204526404026
# 1300
# Len of new dataset is :1300
# class_index:970, Acc1 0.3446153846153846
# 1300
# Len of new dataset is :1300
# class_index:971, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:972, Acc1 0.4823076923076923
# 1300
# Len of new dataset is :1300
# class_index:973, Acc1 0.5161538461538462
# 1300
# Len of new dataset is :1300
# class_index:974, Acc1 0.7515384615384615
# 1300
# Len of new dataset is :1300
# class_index:975, Acc1 0.5192307692307693
# 1300
# Len of new dataset is :1300
# class_index:976, Acc1 0.22846153846153847
# 1300
# Len of new dataset is :1300
# class_index:977, Acc1 0.28307692307692306
# 1300
# Len of new dataset is :1300
# class_index:978, Acc1 0.1853846153846154
# 1300
# Len of new dataset is :1300
# class_index:979, Acc1 0.5961538461538461
# 1300
# Len of new dataset is :1300
# class_index:980, Acc1 0.4153846153846154
# 1300
# Len of new dataset is :1300
# class_index:981, Acc1 0.5769230769230769
# 1300
# Len of new dataset is :1300
# class_index:982, Acc1 0.5307692307692308
# 1300
# Len of new dataset is :1300
# class_index:983, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:984, Acc1 0.12230769230769231
# 1300
# Len of new dataset is :1300
# class_index:985, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:986, Acc1 0.31153846153846154
# 1300
# Len of new dataset is :1300
# class_index:987, Acc1 0.1076923076923077
# 1300
# Len of new dataset is :1300
# class_index:988, Acc1 0.37
# 1300
# Len of new dataset is :1300
# class_index:989, Acc1 0.34076923076923077
# 1300
# Len of new dataset is :1300
# class_index:990, Acc1 0.06923076923076923
# 1300
# Len of new dataset is :1300
# class_index:991, Acc1 0.5415384615384615
# 1300
# Len of new dataset is :1300
# class_index:992, Acc1 0.4153846153846154
# 1300
# Len of new dataset is :1300
# class_index:993, Acc1 0.15384615384615385
# 1300
# Len of new dataset is :1300
# class_index:994, Acc1 0.4461538461538462
# 1300
# Len of new dataset is :1300
# class_index:995, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:996, Acc1 0.15153846153846154
# 1300
# Len of new dataset is :1300
# class_index:997, Acc1 0.3007692307692308
# 1300
# Len of new dataset is :1300
# class_index:998, Acc1 0.17
# 1300
# Len of new dataset is :1300
# class_index:999, Acc1 0.6069230769230769

# %%
gbr_gt_pred_acc = "./gbr_gt_pred_acc.pickle"
with open(gbr_gt_pred_acc, "wb") as handle:
    pickle.dump(gbr_class_y_true_y_pred_acc, handle)
print(np.mean([acc for _, _, acc in gbr_class_y_true_y_pred_acc.values()]))
# Out:
# 0.5180142796762237

# %% [markdown]
# ## Load Swap, RGB->GRB

# %%
grb_class_y_true_y_pred_acc = {}
for class_index in range(1000):
    # Load data
    train_transform = transforms.Compose([                                                                                                                                
        transforms.Resize((224, 224), interpolation=Image.BILINEAR),                                                                                              
        transforms.ToTensor(),                                                                                                                                            
        transforms.Normalize(mean, std)                                                                                                                                   
           ])         
    trainset = imagenet.ImageNet(root=root, 
                                 is_train=True, transform=train_transform)
    len_specific_category = len(trainset.targets_imgs_dict[class_index])
    print(len_specific_category)
    trainset.set_data([class_index], len_specific_category)
    trainloader = torch.utils.data.DataLoader(trainset,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              num_workers=num_workers,
                                              pin_memory=True)
    y_true, y_pred, acc = get_gt_pred_specific_class(net, 
                                                     trainloader,
                                                     order=[1,0,2],
                                                     device=device)
    print("class_index:{}, Acc1 {}".format(class_index, acc))
    grb_class_y_true_y_pred_acc[class_index] = [y_true, y_pred, acc]
# Out:
# 1300
# Len of new dataset is :1300
# class_index:0, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:1, Acc1 0.15538461538461537
# 1300
# Len of new dataset is :1300
# class_index:2, Acc1 0.4807692307692308
# 1300
# Len of new dataset is :1300
# class_index:3, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:4, Acc1 0.7346153846153847
# 1300
# Len of new dataset is :1300
# class_index:5, Acc1 0.4946153846153846
# 1300
# Len of new dataset is :1300
# class_index:6, Acc1 0.56
# 1300
# Len of new dataset is :1300
# class_index:7, Acc1 0.33384615384615385
# 1300
# Len of new dataset is :1300
# class_index:8, Acc1 0.1753846153846154
# 1300
# Len of new dataset is :1300
# class_index:9, Acc1 0.8953846153846153
# 1300
# Len of new dataset is :1300
# class_index:10, Acc1 0.3176923076923077
# 1300
# Len of new dataset is :1300
# class_index:11, Acc1 0.9
# 1300
# Len of new dataset is :1300
# class_index:12, Acc1 0.19846153846153847
# 1300
# Len of new dataset is :1300
# class_index:13, Acc1 0.7807692307692308
# 1300
# Len of new dataset is :1300
# class_index:14, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:15, Acc1 0.22538461538461538
# 1300
# Len of new dataset is :1300
# class_index:16, Acc1 0.6476923076923077
# 1300
# Len of new dataset is :1300
# class_index:17, Acc1 0.8738461538461538
# 1300
# Len of new dataset is :1300
# class_index:18, Acc1 0.86
# 1300
# Len of new dataset is :1300
# class_index:19, Acc1 0.8684615384615385
# 1300
# Len of new dataset is :1300
# class_index:20, Acc1 0.7984615384615384
# 1300
# Len of new dataset is :1300
# class_index:21, Acc1 0.44076923076923075
# 1300
# Len of new dataset is :1300
# class_index:22, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:23, Acc1 0.5438461538461539
# 1300
# Len of new dataset is :1300
# class_index:24, Acc1 0.9192307692307692
# 1300
# Len of new dataset is :1300
# class_index:25, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:26, Acc1 0.3176923076923077
# 1300
# Len of new dataset is :1300
# class_index:27, Acc1 0.05923076923076923
# 1300
# Len of new dataset is :1300
# class_index:28, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:29, Acc1 0.77
# 1300
# Len of new dataset is :1300
# class_index:30, Acc1 0.7730769230769231
# 1300
# Len of new dataset is :1300
# class_index:31, Acc1 0.7684615384615384
# 1300
# Len of new dataset is :1300
# class_index:32, Acc1 0.3638461538461538
# 1300
# Len of new dataset is :1300
# class_index:33, Acc1 0.42846153846153845
# 1300
# Len of new dataset is :1300
# class_index:34, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:35, Acc1 0.47
# 1300
# Len of new dataset is :1300
# class_index:36, Acc1 0.55
# 1300
# Len of new dataset is :1300
# class_index:37, Acc1 0.44384615384615383
# 1300
# Len of new dataset is :1300
# class_index:38, Acc1 0.4146153846153846
# 1300
# Len of new dataset is :1300
# class_index:39, Acc1 0.7253846153846154
# 1300
# Len of new dataset is :1300
# class_index:40, Acc1 0.6623076923076923
# 1300
# Len of new dataset is :1300
# class_index:41, Acc1 0.556923076923077
# 1300
# Len of new dataset is :1300
# class_index:42, Acc1 0.46307692307692305
# 1117
# Len of new dataset is :1117
# class_index:43, Acc1 0.19516562220232767
# 1300
# Len of new dataset is :1300
# class_index:44, Acc1 0.32846153846153847
# 1300
# Len of new dataset is :1300
# class_index:45, Acc1 0.5484615384615384
# 1300
# Len of new dataset is :1300
# class_index:46, Acc1 0.16384615384615384
# 1300
# Len of new dataset is :1300
# class_index:47, Acc1 0.8376923076923077
# 1300
# Len of new dataset is :1300
# class_index:48, Acc1 0.8353846153846154
# 1300
# Len of new dataset is :1300
# class_index:49, Acc1 0.6492307692307693
# 1300
# Len of new dataset is :1300
# class_index:50, Acc1 0.6415384615384615
# 1266
# Len of new dataset is :1266
# class_index:51, Acc1 0.8009478672985783
# 1300
# Len of new dataset is :1300
# class_index:52, Acc1 0.21846153846153846
# 1300
# Len of new dataset is :1300
# class_index:53, Acc1 0.4876923076923077
# 1300
# Len of new dataset is :1300
# class_index:54, Acc1 0.3569230769230769
# 1300
# Len of new dataset is :1300
# class_index:55, Acc1 0.23461538461538461
# 1300
# Len of new dataset is :1300
# class_index:56, Acc1 0.4469230769230769
# 1300
# Len of new dataset is :1300
# class_index:57, Acc1 0.7561538461538462
# 1300
# Len of new dataset is :1300
# class_index:58, Acc1 0.46692307692307694
# 1300
# Len of new dataset is :1300
# class_index:59, Acc1 0.5653846153846154
# 1300
# Len of new dataset is :1300
# class_index:60, Acc1 0.12846153846153846
# 1300
# Len of new dataset is :1300
# class_index:61, Acc1 0.40076923076923077
# 1071
# Len of new dataset is :1071
# class_index:62, Acc1 0.3828197945845005
# 1300
# Len of new dataset is :1300
# class_index:63, Acc1 0.4653846153846154
# 1300
# Len of new dataset is :1300
# class_index:64, Acc1 0.44461538461538463
# 1300
# Len of new dataset is :1300
# class_index:65, Acc1 0.5746153846153846
# 1300
# Len of new dataset is :1300
# class_index:66, Acc1 0.37846153846153846
# 1300
# Len of new dataset is :1300
# class_index:67, Acc1 0.4707692307692308
# 1300
# Len of new dataset is :1300
# class_index:68, Acc1 0.28923076923076924
# 1300
# Len of new dataset is :1300
# class_index:69, Acc1 0.7292307692307692
# 1300
# Len of new dataset is :1300
# class_index:70, Acc1 0.5684615384615385
# 1300
# Len of new dataset is :1300
# class_index:71, Acc1 0.49230769230769234
# 1300
# Len of new dataset is :1300
# class_index:72, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:73, Acc1 0.37615384615384617
# 1300
# Len of new dataset is :1300
# class_index:74, Acc1 0.2423076923076923
# 1300
# Len of new dataset is :1300
# class_index:75, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:76, Acc1 0.5523076923076923
# 1300
# Len of new dataset is :1300
# class_index:77, Acc1 0.5230769230769231
# 1300
# Len of new dataset is :1300
# class_index:78, Acc1 0.44
# 1300
# Len of new dataset is :1300
# class_index:79, Acc1 0.49846153846153846
# 1300
# Len of new dataset is :1300
# class_index:80, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:81, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:82, Acc1 0.36
# 1300
# Len of new dataset is :1300
# class_index:83, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:84, Acc1 0.86
# 1300
# Len of new dataset is :1300
# class_index:85, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:86, Acc1 0.2723076923076923
# 1300
# Len of new dataset is :1300
# class_index:87, Acc1 0.91
# 1300
# Len of new dataset is :1300
# class_index:88, Acc1 0.796923076923077
# 1300
# Len of new dataset is :1300
# class_index:89, Acc1 0.8923076923076924
# 1300
# Len of new dataset is :1300
# class_index:90, Acc1 0.74
# 1300
# Len of new dataset is :1300
# class_index:91, Acc1 0.41923076923076924
# 1300
# Len of new dataset is :1300
# class_index:92, Acc1 0.8876923076923077
# 1300
# Len of new dataset is :1300
# class_index:93, Acc1 0.47923076923076924
# 1300
# Len of new dataset is :1300
# class_index:94, Acc1 0.8184615384615385
# 1300
# Len of new dataset is :1300
# class_index:95, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:96, Acc1 0.8569230769230769
# 1300
# Len of new dataset is :1300
# class_index:97, Acc1 0.7846153846153846
# 1141
# Len of new dataset is :1141
# class_index:98, Acc1 0.5451358457493427
# 1300
# Len of new dataset is :1300
# class_index:99, Acc1 0.5792307692307692
# 1300
# Len of new dataset is :1300
# class_index:100, Acc1 0.8138461538461539
# 1300
# Len of new dataset is :1300
# class_index:101, Acc1 0.7338461538461538
# 1300
# Len of new dataset is :1300
# class_index:102, Acc1 0.6853846153846154
# 1272
# Len of new dataset is :1272
# class_index:103, Acc1 0.6768867924528302
# 1300
# Len of new dataset is :1300
# class_index:104, Acc1 0.6523076923076923
# 1300
# Len of new dataset is :1300
# class_index:105, Acc1 0.8507692307692307
# 1300
# Len of new dataset is :1300
# class_index:106, Acc1 0.713076923076923
# 1300
# Len of new dataset is :1300
# class_index:107, Acc1 0.8692307692307693
# 1300
# Len of new dataset is :1300
# class_index:108, Acc1 0.7930769230769231
# 1300
# Len of new dataset is :1300
# class_index:109, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:110, Acc1 0.6223076923076923
# 1300
# Len of new dataset is :1300
# class_index:111, Acc1 0.7415384615384616
# 1300
# Len of new dataset is :1300
# class_index:112, Acc1 0.1853846153846154
# 1300
# Len of new dataset is :1300
# class_index:113, Acc1 0.44153846153846155
# 1300
# Len of new dataset is :1300
# class_index:114, Acc1 0.4469230769230769
# 1300
# Len of new dataset is :1300
# class_index:115, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:116, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:117, Acc1 0.6723076923076923
# 1300
# Len of new dataset is :1300
# class_index:118, Acc1 0.02
# 1300
# Len of new dataset is :1300
# class_index:119, Acc1 0.12692307692307692
# 1300
# Len of new dataset is :1300
# class_index:120, Acc1 0.3376923076923077
# 1300
# Len of new dataset is :1300
# class_index:121, Acc1 0.016153846153846154
# 1300
# Len of new dataset is :1300
# class_index:122, Acc1 0.06461538461538462
# 1300
# Len of new dataset is :1300
# class_index:123, Acc1 0.4146153846153846
# 1300
# Len of new dataset is :1300
# class_index:124, Acc1 0.09615384615384616
# 1300
# Len of new dataset is :1300
# class_index:125, Acc1 0.15461538461538463
# 1300
# Len of new dataset is :1300
# class_index:126, Acc1 0.5030769230769231
# 1300
# Len of new dataset is :1300
# class_index:127, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:128, Acc1 0.7215384615384616
# 1300
# Len of new dataset is :1300
# class_index:129, Acc1 0.6084615384615385
# 1300
# Len of new dataset is :1300
# class_index:130, Acc1 0.21769230769230768
# 1300
# Len of new dataset is :1300
# class_index:131, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:132, Acc1 0.8638461538461538
# 1300
# Len of new dataset is :1300
# class_index:133, Acc1 0.5838461538461538
# 1300
# Len of new dataset is :1300
# class_index:134, Acc1 0.5792307692307692
# 1300
# Len of new dataset is :1300
# class_index:135, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:136, Acc1 0.7276923076923076
# 1300
# Len of new dataset is :1300
# class_index:137, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:138, Acc1 0.8207692307692308
# 1300
# Len of new dataset is :1300
# class_index:139, Acc1 0.4276923076923077
# 1300
# Len of new dataset is :1300
# class_index:140, Acc1 0.5253846153846153
# 1300
# Len of new dataset is :1300
# class_index:141, Acc1 0.47615384615384615
# 1300
# Len of new dataset is :1300
# class_index:142, Acc1 0.6469230769230769
# 1300
# Len of new dataset is :1300
# class_index:143, Acc1 0.5061538461538462
# 1300
# Len of new dataset is :1300
# class_index:144, Acc1 0.7053846153846154
# 1300
# Len of new dataset is :1300
# class_index:145, Acc1 0.8984615384615384
# 1300
# Len of new dataset is :1300
# class_index:146, Acc1 0.8023076923076923
# 1150
# Len of new dataset is :1150
# class_index:147, Acc1 0.688695652173913
# 1300
# Len of new dataset is :1300
# class_index:148, Acc1 0.8630769230769231
# 1300
# Len of new dataset is :1300
# class_index:149, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:150, Acc1 0.47615384615384615
# 1300
# Len of new dataset is :1300
# class_index:151, Acc1 0.5323076923076923
# 772
# Len of new dataset is :772
# class_index:152, Acc1 0.7797927461139896
# 1300
# Len of new dataset is :1300
# class_index:153, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:154, Acc1 0.6676923076923077
# 1300
# Len of new dataset is :1300
# class_index:155, Acc1 0.5769230769230769
# 1300
# Len of new dataset is :1300
# class_index:156, Acc1 0.46923076923076923
# 1300
# Len of new dataset is :1300
# class_index:157, Acc1 0.7746153846153846
# 860
# Len of new dataset is :860
# class_index:158, Acc1 0.5337209302325582
# 1300
# Len of new dataset is :1300
# class_index:159, Acc1 0.06846153846153846
# 1300
# Len of new dataset is :1300
# class_index:160, Acc1 0.676923076923077
# 1300
# Len of new dataset is :1300
# class_index:161, Acc1 0.5123076923076924
# 1300
# Len of new dataset is :1300
# class_index:162, Acc1 0.4346153846153846
# 1300
# Len of new dataset is :1300
# class_index:163, Acc1 0.3046153846153846
# 1136
# Len of new dataset is :1136
# class_index:164, Acc1 0.7165492957746479
# 732
# Len of new dataset is :732
# class_index:165, Acc1 0.31830601092896177
# 1025
# Len of new dataset is :1025
# class_index:166, Acc1 0.3678048780487805
# 754
# Len of new dataset is :754
# class_index:167, Acc1 0.10742705570291777
# 1290
# Len of new dataset is :1290
# class_index:168, Acc1 0.046511627906976744
# 1300
# Len of new dataset is :1300
# class_index:169, Acc1 0.6946153846153846
# 1300
# Len of new dataset is :1300
# class_index:170, Acc1 0.4753846153846154
# 1300
# Len of new dataset is :1300
# class_index:171, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:172, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:173, Acc1 0.11384615384615385
# 1300
# Len of new dataset is :1300
# class_index:174, Acc1 0.8307692307692308
# 738
# Len of new dataset is :738
# class_index:175, Acc1 0.1802168021680217
# 1300
# Len of new dataset is :1300
# class_index:176, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:177, Acc1 0.8138461538461539
# 1300
# Len of new dataset is :1300
# class_index:178, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:179, Acc1 0.6115384615384616
# 1300
# Len of new dataset is :1300
# class_index:180, Acc1 0.36923076923076925
# 1258
# Len of new dataset is :1258
# class_index:181, Acc1 0.8330683624801272
# 1300
# Len of new dataset is :1300
# class_index:182, Acc1 0.4453846153846154
# 1273
# Len of new dataset is :1273
# class_index:183, Acc1 0.8421052631578947
# 1300
# Len of new dataset is :1300
# class_index:184, Acc1 0.03307692307692308
# 1300
# Len of new dataset is :1300
# class_index:185, Acc1 0.10923076923076923
# 1300
# Len of new dataset is :1300
# class_index:186, Acc1 0.15461538461538463
# 1300
# Len of new dataset is :1300
# class_index:187, Acc1 0.26461538461538464
# 977
# Len of new dataset is :977
# class_index:188, Acc1 0.5475946775844421
# 1300
# Len of new dataset is :1300
# class_index:189, Acc1 0.15846153846153846
# 936
# Len of new dataset is :936
# class_index:190, Acc1 0.7617521367521367
# 1300
# Len of new dataset is :1300
# class_index:191, Acc1 0.052307692307692305
# 1300
# Len of new dataset is :1300
# class_index:192, Acc1 0.45615384615384613
# 1300
# Len of new dataset is :1300
# class_index:193, Acc1 0.15153846153846154
# 1156
# Len of new dataset is :1156
# class_index:194, Acc1 0.6738754325259516
# 1300
# Len of new dataset is :1300
# class_index:195, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:196, Acc1 0.713076923076923
# 1300
# Len of new dataset is :1300
# class_index:197, Acc1 0.6784615384615384
# 1300
# Len of new dataset is :1300
# class_index:198, Acc1 0.6084615384615385
# 1300
# Len of new dataset is :1300
# class_index:199, Acc1 0.8207692307692308
# 1300
# Len of new dataset is :1300
# class_index:200, Acc1 0.6376923076923077
# 1300
# Len of new dataset is :1300
# class_index:201, Acc1 0.13538461538461538
# 1300
# Len of new dataset is :1300
# class_index:202, Acc1 0.12846153846153846
# 1300
# Len of new dataset is :1300
# class_index:203, Acc1 0.8053846153846154
# 1300
# Len of new dataset is :1300
# class_index:204, Acc1 0.35846153846153844
# 1300
# Len of new dataset is :1300
# class_index:205, Acc1 0.7769230769230769
# 1218
# Len of new dataset is :1218
# class_index:206, Acc1 0.7906403940886699
# 1300
# Len of new dataset is :1300
# class_index:207, Acc1 0.33692307692307694
# 1300
# Len of new dataset is :1300
# class_index:208, Acc1 0.5176923076923077
# 1300
# Len of new dataset is :1300
# class_index:209, Acc1 0.17923076923076922
# 1300
# Len of new dataset is :1300
# class_index:210, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:211, Acc1 0.022307692307692306
# 1300
# Len of new dataset is :1300
# class_index:212, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:213, Acc1 0.047692307692307694
# 1300
# Len of new dataset is :1300
# class_index:214, Acc1 0.2153846153846154
# 1300
# Len of new dataset is :1300
# class_index:215, Acc1 0.05076923076923077
# 1300
# Len of new dataset is :1300
# class_index:216, Acc1 0.5515384615384615
# 1300
# Len of new dataset is :1300
# class_index:217, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:218, Acc1 0.025384615384615384
# 1300
# Len of new dataset is :1300
# class_index:219, Acc1 0.536923076923077
# 1300
# Len of new dataset is :1300
# class_index:220, Acc1 0.4015384615384615
# 969
# Len of new dataset is :969
# class_index:221, Acc1 0.3973168214654283
# 1300
# Len of new dataset is :1300
# class_index:222, Acc1 0.76
# 1300
# Len of new dataset is :1300
# class_index:223, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:224, Acc1 0.8361538461538461
# 1300
# Len of new dataset is :1300
# class_index:225, Acc1 0.2230769230769231
# 1300
# Len of new dataset is :1300
# class_index:226, Acc1 0.36615384615384616
# 1300
# Len of new dataset is :1300
# class_index:227, Acc1 0.4523076923076923
# 1300
# Len of new dataset is :1300
# class_index:228, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:229, Acc1 0.8215384615384616
# 1300
# Len of new dataset is :1300
# class_index:230, Acc1 0.40615384615384614
# 1300
# Len of new dataset is :1300
# class_index:231, Acc1 0.26153846153846155
# 1300
# Len of new dataset is :1300
# class_index:232, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:233, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:234, Acc1 0.12692307692307692
# 1300
# Len of new dataset is :1300
# class_index:235, Acc1 0.36
# 1300
# Len of new dataset is :1300
# class_index:236, Acc1 0.1476923076923077
# 1300
# Len of new dataset is :1300
# class_index:237, Acc1 0.45076923076923076
# 1300
# Len of new dataset is :1300
# class_index:238, Acc1 0.21384615384615385
# 1300
# Len of new dataset is :1300
# class_index:239, Acc1 0.1346153846153846
# 1300
# Len of new dataset is :1300
# class_index:240, Acc1 0.20692307692307693
# 1300
# Len of new dataset is :1300
# class_index:241, Acc1 0.3346153846153846
# 1300
# Len of new dataset is :1300
# class_index:242, Acc1 0.30153846153846153
# 1300
# Len of new dataset is :1300
# class_index:243, Acc1 0.48846153846153845
# 1300
# Len of new dataset is :1300
# class_index:244, Acc1 0.63
# 1300
# Len of new dataset is :1300
# class_index:245, Acc1 0.66
# 1300
# Len of new dataset is :1300
# class_index:246, Acc1 0.696923076923077
# 1300
# Len of new dataset is :1300
# class_index:247, Acc1 0.59
# 1300
# Len of new dataset is :1300
# class_index:248, Acc1 0.3007692307692308
# 1300
# Len of new dataset is :1300
# class_index:249, Acc1 0.6076923076923076
# 1300
# Len of new dataset is :1300
# class_index:250, Acc1 0.6176923076923077
# 1300
# Len of new dataset is :1300
# class_index:251, Acc1 0.8946153846153846
# 954
# Len of new dataset is :954
# class_index:252, Acc1 0.850104821802935
# 1300
# Len of new dataset is :1300
# class_index:253, Acc1 0.2023076923076923
# 1300
# Len of new dataset is :1300
# class_index:254, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:255, Acc1 0.3853846153846154
# 1300
# Len of new dataset is :1300
# class_index:256, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:257, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:258, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:259, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:260, Acc1 0.5607692307692308
# 1300
# Len of new dataset is :1300
# class_index:261, Acc1 0.8953846153846153
# 1070
# Len of new dataset is :1070
# class_index:262, Acc1 0.35887850467289717
# 1300
# Len of new dataset is :1300
# class_index:263, Acc1 0.3069230769230769
# 1300
# Len of new dataset is :1300
# class_index:264, Acc1 0.4453846153846154
# 1300
# Len of new dataset is :1300
# class_index:265, Acc1 0.5415384615384615
# 1300
# Len of new dataset is :1300
# class_index:266, Acc1 0.27615384615384614
# 1300
# Len of new dataset is :1300
# class_index:267, Acc1 0.6630769230769231
# 755
# Len of new dataset is :755
# class_index:268, Acc1 0.7509933774834437
# 1300
# Len of new dataset is :1300
# class_index:269, Acc1 0.5969230769230769
# 1300
# Len of new dataset is :1300
# class_index:270, Acc1 0.7184615384615385
# 1300
# Len of new dataset is :1300
# class_index:271, Acc1 0.2753846153846154
# 1300
# Len of new dataset is :1300
# class_index:272, Acc1 0.5361538461538462
# 1300
# Len of new dataset is :1300
# class_index:273, Acc1 0.2969230769230769
# 1300
# Len of new dataset is :1300
# class_index:274, Acc1 0.08
# 1300
# Len of new dataset is :1300
# class_index:275, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:276, Acc1 0.7115384615384616
# 1300
# Len of new dataset is :1300
# class_index:277, Acc1 0.08307692307692308
# 1300
# Len of new dataset is :1300
# class_index:278, Acc1 0.34923076923076923
# 1300
# Len of new dataset is :1300
# class_index:279, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:280, Acc1 0.6169230769230769
# 1300
# Len of new dataset is :1300
# class_index:281, Acc1 0.5946153846153847
# 1300
# Len of new dataset is :1300
# class_index:282, Acc1 0.25384615384615383
# 1300
# Len of new dataset is :1300
# class_index:283, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:284, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:285, Acc1 0.6892307692307692
# 1300
# Len of new dataset is :1300
# class_index:286, Acc1 0.6184615384615385
# 1300
# Len of new dataset is :1300
# class_index:287, Acc1 0.5046153846153846
# 1300
# Len of new dataset is :1300
# class_index:288, Acc1 0.6846153846153846
# 1300
# Len of new dataset is :1300
# class_index:289, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:290, Acc1 0.583076923076923
# 1300
# Len of new dataset is :1300
# class_index:291, Acc1 0.5884615384615385
# 1300
# Len of new dataset is :1300
# class_index:292, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:293, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:294, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:295, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:296, Acc1 0.8446153846153847
# 1300
# Len of new dataset is :1300
# class_index:297, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:298, Acc1 0.38153846153846155
# 1300
# Len of new dataset is :1300
# class_index:299, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:300, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:301, Acc1 0.3384615384615385
# 1300
# Len of new dataset is :1300
# class_index:302, Acc1 0.6938461538461539
# 1300
# Len of new dataset is :1300
# class_index:303, Acc1 0.5776923076923077
# 1300
# Len of new dataset is :1300
# class_index:304, Acc1 0.56
# 1300
# Len of new dataset is :1300
# class_index:305, Acc1 0.6469230769230769
# 1300
# Len of new dataset is :1300
# class_index:306, Acc1 0.6046153846153847
# 1300
# Len of new dataset is :1300
# class_index:307, Acc1 0.6884615384615385
# 1300
# Len of new dataset is :1300
# class_index:308, Acc1 0.7238461538461538
# 1300
# Len of new dataset is :1300
# class_index:309, Acc1 0.4307692307692308
# 1300
# Len of new dataset is :1300
# class_index:310, Acc1 0.42615384615384616
# 1300
# Len of new dataset is :1300
# class_index:311, Acc1 0.5792307692307692
# 1300
# Len of new dataset is :1300
# class_index:312, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:313, Acc1 0.6423076923076924
# 1300
# Len of new dataset is :1300
# class_index:314, Acc1 0.08923076923076922
# 1300
# Len of new dataset is :1300
# class_index:315, Acc1 0.7961538461538461
# 1300
# Len of new dataset is :1300
# class_index:316, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:317, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:318, Acc1 0.7815384615384615
# 1300
# Len of new dataset is :1300
# class_index:319, Acc1 0.6046153846153847
# 1300
# Len of new dataset is :1300
# class_index:320, Acc1 0.7161538461538461
# 1300
# Len of new dataset is :1300
# class_index:321, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:322, Acc1 0.41
# 1300
# Len of new dataset is :1300
# class_index:323, Acc1 0.8823076923076923
# 1300
# Len of new dataset is :1300
# class_index:324, Acc1 0.8676923076923077
# 1300
# Len of new dataset is :1300
# class_index:325, Acc1 0.8961538461538462
# 1300
# Len of new dataset is :1300
# class_index:326, Acc1 0.7146153846153847
# 1300
# Len of new dataset is :1300
# class_index:327, Acc1 0.36615384615384616
# 1300
# Len of new dataset is :1300
# class_index:328, Acc1 0.7323076923076923
# 1300
# Len of new dataset is :1300
# class_index:329, Acc1 0.37538461538461537
# 1300
# Len of new dataset is :1300
# class_index:330, Acc1 0.6038461538461538
# 1300
# Len of new dataset is :1300
# class_index:331, Acc1 0.5892307692307692
# 1300
# Len of new dataset is :1300
# class_index:332, Acc1 0.7923076923076923
# 1300
# Len of new dataset is :1300
# class_index:333, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:334, Acc1 0.823076923076923
# 1206
# Len of new dataset is :1206
# class_index:335, Acc1 0.42205638474295193
# 1300
# Len of new dataset is :1300
# class_index:336, Acc1 0.6653846153846154
# 1300
# Len of new dataset is :1300
# class_index:337, Acc1 0.49230769230769234
# 1300
# Len of new dataset is :1300
# class_index:338, Acc1 0.6615384615384615
# 1300
# Len of new dataset is :1300
# class_index:339, Acc1 0.2246153846153846
# 1300
# Len of new dataset is :1300
# class_index:340, Acc1 0.9546153846153846
# 1300
# Len of new dataset is :1300
# class_index:341, Acc1 0.2561538461538462
# 1300
# Len of new dataset is :1300
# class_index:342, Acc1 0.6138461538461538
# 1300
# Len of new dataset is :1300
# class_index:343, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:344, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:345, Acc1 0.3923076923076923
# 1300
# Len of new dataset is :1300
# class_index:346, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:347, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:348, Acc1 0.5053846153846154
# 1300
# Len of new dataset is :1300
# class_index:349, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:350, Acc1 0.6692307692307692
# 1300
# Len of new dataset is :1300
# class_index:351, Acc1 0.5023076923076923
# 1300
# Len of new dataset is :1300
# class_index:352, Acc1 0.3676923076923077
# 1300
# Len of new dataset is :1300
# class_index:353, Acc1 0.6761538461538461
# 1300
# Len of new dataset is :1300
# class_index:354, Acc1 0.5069230769230769
# 1300
# Len of new dataset is :1300
# class_index:355, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:356, Acc1 0.27384615384615385
# 1300
# Len of new dataset is :1300
# class_index:357, Acc1 0.3769230769230769
# 1300
# Len of new dataset is :1300
# class_index:358, Acc1 0.4346153846153846
# 1300
# Len of new dataset is :1300
# class_index:359, Acc1 0.34923076923076923
# 1300
# Len of new dataset is :1300
# class_index:360, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:361, Acc1 0.8646153846153846
# 1300
# Len of new dataset is :1300
# class_index:362, Acc1 0.8153846153846154
# 1300
# Len of new dataset is :1300
# class_index:363, Acc1 0.7476923076923077
# 1300
# Len of new dataset is :1300
# class_index:364, Acc1 0.6707692307692308
# 1300
# Len of new dataset is :1300
# class_index:365, Acc1 0.40615384615384614
# 1300
# Len of new dataset is :1300
# class_index:366, Acc1 0.8146153846153846
# 1300
# Len of new dataset is :1300
# class_index:367, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:368, Acc1 0.5846153846153846
# 1300
# Len of new dataset is :1300
# class_index:369, Acc1 0.8038461538461539
# 1300
# Len of new dataset is :1300
# class_index:370, Acc1 0.6884615384615385
# 1300
# Len of new dataset is :1300
# class_index:371, Acc1 0.3930769230769231
# 1300
# Len of new dataset is :1300
# class_index:372, Acc1 0.57
# 1300
# Len of new dataset is :1300
# class_index:373, Acc1 0.28384615384615386
# 1300
# Len of new dataset is :1300
# class_index:374, Acc1 0.6876923076923077
# 1300
# Len of new dataset is :1300
# class_index:375, Acc1 0.8115384615384615
# 1300
# Len of new dataset is :1300
# class_index:376, Acc1 0.31846153846153846
# 1300
# Len of new dataset is :1300
# class_index:377, Acc1 0.5053846153846154
# 1300
# Len of new dataset is :1300
# class_index:378, Acc1 0.3484615384615385
# 1300
# Len of new dataset is :1300
# class_index:379, Acc1 0.5538461538461539
# 1300
# Len of new dataset is :1300
# class_index:380, Acc1 0.27076923076923076
# 1300
# Len of new dataset is :1300
# class_index:381, Acc1 0.37461538461538463
# 1300
# Len of new dataset is :1300
# class_index:382, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:383, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:384, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:385, Acc1 0.5323076923076923
# 1300
# Len of new dataset is :1300
# class_index:386, Acc1 0.48538461538461536
# 1300
# Len of new dataset is :1300
# class_index:387, Acc1 0.56
# 1300
# Len of new dataset is :1300
# class_index:388, Acc1 0.9453846153846154
# 1300
# Len of new dataset is :1300
# class_index:389, Acc1 0.7369230769230769
# 1165
# Len of new dataset is :1165
# class_index:390, Acc1 0.5725321888412017
# 1300
# Len of new dataset is :1300
# class_index:391, Acc1 0.4715384615384615
# 969
# Len of new dataset is :969
# class_index:392, Acc1 0.8978328173374613
# 1300
# Len of new dataset is :1300
# class_index:393, Acc1 0.536923076923077
# 1300
# Len of new dataset is :1300
# class_index:394, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:395, Acc1 0.4869230769230769
# 1300
# Len of new dataset is :1300
# class_index:396, Acc1 0.6823076923076923
# 1300
# Len of new dataset is :1300
# class_index:397, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:398, Acc1 0.7569230769230769
# 1300
# Len of new dataset is :1300
# class_index:399, Acc1 0.7807692307692308
# 1300
# Len of new dataset is :1300
# class_index:400, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:401, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:402, Acc1 0.6546153846153846
# 1300
# Len of new dataset is :1300
# class_index:403, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:404, Acc1 0.8523076923076923
# 1300
# Len of new dataset is :1300
# class_index:405, Acc1 0.8792307692307693
# 1300
# Len of new dataset is :1300
# class_index:406, Acc1 0.6823076923076923
# 1300
# Len of new dataset is :1300
# class_index:407, Acc1 0.5230769230769231
# 1300
# Len of new dataset is :1300
# class_index:408, Acc1 0.7353846153846154
# 1292
# Len of new dataset is :1292
# class_index:409, Acc1 0.5781733746130031
# 1300
# Len of new dataset is :1300
# class_index:410, Acc1 0.6453846153846153
# 1300
# Len of new dataset is :1300
# class_index:411, Acc1 0.6915384615384615
# 1300
# Len of new dataset is :1300
# class_index:412, Acc1 0.5884615384615385
# 1300
# Len of new dataset is :1300
# class_index:413, Acc1 0.6215384615384615
# 1300
# Len of new dataset is :1300
# class_index:414, Acc1 0.7638461538461538
# 1300
# Len of new dataset is :1300
# class_index:415, Acc1 0.09384615384615384
# 1300
# Len of new dataset is :1300
# class_index:416, Acc1 0.676923076923077
# 1300
# Len of new dataset is :1300
# class_index:417, Acc1 0.8176923076923077
# 1236
# Len of new dataset is :1236
# class_index:418, Acc1 0.6043689320388349
# 1300
# Len of new dataset is :1300
# class_index:419, Acc1 0.21461538461538462
# 1300
# Len of new dataset is :1300
# class_index:420, Acc1 0.5661538461538461
# 1300
# Len of new dataset is :1300
# class_index:421, Acc1 0.5307692307692308
# 1300
# Len of new dataset is :1300
# class_index:422, Acc1 0.7261538461538461
# 1300
# Len of new dataset is :1300
# class_index:423, Acc1 0.7476923076923077
# 1300
# Len of new dataset is :1300
# class_index:424, Acc1 0.5230769230769231
# 1300
# Len of new dataset is :1300
# class_index:425, Acc1 0.8361538461538461
# 1199
# Len of new dataset is :1199
# class_index:426, Acc1 0.7489574645537949
# 1300
# Len of new dataset is :1300
# class_index:427, Acc1 0.5484615384615384
# 1300
# Len of new dataset is :1300
# class_index:428, Acc1 0.6453846153846153
# 1300
# Len of new dataset is :1300
# class_index:429, Acc1 0.5007692307692307
# 1300
# Len of new dataset is :1300
# class_index:430, Acc1 0.44846153846153847
# 1300
# Len of new dataset is :1300
# class_index:431, Acc1 0.78
# 1300
# Len of new dataset is :1300
# class_index:432, Acc1 0.43615384615384617
# 1300
# Len of new dataset is :1300
# class_index:433, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:434, Acc1 0.6976923076923077
# 1300
# Len of new dataset is :1300
# class_index:435, Acc1 0.6707692307692308
# 1300
# Len of new dataset is :1300
# class_index:436, Acc1 0.5853846153846154
# 1300
# Len of new dataset is :1300
# class_index:437, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:438, Acc1 0.76
# 1209
# Len of new dataset is :1209
# class_index:439, Acc1 0.6608767576509512
# 1300
# Len of new dataset is :1300
# class_index:440, Acc1 0.6069230769230769
# 1300
# Len of new dataset is :1300
# class_index:441, Acc1 0.44076923076923075
# 1300
# Len of new dataset is :1300
# class_index:442, Acc1 0.6138461538461538
# 1300
# Len of new dataset is :1300
# class_index:443, Acc1 0.8007692307692308
# 1300
# Len of new dataset is :1300
# class_index:444, Acc1 0.8084615384615385
# 1300
# Len of new dataset is :1300
# class_index:445, Acc1 0.3676923076923077
# 1300
# Len of new dataset is :1300
# class_index:446, Acc1 0.7438461538461538
# 1300
# Len of new dataset is :1300
# class_index:447, Acc1 0.6430769230769231
# 1300
# Len of new dataset is :1300
# class_index:448, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:449, Acc1 0.7261538461538461
# 1300
# Len of new dataset is :1300
# class_index:450, Acc1 0.7669230769230769
# 1300
# Len of new dataset is :1300
# class_index:451, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:452, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:453, Acc1 0.6423076923076924
# 1300
# Len of new dataset is :1300
# class_index:454, Acc1 0.5253846153846153
# 1300
# Len of new dataset is :1300
# class_index:455, Acc1 0.7392307692307692
# 1300
# Len of new dataset is :1300
# class_index:456, Acc1 0.5307692307692308
# 1300
# Len of new dataset is :1300
# class_index:457, Acc1 0.4592307692307692
# 1300
# Len of new dataset is :1300
# class_index:458, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:459, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:460, Acc1 0.4346153846153846
# 1300
# Len of new dataset is :1300
# class_index:461, Acc1 0.46153846153846156
# 1300
# Len of new dataset is :1300
# class_index:462, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:463, Acc1 0.5546153846153846
# 1300
# Len of new dataset is :1300
# class_index:464, Acc1 0.45153846153846156
# 1176
# Len of new dataset is :1176
# class_index:465, Acc1 0.7363945578231292
# 1300
# Len of new dataset is :1300
# class_index:466, Acc1 0.9407692307692308
# 1300
# Len of new dataset is :1300
# class_index:467, Acc1 0.013846153846153847
# 1300
# Len of new dataset is :1300
# class_index:468, Acc1 0.6215384615384615
# 1300
# Len of new dataset is :1300
# class_index:469, Acc1 0.5923076923076923
# 1300
# Len of new dataset is :1300
# class_index:470, Acc1 0.53
# 1300
# Len of new dataset is :1300
# class_index:471, Acc1 0.7984615384615384
# 1300
# Len of new dataset is :1300
# class_index:472, Acc1 0.6676923076923077
# 1300
# Len of new dataset is :1300
# class_index:473, Acc1 0.5261538461538462
# 1300
# Len of new dataset is :1300
# class_index:474, Acc1 0.7276923076923076
# 1300
# Len of new dataset is :1300
# class_index:475, Acc1 0.8792307692307693
# 1300
# Len of new dataset is :1300
# class_index:476, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:477, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:478, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:479, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:480, Acc1 0.8415384615384616
# 1186
# Len of new dataset is :1186
# class_index:481, Acc1 0.6964586846543002
# 1300
# Len of new dataset is :1300
# class_index:482, Acc1 0.40076923076923077
# 1300
# Len of new dataset is :1300
# class_index:483, Acc1 0.8453846153846154
# 1300
# Len of new dataset is :1300
# class_index:484, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:485, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:486, Acc1 0.3638461538461538
# 1300
# Len of new dataset is :1300
# class_index:487, Acc1 0.5738461538461539
# 1300
# Len of new dataset is :1300
# class_index:488, Acc1 0.4269230769230769
# 1300
# Len of new dataset is :1300
# class_index:489, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:490, Acc1 0.6015384615384616
# 1194
# Len of new dataset is :1194
# class_index:491, Acc1 0.4824120603015075
# 1300
# Len of new dataset is :1300
# class_index:492, Acc1 0.5176923076923077
# 1300
# Len of new dataset is :1300
# class_index:493, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:494, Acc1 0.5092307692307693
# 1300
# Len of new dataset is :1300
# class_index:495, Acc1 0.7346153846153847
# 1300
# Len of new dataset is :1300
# class_index:496, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:497, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:498, Acc1 0.7392307692307692
# 1067
# Len of new dataset is :1067
# class_index:499, Acc1 0.4817244611059044
# 1300
# Len of new dataset is :1300
# class_index:500, Acc1 0.40307692307692305
# 1029
# Len of new dataset is :1029
# class_index:501, Acc1 0.6073858114674441
# 1300
# Len of new dataset is :1300
# class_index:502, Acc1 0.4584615384615385
# 1154
# Len of new dataset is :1154
# class_index:503, Acc1 0.6733102253032929
# 1300
# Len of new dataset is :1300
# class_index:504, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:505, Acc1 0.5615384615384615
# 1300
# Len of new dataset is :1300
# class_index:506, Acc1 0.7046153846153846
# 1216
# Len of new dataset is :1216
# class_index:507, Acc1 0.6463815789473685
# 1300
# Len of new dataset is :1300
# class_index:508, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:509, Acc1 0.2746153846153846
# 1300
# Len of new dataset is :1300
# class_index:510, Acc1 0.7976923076923077
# 1300
# Len of new dataset is :1300
# class_index:511, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:512, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:513, Acc1 0.5123076923076924
# 1300
# Len of new dataset is :1300
# class_index:514, Acc1 0.5115384615384615
# 1300
# Len of new dataset is :1300
# class_index:515, Acc1 0.4330769230769231
# 1300
# Len of new dataset is :1300
# class_index:516, Acc1 0.40076923076923077
# 1300
# Len of new dataset is :1300
# class_index:517, Acc1 0.7292307692307692
# 1300
# Len of new dataset is :1300
# class_index:518, Acc1 0.6961538461538461
# 1300
# Len of new dataset is :1300
# class_index:519, Acc1 0.4653846153846154
# 1300
# Len of new dataset is :1300
# class_index:520, Acc1 0.8592307692307692
# 1187
# Len of new dataset is :1187
# class_index:521, Acc1 0.7472620050547599
# 1300
# Len of new dataset is :1300
# class_index:524, Acc1 0.47384615384615386
# 1300
# Len of new dataset is :1300
# class_index:525, Acc1 0.7753846153846153
# 1300
# Len of new dataset is :1300
# class_index:526, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:527, Acc1 0.676923076923077
# 1300
# Len of new dataset is :1300
# class_index:528, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:529, Acc1 0.4946153846153846
# 1300
# Len of new dataset is :1300
# class_index:530, Acc1 0.7923076923076923
# 889
# Len of new dataset is :889
# class_index:531, Acc1 0.7615298087739033
# 1300
# Len of new dataset is :1300
# class_index:532, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:533, Acc1 0.8807692307692307
# 1300
# Len of new dataset is :1300
# class_index:534, Acc1 0.68
# 1300
# Len of new dataset is :1300
# class_index:535, Acc1 0.7715384615384615
# 1211
# Len of new dataset is :1211
# class_index:536, Acc1 0.4360033030553262
# 1300
# Len of new dataset is :1300
# class_index:537, Acc1 0.7053846153846154
# 1300
# Len of new dataset is :1300
# class_index:538, Acc1 0.6030769230769231
# 1300
# Len of new dataset is :1300
# class_index:539, Acc1 0.6392307692307693
# 1300
# Len of new dataset is :1300
# class_index:540, Acc1 0.7523076923076923
# 1300
# Len of new dataset is :1300
# class_index:541, Acc1 0.41846153846153844
# 1300
# Len of new dataset is :1300
# class_index:542, Acc1 0.2815384615384615
# 1300
# Len of new dataset is :1300
# class_index:543, Acc1 0.5723076923076923
# 1300
# Len of new dataset is :1300
# class_index:544, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:545, Acc1 0.7753846153846153
# 1300
# Len of new dataset is :1300
# class_index:546, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:547, Acc1 0.8415384615384616
# 1300
# Len of new dataset is :1300
# class_index:548, Acc1 0.6861538461538461
# 1300
# Len of new dataset is :1300
# class_index:549, Acc1 0.7084615384615385
# 1136
# Len of new dataset is :1136
# class_index:550, Acc1 0.7279929577464789
# 1153
# Len of new dataset is :1153
# class_index:551, Acc1 0.45793581960104074
# 1300
# Len of new dataset is :1300
# class_index:552, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:553, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:554, Acc1 0.5715384615384616
# 1300
# Len of new dataset is :1300
# class_index:555, Acc1 0.3830769230769231
# 1300
# Len of new dataset is :1300
# class_index:556, Acc1 0.6076923076923076
# 1300
# Len of new dataset is :1300
# class_index:557, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:558, Acc1 0.31461538461538463
# 1300
# Len of new dataset is :1300
# class_index:559, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:560, Acc1 0.8153846153846154
# 1300
# Len of new dataset is :1300
# class_index:561, Acc1 0.8407692307692308
# 1300
# Len of new dataset is :1300
# class_index:562, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:563, Acc1 0.6223076923076923
# 1300
# Len of new dataset is :1300
# class_index:564, Acc1 0.7046153846153846
# 1300
# Len of new dataset is :1300
# class_index:565, Acc1 0.8684615384615385
# 1300
# Len of new dataset is :1300
# class_index:566, Acc1 0.6838461538461539
# 1222
# Len of new dataset is :1222
# class_index:567, Acc1 0.353518821603928
# 1300
# Len of new dataset is :1300
# class_index:568, Acc1 0.39153846153846156
# 1300
# Len of new dataset is :1300
# class_index:569, Acc1 0.8746153846153846
# 1300
# Len of new dataset is :1300
# class_index:570, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:571, Acc1 0.7484615384615385
# 1300
# Len of new dataset is :1300
# class_index:572, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:573, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:574, Acc1 0.8607692307692307
# 1300
# Len of new dataset is :1300
# class_index:575, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:576, Acc1 0.8769230769230769
# 1282
# Len of new dataset is :1282
# class_index:577, Acc1 0.6053042121684867
# 1300
# Len of new dataset is :1300
# class_index:578, Acc1 0.5161538461538462
# 1300
# Len of new dataset is :1300
# class_index:579, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:580, Acc1 0.8
# 1300
# Len of new dataset is :1300
# class_index:581, Acc1 0.6576923076923077
# 1300
# Len of new dataset is :1300
# class_index:582, Acc1 0.5392307692307692
# 1283
# Len of new dataset is :1283
# class_index:583, Acc1 0.7264224473889321
# 1300
# Len of new dataset is :1300
# class_index:584, Acc1 0.6169230769230769
# 980
# Len of new dataset is :980
# class_index:585, Acc1 0.373469387755102
# 1300
# Len of new dataset is :1300
# class_index:586, Acc1 0.8876923076923077
# 1300
# Len of new dataset is :1300
# class_index:587, Acc1 0.3515384615384615
# 1300
# Len of new dataset is :1300
# class_index:588, Acc1 0.5323076923076923
# 1300
# Len of new dataset is :1300
# class_index:589, Acc1 0.6615384615384615
# 1034
# Len of new dataset is :1034
# class_index:590, Acc1 0.706963249516441
# 1300
# Len of new dataset is :1300
# class_index:591, Acc1 0.6238461538461538
# 1300
# Len of new dataset is :1300
# class_index:592, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:593, Acc1 0.53
# 1300
# Len of new dataset is :1300
# class_index:594, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:595, Acc1 0.72
# 891
# Len of new dataset is :891
# class_index:596, Acc1 0.3063973063973064
# 1300
# Len of new dataset is :1300
# class_index:597, Acc1 0.69
# 1300
# Len of new dataset is :1300
# class_index:598, Acc1 0.6723076923076923
# 1300
# Len of new dataset is :1300
# class_index:599, Acc1 0.40307692307692305
# 1300
# Len of new dataset is :1300
# class_index:600, Acc1 0.4376923076923077
# 1300
# Len of new dataset is :1300
# class_index:601, Acc1 0.6438461538461538
# 1300
# Len of new dataset is :1300
# class_index:602, Acc1 0.6007692307692307
# 1300
# Len of new dataset is :1300
# class_index:603, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:604, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:605, Acc1 0.7984615384615384
# 1300
# Len of new dataset is :1300
# class_index:606, Acc1 0.6715384615384615
# 1300
# Len of new dataset is :1300
# class_index:607, Acc1 0.4869230769230769
# 1300
# Len of new dataset is :1300
# class_index:608, Acc1 0.4746153846153846
# 1300
# Len of new dataset is :1300
# class_index:609, Acc1 0.8538461538461538
# 1285
# Len of new dataset is :1285
# class_index:610, Acc1 0.6926070038910506
# 1300
# Len of new dataset is :1300
# class_index:611, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:612, Acc1 0.7523076923076923
# 1300
# Len of new dataset is :1300
# class_index:613, Acc1 0.7169230769230769
# 1300
# Len of new dataset is :1300
# class_index:614, Acc1 0.5738461538461539
# 1300
# Len of new dataset is :1300
# class_index:615, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:616, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:617, Acc1 0.7215384615384616
# 1300
# Len of new dataset is :1300
# class_index:618, Acc1 0.3823076923076923
# 1300
# Len of new dataset is :1300
# class_index:619, Acc1 0.5176923076923077
# 1300
# Len of new dataset is :1300
# class_index:620, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:621, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:622, Acc1 0.7515384615384615
# 986
# Len of new dataset is :986
# class_index:623, Acc1 0.4249492900608519
# 1300
# Len of new dataset is :1300
# class_index:624, Acc1 0.5969230769230769
# 1300
# Len of new dataset is :1300
# class_index:625, Acc1 0.11
# 1300
# Len of new dataset is :1300
# class_index:626, Acc1 0.5684615384615385
# 1300
# Len of new dataset is :1300
# class_index:627, Acc1 0.7115384615384616
# 1300
# Len of new dataset is :1300
# class_index:628, Acc1 0.8092307692307692
# 1300
# Len of new dataset is :1300
# class_index:629, Acc1 0.3769230769230769
# 1137
# Len of new dataset is :1137
# class_index:630, Acc1 0.48812664907651715
# 1272
# Len of new dataset is :1272
# class_index:631, Acc1 0.6383647798742138
# 1300
# Len of new dataset is :1300
# class_index:632, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:633, Acc1 0.5484615384615384
# 1300
# Len of new dataset is :1300
# class_index:634, Acc1 0.21461538461538462
# 1155
# Len of new dataset is :1155
# class_index:635, Acc1 0.7956709956709956
# 1300
# Len of new dataset is :1300
# class_index:636, Acc1 0.563076923076923
# 1300
# Len of new dataset is :1300
# class_index:637, Acc1 0.7169230769230769
# 1300
# Len of new dataset is :1300
# class_index:638, Acc1 0.2630769230769231
# 1300
# Len of new dataset is :1300
# class_index:639, Acc1 0.43153846153846154
# 1300
# Len of new dataset is :1300
# class_index:640, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:641, Acc1 0.47
# 1300
# Len of new dataset is :1300
# class_index:642, Acc1 0.42846153846153845
# 1300
# Len of new dataset is :1300
# class_index:643, Acc1 0.5507692307692308
# 1300
# Len of new dataset is :1300
# class_index:644, Acc1 0.41615384615384615
# 1300
# Len of new dataset is :1300
# class_index:645, Acc1 0.8653846153846154
# 1300
# Len of new dataset is :1300
# class_index:646, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:647, Acc1 0.6284615384615385
# 1300
# Len of new dataset is :1300
# class_index:648, Acc1 0.8146153846153846
# 1300
# Len of new dataset is :1300
# class_index:649, Acc1 0.8646153846153846
# 1300
# Len of new dataset is :1300
# class_index:650, Acc1 0.5646153846153846
# 1300
# Len of new dataset is :1300
# class_index:651, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:652, Acc1 0.5723076923076923
# 1097
# Len of new dataset is :1097
# class_index:653, Acc1 0.731996353691887
# 1300
# Len of new dataset is :1300
# class_index:654, Acc1 0.71
# 1300
# Len of new dataset is :1300
# class_index:655, Acc1 0.31384615384615383
# 1300
# Len of new dataset is :1300
# class_index:656, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:657, Acc1 0.6915384615384615
# 1300
# Len of new dataset is :1300
# class_index:658, Acc1 0.7653846153846153
# 1300
# Len of new dataset is :1300
# ...
#   warnings.warn(str(msg))
# class_index:782, Acc1 0.4451460142067877
# 1300
# Len of new dataset is :1300
# class_index:783, Acc1 0.6223076923076923
# 1300
# Len of new dataset is :1300
# class_index:784, Acc1 0.46307692307692305
# 1300
# Len of new dataset is :1300
# class_index:785, Acc1 0.7776923076923077
# 1300
# Len of new dataset is :1300
# class_index:786, Acc1 0.7807692307692308
# 1300
# Len of new dataset is :1300
# class_index:787, Acc1 0.5553846153846154
# 1300
# Len of new dataset is :1300
# class_index:788, Acc1 0.6530769230769231
# 1249
# Len of new dataset is :1249
# class_index:789, Acc1 0.578062449959968
# 1300
# Len of new dataset is :1300
# class_index:790, Acc1 0.7715384615384615
# 1300
# Len of new dataset is :1300
# class_index:791, Acc1 0.7407692307692307
# 1300
# Len of new dataset is :1300
# class_index:792, Acc1 0.49615384615384617
# 1300
# Len of new dataset is :1300
# class_index:793, Acc1 0.6761538461538461
# 1300
# Len of new dataset is :1300
# class_index:794, Acc1 0.7830769230769231
# 1300
# Len of new dataset is :1300
# class_index:795, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:796, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:797, Acc1 0.7253846153846154
# 1162
# Len of new dataset is :1162
# class_index:798, Acc1 0.8614457831325302
# 1300
# Len of new dataset is :1300
# class_index:799, Acc1 0.6392307692307693
# 1300
# Len of new dataset is :1300
# class_index:800, Acc1 0.8546153846153847
# 1300
# Len of new dataset is :1300
# class_index:801, Acc1 0.5076923076923077
# 1300
# Len of new dataset is :1300
# class_index:802, Acc1 0.8930769230769231
# 1300
# Len of new dataset is :1300
# class_index:803, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:804, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:805, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:806, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:807, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:808, Acc1 0.5507692307692308
# 1300
# Len of new dataset is :1300
# class_index:809, Acc1 0.5330769230769231
# 1045
# Len of new dataset is :1045
# class_index:810, Acc1 0.5100478468899522
# 1004
# Len of new dataset is :1004
# class_index:811, Acc1 0.5278884462151394
# 1238
# Len of new dataset is :1238
# class_index:812, Acc1 0.7649434571890146
# 1300
# Len of new dataset is :1300
# class_index:813, Acc1 0.3223076923076923
# 1300
# Len of new dataset is :1300
# class_index:814, Acc1 0.7530769230769231
# 1300
# Len of new dataset is :1300
# class_index:815, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:816, Acc1 0.57
# 1300
# Len of new dataset is :1300
# class_index:817, Acc1 0.5538461538461539
# 1300
# Len of new dataset is :1300
# class_index:818, Acc1 0.5976923076923077
# 1300
# Len of new dataset is :1300
# class_index:819, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:820, Acc1 0.9323076923076923
# 1153
# Len of new dataset is :1153
# class_index:821, Acc1 0.8950563746747615
# 1300
# Len of new dataset is :1300
# class_index:822, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:823, Acc1 0.6392307692307693
# 1300
# Len of new dataset is :1300
# class_index:824, Acc1 0.4076923076923077
# 1300
# Len of new dataset is :1300
# class_index:825, Acc1 0.8284615384615385
# 1084
# Len of new dataset is :1084
# class_index:826, Acc1 0.6559040590405905
# 1300
# Len of new dataset is :1300
# class_index:827, Acc1 0.4530769230769231
# 1300
# Len of new dataset is :1300
# class_index:828, Acc1 0.5515384615384615
# 1300
# Len of new dataset is :1300
# class_index:829, Acc1 0.8707692307692307
# 1300
# Len of new dataset is :1300
# class_index:830, Acc1 0.5438461538461539
# 1300
# Len of new dataset is :1300
# class_index:831, Acc1 0.6884615384615385
# 1300
# Len of new dataset is :1300
# class_index:832, Acc1 0.8530769230769231
# 1300
# Len of new dataset is :1300
# class_index:833, Acc1 0.83
# 1300
# Len of new dataset is :1300
# class_index:834, Acc1 0.4946153846153846
# 1300
# Len of new dataset is :1300
# class_index:835, Acc1 0.8292307692307692
# 1300
# Len of new dataset is :1300
# class_index:836, Acc1 0.39
# 1300
# Len of new dataset is :1300
# class_index:837, Acc1 0.3569230769230769
# 1217
# Len of new dataset is :1217
# class_index:838, Acc1 0.3656532456861134
# 1300
# Len of new dataset is :1300
# class_index:839, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:840, Acc1 0.686923076923077
# 931
# Len of new dataset is :931
# class_index:841, Acc1 0.5810955961331902
# 1300
# Len of new dataset is :1300
# class_index:842, Acc1 0.4553846153846154
# 1300
# Len of new dataset is :1300
# class_index:843, Acc1 0.7776923076923077
# 1300
# Len of new dataset is :1300
# class_index:844, Acc1 0.6369230769230769
# 1300
# Len of new dataset is :1300
# class_index:845, Acc1 0.556923076923077
# 1300
# Len of new dataset is :1300
# class_index:846, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:847, Acc1 0.8353846153846154
# 1300
# Len of new dataset is :1300
# class_index:848, Acc1 0.41384615384615386
# 1300
# Len of new dataset is :1300
# class_index:849, Acc1 0.7146153846153847
# 1300
# Len of new dataset is :1300
# class_index:850, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:851, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:852, Acc1 0.6084615384615385
# 1300
# Len of new dataset is :1300
# class_index:853, Acc1 0.7115384615384616
# 1264
# Len of new dataset is :1264
# class_index:854, Acc1 0.7041139240506329
# 1300
# Len of new dataset is :1300
# class_index:855, Acc1 0.73
# 1300
# Len of new dataset is :1300
# class_index:856, Acc1 0.5492307692307692
# 976
# Len of new dataset is :976
# class_index:857, Acc1 0.3831967213114754
# 1300
# Len of new dataset is :1300
# class_index:858, Acc1 0.5507692307692308
# 1300
# Len of new dataset is :1300
# class_index:859, Acc1 0.5938461538461538
# 1250
# Len of new dataset is :1250
# class_index:860, Acc1 0.376
# 1300
# Len of new dataset is :1300
# class_index:861, Acc1 0.7530769230769231
# 1300
# Len of new dataset is :1300
# class_index:862, Acc1 0.28846153846153844
# 1300
# Len of new dataset is :1300
# class_index:863, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:864, Acc1 0.46
# 1300
# Len of new dataset is :1300
# class_index:865, Acc1 0.4376923076923077
# 1300
# Len of new dataset is :1300
# class_index:866, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:867, Acc1 0.6507692307692308
# 1300
# Len of new dataset is :1300
# class_index:868, Acc1 0.48846153846153845
# 1053
# Len of new dataset is :1053
# class_index:869, Acc1 0.6381766381766382
# 1300
# Len of new dataset is :1300
# class_index:870, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:871, Acc1 0.7223076923076923
# 1160
# Len of new dataset is :1160
# class_index:872, Acc1 0.8112068965517242
# 1300
# Len of new dataset is :1300
# class_index:873, Acc1 0.8661538461538462
# 1300
# Len of new dataset is :1300
# class_index:874, Acc1 0.8784615384615385
# 1300
# Len of new dataset is :1300
# class_index:875, Acc1 0.5684615384615385
# 1300
# Len of new dataset is :1300
# class_index:876, Acc1 0.23153846153846153
# 1300
# Len of new dataset is :1300
# class_index:877, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:878, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:879, Acc1 0.69
# 1300
# Len of new dataset is :1300
# class_index:880, Acc1 0.7084615384615385
# 1300
# Len of new dataset is :1300
# class_index:881, Acc1 0.703076923076923
# 1300
# Len of new dataset is :1300
# class_index:882, Acc1 0.6176923076923077
# 1300
# Len of new dataset is :1300
# class_index:883, Acc1 0.7007692307692308
# 1300
# Len of new dataset is :1300
# class_index:884, Acc1 0.6415384615384615
# 1062
# Len of new dataset is :1062
# class_index:885, Acc1 0.3606403013182674
# 1300
# Len of new dataset is :1300
# class_index:886, Acc1 0.8630769230769231
# 1300
# Len of new dataset is :1300
# class_index:887, Acc1 0.6438461538461538
# 1300
# Len of new dataset is :1300
# class_index:888, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:889, Acc1 0.2915384615384615
# 1300
# Len of new dataset is :1300
# class_index:890, Acc1 0.6330769230769231
# 1137
# Len of new dataset is :1137
# class_index:891, Acc1 0.55584872471416
# 1299
# Len of new dataset is :1299
# class_index:892, Acc1 0.7090069284064665
# 1300
# Len of new dataset is :1300
# class_index:893, Acc1 0.63
# 1300
# Len of new dataset is :1300
# class_index:894, Acc1 0.6561538461538462
# 1300
# Len of new dataset is :1300
# class_index:895, Acc1 0.7515384615384615
# 1300
# Len of new dataset is :1300
# class_index:896, Acc1 0.6730769230769231
# 1300
# Len of new dataset is :1300
# class_index:897, Acc1 0.8523076923076923
# 1300
# Len of new dataset is :1300
# class_index:898, Acc1 0.5130769230769231
# 1300
# Len of new dataset is :1300
# class_index:899, Acc1 0.3130769230769231
# 1300
# Len of new dataset is :1300
# class_index:900, Acc1 0.9146153846153846
# 1055
# Len of new dataset is :1055
# class_index:901, Acc1 0.7090047393364929
# 1300
# Len of new dataset is :1300
# class_index:902, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:903, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:904, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:905, Acc1 0.7246153846153847
# 1213
# Len of new dataset is :1213
# class_index:906, Acc1 0.5325638911788954
# 1300
# Len of new dataset is :1300
# class_index:907, Acc1 0.6838461538461539
# 1300
# Len of new dataset is :1300
# class_index:908, Acc1 0.6946153846153846
# 1300
# Len of new dataset is :1300
# class_index:909, Acc1 0.51
# 1300
# Len of new dataset is :1300
# class_index:910, Acc1 0.07538461538461538
# 1300
# Len of new dataset is :1300
# class_index:911, Acc1 0.3853846153846154
# 1300
# Len of new dataset is :1300
# class_index:912, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:913, Acc1 0.5192307692307693
# 1206
# Len of new dataset is :1206
# class_index:914, Acc1 0.703150912106136
# 1300
# Len of new dataset is :1300
# class_index:915, Acc1 0.7938461538461539
# 1300
# Len of new dataset is :1300
# class_index:916, Acc1 0.9215384615384615
# 1300
# Len of new dataset is :1300
# class_index:917, Acc1 0.6384615384615384
# 1300
# Len of new dataset is :1300
# class_index:918, Acc1 0.8453846153846154
# 1300
# Len of new dataset is :1300
# class_index:919, Acc1 0.8076923076923077
# 1300
# Len of new dataset is :1300
# class_index:920, Acc1 0.8146153846153846
# 1154
# Len of new dataset is :1154
# class_index:921, Acc1 0.6334488734835355
# 1300
# Len of new dataset is :1300
# class_index:922, Acc1 0.7369230769230769
# 1300
# Len of new dataset is :1300
# class_index:923, Acc1 0.36846153846153845
# 1300
# Len of new dataset is :1300
# class_index:924, Acc1 0.7323076923076923
# 1207
# Len of new dataset is :1207
# class_index:925, Acc1 0.40513670256835127
# 1149
# Len of new dataset is :1149
# class_index:926, Acc1 0.18798955613577023
# 1300
# Len of new dataset is :1300
# class_index:927, Acc1 0.3630769230769231
# 1300
# Len of new dataset is :1300
# class_index:928, Acc1 0.34615384615384615
# 1300
# Len of new dataset is :1300
# class_index:929, Acc1 0.3946153846153846
# 1300
# Len of new dataset is :1300
# class_index:930, Acc1 0.0015384615384615385
# 1300
# Len of new dataset is :1300
# class_index:931, Acc1 0.04384615384615385
# 1300
# Len of new dataset is :1300
# class_index:932, Acc1 0.055384615384615386
# 1300
# Len of new dataset is :1300
# class_index:933, Acc1 0.17461538461538462
# 1300
# Len of new dataset is :1300
# class_index:934, Acc1 0.07461538461538461
# 1300
# Len of new dataset is :1300
# class_index:935, Acc1 0.30923076923076925
# 1300
# Len of new dataset is :1300
# class_index:936, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:937, Acc1 0.5353846153846153
# 1300
# Len of new dataset is :1300
# class_index:938, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:939, Acc1 0.26615384615384613
# 1239
# Len of new dataset is :1239
# class_index:940, Acc1 0.1937046004842615
# 1300
# Len of new dataset is :1300
# class_index:941, Acc1 0.2469230769230769
# 1300
# Len of new dataset is :1300
# class_index:942, Acc1 0.15076923076923077
# 1300
# Len of new dataset is :1300
# class_index:943, Acc1 0.21
# 1300
# Len of new dataset is :1300
# class_index:944, Acc1 0.7553846153846154
# 1300
# Len of new dataset is :1300
# class_index:945, Acc1 0.6492307692307693
# 1125
# Len of new dataset is :1125
# class_index:946, Acc1 0.8657777777777778
# 1300
# Len of new dataset is :1300
# class_index:947, Acc1 0.41384615384615386
# 1300
# Len of new dataset is :1300
# class_index:948, Acc1 0.48538461538461536
# 1300
# Len of new dataset is :1300
# class_index:949, Acc1 0.38769230769230767
# 1300
# Len of new dataset is :1300
# class_index:950, Acc1 0.011538461538461539
# 1300
# Len of new dataset is :1300
# class_index:951, Acc1 0.573076923076923
# 1300
# Len of new dataset is :1300
# class_index:952, Acc1 0.44153846153846155
# 1300
# Len of new dataset is :1300
# class_index:953, Acc1 0.693076923076923
# 1300
# Len of new dataset is :1300
# class_index:954, Acc1 0.6630769230769231
# 1300
# Len of new dataset is :1300
# class_index:955, Acc1 0.8146153846153846
# 1300
# Len of new dataset is :1300
# class_index:956, Acc1 0.7369230769230769
# 1300
# Len of new dataset is :1300
# class_index:957, Acc1 0.052307692307692305
# 1300
# Len of new dataset is :1300
# class_index:958, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:959, Acc1 0.2423076923076923
# 1300
# Len of new dataset is :1300
# class_index:960, Acc1 0.09846153846153846
# 1300
# Len of new dataset is :1300
# class_index:961, Acc1 0.2376923076923077
# 1300
# Len of new dataset is :1300
# class_index:962, Acc1 0.019230769230769232
# 1300
# Len of new dataset is :1300
# class_index:963, Acc1 0.010769230769230769
# 1300
# Len of new dataset is :1300
# class_index:964, Acc1 0.005384615384615384
# 1300
# Len of new dataset is :1300
# class_index:965, Acc1 0.18615384615384614
# 1300
# Len of new dataset is :1300
# class_index:966, Acc1 0.2815384615384615
# 1300
# Len of new dataset is :1300
# class_index:967, Acc1 0.038461538461538464
# 1300
# Len of new dataset is :1300
# class_index:968, Acc1 0.5392307692307692
# 1193
# Len of new dataset is :1193
# class_index:969, Acc1 0.40318524727577537
# 1300
# Len of new dataset is :1300
# class_index:970, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:971, Acc1 0.7484615384615385
# 1300
# Len of new dataset is :1300
# class_index:972, Acc1 0.6223076923076923
# 1300
# Len of new dataset is :1300
# class_index:973, Acc1 0.6507692307692308
# 1300
# Len of new dataset is :1300
# class_index:974, Acc1 0.9123076923076923
# 1300
# Len of new dataset is :1300
# class_index:975, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:976, Acc1 0.45076923076923076
# 1300
# Len of new dataset is :1300
# class_index:977, Acc1 0.36538461538461536
# 1300
# Len of new dataset is :1300
# class_index:978, Acc1 0.45692307692307693
# 1300
# Len of new dataset is :1300
# class_index:979, Acc1 0.693076923076923
# 1300
# Len of new dataset is :1300
# class_index:980, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:981, Acc1 0.6876923076923077
# 1300
# Len of new dataset is :1300
# class_index:982, Acc1 0.6561538461538462
# 1300
# Len of new dataset is :1300
# class_index:983, Acc1 0.7261538461538461
# 1300
# Len of new dataset is :1300
# class_index:984, Acc1 0.9346153846153846
# 1300
# Len of new dataset is :1300
# class_index:985, Acc1 0.9023076923076923
# 1300
# Len of new dataset is :1300
# class_index:986, Acc1 0.8792307692307693
# 1300
# Len of new dataset is :1300
# class_index:987, Acc1 0.10846153846153846
# 1300
# Len of new dataset is :1300
# class_index:988, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:989, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:990, Acc1 0.18692307692307691
# 1300
# Len of new dataset is :1300
# class_index:991, Acc1 0.6576923076923077
# 1300
# Len of new dataset is :1300
# class_index:992, Acc1 0.3769230769230769
# 1300
# Len of new dataset is :1300
# class_index:993, Acc1 0.10923076923076923
# 1300
# Len of new dataset is :1300
# class_index:994, Acc1 0.46384615384615385
# 1300
# Len of new dataset is :1300
# class_index:995, Acc1 0.5615384615384615
# 1300
# Len of new dataset is :1300
# class_index:996, Acc1 0.1
# 1300
# Len of new dataset is :1300
# class_index:997, Acc1 0.31461538461538463
# 1300
# Len of new dataset is :1300
# class_index:998, Acc1 0.5123076923076924
# 1300
# Len of new dataset is :1300
# class_index:999, Acc1 0.5976923076923077

# %%
grb_gt_pred_acc = "./grb_gt_pred_acc.pickle"
with open(grb_gt_pred_acc, "wb") as handle:
    pickle.dump(grb_class_y_true_y_pred_acc, handle)
print(np.mean([acc for _, _, acc in grb_class_y_true_y_pred_acc.values()]))
# Out:
# 0.5906631561170281
