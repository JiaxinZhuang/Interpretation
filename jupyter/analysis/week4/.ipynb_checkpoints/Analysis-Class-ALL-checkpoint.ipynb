# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Import module

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torch
import os
import sys
from torchsummary import summary
from torchvision import transforms                                                                                                                                        
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.metrics import accuracy_score
mpl.rcParams['figure.dpi'] = 600
from PIL import Image
import pickle

import sys
sys.path.append("../../../src/")
sys.path.append("../..")
import model
from datasets import imagenet
import config
from aux.utils import obtain_features_map, load_imgs, zscore, extract_valid
from aux.visualization import visualize_features_map
from utils.function import recreate_image

# %% [markdown]
# ## Hyperparameter

# %%
resume = "037-0"
model_dir = "/home/lincolnzjx/Desktop/Interpretation/saved/models"
generated_dir = "/home/lincolnzjx/Desktop/saved/generated/"
backbone = "vgg16"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Load modal from dict

# %%
# model
net = model.Network(backbone=backbone, num_classes=1000)
net.to(device)

# resume from model
resume_exp = resume.split("-")[0]
resume_epoch = resume.split("-")[1]
print("Resume from model from exp: {} at epoch {}".format(resume_exp, resume_epoch))
resume_path = os.path.join(model_dir, str(resume_exp), str(resume_epoch))
ckpt = torch.load(resume_path, map_location=device)
net.load_state_dict(ckpt) 

# Class & data
batch_size = 256
num_workers = 4
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
reverse_mean = [-0.485, -0.456, -0.406]
reverse_std = [1/0.229, 1/0.224, 1/0.225]
# Out:
# > Use original fc
# Resume from model from exp: 037 at epoch 0

# %% [markdown]
# ## Load Original Data

# %% [markdown]
# ### Get ALL category all images

# %%
def get_gt_pred_specific_class(trainloader):
    y_true = []
    y_pred = []
    net.eval()
    with torch.no_grad():
        for index, (data, target, *_) in enumerate(trainloader):
            data = data.to(device)
            predict = torch.argmax(net(data), dim=1).cpu().data.numpy()
            y_pred.extend(predict)
            target = target.cpu().data.numpy()
            y_true.extend(target)
    acc = accuracy_score(y_true, y_pred)
    del data
    return y_true, y_pred, acc

# %%
class_y_true_y_pred_acc = {}
for class_index in range(1000):
    # Load data
    train_transform = transforms.Compose([                                                                                                                                
        transforms.Resize((224, 224), interpolation=Image.BILINEAR),                                                                                              
        transforms.ToTensor(),                                                                                                                                            
        transforms.Normalize(mean, std)                                                                                                                                   
           ])         
    trainset = imagenet.ImageNet(root="/media/lincolnzjx/HardDisk/Datasets/", 
                                 is_train=True, transform=train_transform)
    len_specific_category = len(trainset.targets_imgs_dict[class_index])
    print(len_specific_category)
    trainset.set_data([class_index], len_specific_category)
    trainloader = torch.utils.data.DataLoader(trainset,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              num_workers=num_workers,
                                              pin_memory=True)
    y_true, y_pred, acc = get_gt_pred_specific_class(trainloader)
    print("class_index:{}, Acc1 {}".format(class_index, acc))
    class_y_true_y_pred_acc[class_index] = [y_true, y_pred, acc]
# Out:
# 1300
# Len of new dataset is :1300
# class_index:0, Acc1 0.9392307692307692
# 1300
# Len of new dataset is :1300
# class_index:1, Acc1 0.9515384615384616
# 1300
# Len of new dataset is :1300
# class_index:2, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:3, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:4, Acc1 0.8623076923076923
# 1300
# Len of new dataset is :1300
# class_index:5, Acc1 0.7415384615384616
# 1300
# Len of new dataset is :1300
# class_index:6, Acc1 0.8430769230769231
# 1300
# Len of new dataset is :1300
# class_index:7, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:8, Acc1 0.8430769230769231
# 1300
# Len of new dataset is :1300
# class_index:9, Acc1 0.9723076923076923
# 1300
# Len of new dataset is :1300
# class_index:10, Acc1 0.9253846153846154
# 1300
# Len of new dataset is :1300
# class_index:11, Acc1 0.9776923076923076
# 1300
# Len of new dataset is :1300
# class_index:12, Acc1 0.946923076923077
# 1300
# Len of new dataset is :1300
# class_index:13, Acc1 0.9315384615384615
# 1300
# Len of new dataset is :1300
# class_index:14, Acc1 0.9692307692307692
# 1300
# Len of new dataset is :1300
# class_index:15, Acc1 0.9546153846153846
# 1300
# Len of new dataset is :1300
# class_index:16, Acc1 0.9284615384615384
# 1300
# Len of new dataset is :1300
# class_index:17, Acc1 0.9423076923076923
# 1300
# Len of new dataset is :1300
# class_index:18, Acc1 0.9176923076923077
# 1300
# Len of new dataset is :1300
# class_index:19, Acc1 0.9461538461538461
# 1300
# Len of new dataset is :1300
# class_index:20, Acc1 0.93
# 1300
# Len of new dataset is :1300
# class_index:21, Acc1 0.8523076923076923
# 1300
# Len of new dataset is :1300
# class_index:22, Acc1 0.9146153846153846
# 1300
# Len of new dataset is :1300
# class_index:23, Acc1 0.8523076923076923
# 1300
# Len of new dataset is :1300
# class_index:24, Acc1 0.9684615384615385
# 1300
# Len of new dataset is :1300
# class_index:25, Acc1 0.9230769230769231
# 1300
# Len of new dataset is :1300
# class_index:26, Acc1 0.6792307692307692
# 1300
# Len of new dataset is :1300
# class_index:27, Acc1 0.8930769230769231
# 1300
# Len of new dataset is :1300
# class_index:28, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:29, Acc1 0.9261538461538461
# 1300
# Len of new dataset is :1300
# class_index:30, Acc1 0.89
# 1300
# Len of new dataset is :1300
# class_index:31, Acc1 0.8953846153846153
# 1300
# Len of new dataset is :1300
# class_index:32, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:33, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:34, Acc1 0.796923076923077
# 1300
# Len of new dataset is :1300
# class_index:35, Acc1 0.7353846153846154
# 1300
# Len of new dataset is :1300
# class_index:36, Acc1 0.6461538461538462
# 1300
# Len of new dataset is :1300
# class_index:37, Acc1 0.8907692307692308
# 1300
# Len of new dataset is :1300
# class_index:38, Acc1 0.823076923076923
# 1300
# Len of new dataset is :1300
# class_index:39, Acc1 0.86
# 1300
# Len of new dataset is :1300
# class_index:40, Acc1 0.6976923076923077
# 1300
# Len of new dataset is :1300
# class_index:41, Acc1 0.7946153846153846
# 1300
# Len of new dataset is :1300
# class_index:42, Acc1 0.8638461538461538
# 1117
# Len of new dataset is :1117
# class_index:43, Acc1 0.8594449418084154
# 1300
# Len of new dataset is :1300
# class_index:44, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:45, Acc1 0.9453846153846154
# 1300
# Len of new dataset is :1300
# class_index:46, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:47, Acc1 0.8830769230769231
# 1300
# Len of new dataset is :1300
# class_index:48, Acc1 0.936923076923077
# 1300
# Len of new dataset is :1300
# class_index:49, Acc1 0.8107692307692308
# 1300
# Len of new dataset is :1300
# class_index:50, Acc1 0.8715384615384615
# 1266
# Len of new dataset is :1266
# class_index:51, Acc1 0.95260663507109
# 1300
# Len of new dataset is :1300
# class_index:52, Acc1 0.7469230769230769
# 1300
# Len of new dataset is :1300
# class_index:53, Acc1 0.8376923076923077
# 1300
# Len of new dataset is :1300
# class_index:54, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:55, Acc1 0.7515384615384615
# 1300
# Len of new dataset is :1300
# class_index:56, Acc1 0.86
# 1300
# Len of new dataset is :1300
# class_index:57, Acc1 0.9238461538461539
# 1300
# Len of new dataset is :1300
# class_index:58, Acc1 0.7838461538461539
# 1300
# Len of new dataset is :1300
# class_index:59, Acc1 0.74
# 1300
# Len of new dataset is :1300
# class_index:60, Acc1 0.40692307692307694
# 1300
# Len of new dataset is :1300
# class_index:61, Acc1 0.8523076923076923
# 1071
# Len of new dataset is :1071
# class_index:62, Acc1 0.6349206349206349
# 1300
# Len of new dataset is :1300
# class_index:63, Acc1 0.8569230769230769
# 1300
# Len of new dataset is :1300
# class_index:64, Acc1 0.7915384615384615
# 1300
# Len of new dataset is :1300
# class_index:65, Acc1 0.7830769230769231
# 1300
# Len of new dataset is :1300
# class_index:66, Acc1 0.553076923076923
# 1300
# Len of new dataset is :1300
# class_index:67, Acc1 0.8076923076923077
# 1300
# Len of new dataset is :1300
# class_index:68, Acc1 0.4753846153846154
# 1300
# Len of new dataset is :1300
# class_index:69, Acc1 0.9523076923076923
# 1300
# Len of new dataset is :1300
# class_index:70, Acc1 0.9030769230769231
# 1300
# Len of new dataset is :1300
# class_index:71, Acc1 0.8776923076923077
# 1300
# Len of new dataset is :1300
# class_index:72, Acc1 0.9061538461538462
# 1300
# Len of new dataset is :1300
# class_index:73, Acc1 0.556923076923077
# 1300
# Len of new dataset is :1300
# class_index:74, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:75, Acc1 0.9284615384615384
# 1300
# Len of new dataset is :1300
# class_index:76, Acc1 0.89
# 1300
# Len of new dataset is :1300
# class_index:77, Acc1 0.8153846153846154
# 1300
# Len of new dataset is :1300
# class_index:78, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:79, Acc1 0.8838461538461538
# 1300
# Len of new dataset is :1300
# class_index:80, Acc1 0.8923076923076924
# 1300
# Len of new dataset is :1300
# class_index:81, Acc1 0.9415384615384615
# 1300
# Len of new dataset is :1300
# class_index:82, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:83, Acc1 0.9
# 1300
# Len of new dataset is :1300
# class_index:84, Acc1 0.9661538461538461
# 1300
# Len of new dataset is :1300
# class_index:85, Acc1 0.8761538461538462
# 1300
# Len of new dataset is :1300
# class_index:86, Acc1 0.7646153846153846
# 1300
# Len of new dataset is :1300
# class_index:87, Acc1 0.9692307692307692
# 1300
# Len of new dataset is :1300
# class_index:88, Acc1 0.9546153846153846
# 1300
# Len of new dataset is :1300
# class_index:89, Acc1 0.963076923076923
# 1300
# Len of new dataset is :1300
# class_index:90, Acc1 0.9753846153846154
# 1300
# Len of new dataset is :1300
# class_index:91, Acc1 0.9284615384615384
# 1300
# Len of new dataset is :1300
# class_index:92, Acc1 0.95
# 1300
# Len of new dataset is :1300
# class_index:93, Acc1 0.9276923076923077
# 1300
# Len of new dataset is :1300
# class_index:94, Acc1 0.9130769230769231
# 1300
# Len of new dataset is :1300
# class_index:95, Acc1 0.9546153846153846
# 1300
# Len of new dataset is :1300
# class_index:96, Acc1 0.9523076923076923
# 1300
# Len of new dataset is :1300
# class_index:97, Acc1 0.9446153846153846
# 1141
# Len of new dataset is :1141
# class_index:98, Acc1 0.9035933391761612
# 1300
# Len of new dataset is :1300
# class_index:99, Acc1 0.8884615384615384
# 1300
# Len of new dataset is :1300
# class_index:100, Acc1 0.9753846153846154
# 1300
# Len of new dataset is :1300
# class_index:101, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:102, Acc1 0.9638461538461538
# 1272
# Len of new dataset is :1272
# class_index:103, Acc1 0.889937106918239
# 1300
# Len of new dataset is :1300
# class_index:104, Acc1 0.8838461538461538
# 1300
# Len of new dataset is :1300
# class_index:105, Acc1 0.9653846153846154
# 1300
# Len of new dataset is :1300
# class_index:106, Acc1 0.9053846153846153
# 1300
# Len of new dataset is :1300
# class_index:107, Acc1 0.9484615384615385
# 1300
# Len of new dataset is :1300
# class_index:108, Acc1 0.7961538461538461
# 1300
# Len of new dataset is :1300
# class_index:109, Acc1 0.8823076923076923
# 1300
# Len of new dataset is :1300
# class_index:110, Acc1 0.8038461538461539
# 1300
# Len of new dataset is :1300
# class_index:111, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:112, Acc1 0.7569230769230769
# 1300
# Len of new dataset is :1300
# class_index:113, Acc1 0.8276923076923077
# 1300
# Len of new dataset is :1300
# class_index:114, Acc1 0.8446153846153847
# 1300
# Len of new dataset is :1300
# class_index:115, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:116, Acc1 0.89
# 1300
# Len of new dataset is :1300
# class_index:117, Acc1 0.9461538461538461
# 1300
# Len of new dataset is :1300
# class_index:118, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:119, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:120, Acc1 0.8907692307692308
# 1300
# Len of new dataset is :1300
# class_index:121, Acc1 0.7884615384615384
# 1300
# Len of new dataset is :1300
# class_index:122, Acc1 0.8346153846153846
# 1300
# Len of new dataset is :1300
# class_index:123, Acc1 0.8507692307692307
# 1300
# Len of new dataset is :1300
# class_index:124, Acc1 0.6915384615384615
# 1300
# Len of new dataset is :1300
# class_index:125, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:126, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:127, Acc1 0.9007692307692308
# 1300
# Len of new dataset is :1300
# class_index:128, Acc1 0.8907692307692308
# 1300
# Len of new dataset is :1300
# class_index:129, Acc1 0.9407692307692308
# 1300
# Len of new dataset is :1300
# class_index:130, Acc1 0.9838461538461538
# 1300
# Len of new dataset is :1300
# class_index:131, Acc1 0.9123076923076923
# 1300
# Len of new dataset is :1300
# class_index:132, Acc1 0.9084615384615384
# 1300
# Len of new dataset is :1300
# class_index:133, Acc1 0.9276923076923077
# 1300
# Len of new dataset is :1300
# class_index:134, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:135, Acc1 0.9392307692307692
# 1300
# Len of new dataset is :1300
# class_index:136, Acc1 0.9507692307692308
# 1300
# Len of new dataset is :1300
# class_index:137, Acc1 0.9523076923076923
# 1300
# Len of new dataset is :1300
# class_index:138, Acc1 0.9446153846153846
# 1300
# Len of new dataset is :1300
# class_index:139, Acc1 0.9492307692307692
# 1300
# Len of new dataset is :1300
# class_index:140, Acc1 0.9153846153846154
# 1300
# Len of new dataset is :1300
# class_index:141, Acc1 0.9292307692307692
# 1300
# Len of new dataset is :1300
# class_index:142, Acc1 0.9446153846153846
# 1300
# Len of new dataset is :1300
# class_index:143, Acc1 0.9484615384615385
# 1300
# Len of new dataset is :1300
# class_index:144, Acc1 0.9376923076923077
# 1300
# Len of new dataset is :1300
# class_index:145, Acc1 0.9723076923076923
# 1300
# Len of new dataset is :1300
# class_index:146, Acc1 0.9392307692307692
# 1150
# Len of new dataset is :1150
# class_index:147, Acc1 0.8721739130434782
# 1300
# Len of new dataset is :1300
# class_index:148, Acc1 0.9361538461538461
# 1300
# Len of new dataset is :1300
# class_index:149, Acc1 0.9061538461538462
# 1300
# Len of new dataset is :1300
# class_index:150, Acc1 0.8569230769230769
# 1300
# Len of new dataset is :1300
# class_index:151, Acc1 0.7146153846153847
# 772
# Len of new dataset is :772
# class_index:152, Acc1 0.8212435233160622
# 1300
# Len of new dataset is :1300
# class_index:153, Acc1 0.8784615384615385
# 1300
# Len of new dataset is :1300
# class_index:154, Acc1 0.8653846153846154
# 1300
# Len of new dataset is :1300
# class_index:155, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:156, Acc1 0.916923076923077
# 1300
# Len of new dataset is :1300
# class_index:157, Acc1 0.8976923076923077
# 860
# Len of new dataset is :860
# class_index:158, Acc1 0.7197674418604652
# 1300
# Len of new dataset is :1300
# class_index:159, Acc1 0.7123076923076923
# 1300
# Len of new dataset is :1300
# class_index:160, Acc1 0.8730769230769231
# 1300
# Len of new dataset is :1300
# class_index:161, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:162, Acc1 0.7792307692307693
# 1300
# Len of new dataset is :1300
# class_index:163, Acc1 0.7769230769230769
# 1136
# Len of new dataset is :1136
# class_index:164, Acc1 0.8565140845070423
# 732
# Len of new dataset is :732
# class_index:165, Acc1 0.6816939890710383
# 1025
# Len of new dataset is :1025
# class_index:166, Acc1 0.7024390243902439
# 754
# Len of new dataset is :754
# class_index:167, Acc1 0.5862068965517241
# 1290
# Len of new dataset is :1290
# class_index:168, Acc1 0.713953488372093
# 1300
# Len of new dataset is :1300
# class_index:169, Acc1 0.8853846153846154
# 1300
# Len of new dataset is :1300
# class_index:170, Acc1 0.7438461538461538
# 1300
# Len of new dataset is :1300
# class_index:171, Acc1 0.7723076923076924
# 1300
# Len of new dataset is :1300
# class_index:172, Acc1 0.7823076923076923
# 1300
# Len of new dataset is :1300
# class_index:173, Acc1 0.8546153846153847
# 1300
# Len of new dataset is :1300
# class_index:174, Acc1 0.8730769230769231
# 738
# Len of new dataset is :738
# class_index:175, Acc1 0.7168021680216802
# 1300
# Len of new dataset is :1300
# class_index:176, Acc1 0.8438461538461538
# 1300
# Len of new dataset is :1300
# class_index:177, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:178, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:179, Acc1 0.696923076923077
# 1300
# Len of new dataset is :1300
# class_index:180, Acc1 0.6246153846153846
# 1258
# Len of new dataset is :1258
# class_index:181, Acc1 0.9236883942766295
# 1300
# Len of new dataset is :1300
# class_index:182, Acc1 0.8623076923076923
# 1273
# Len of new dataset is :1273
# class_index:183, Acc1 0.852317360565593
# 1300
# Len of new dataset is :1300
# class_index:184, Acc1 0.7069230769230769
# 1300
# Len of new dataset is :1300
# class_index:185, Acc1 0.6646153846153846
# 1300
# Len of new dataset is :1300
# class_index:186, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:187, Acc1 0.7746153846153846
# 977
# Len of new dataset is :977
# class_index:188, Acc1 0.7338792221084954
# 1300
# Len of new dataset is :1300
# class_index:189, Acc1 0.6846153846153846
# 936
# Len of new dataset is :936
# class_index:190, Acc1 0.844017094017094
# 1300
# Len of new dataset is :1300
# class_index:191, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:192, Acc1 0.75
# 1300
# Len of new dataset is :1300
# class_index:193, Acc1 0.6576923076923077
# 1156
# Len of new dataset is :1156
# class_index:194, Acc1 0.8693771626297578
# 1300
# Len of new dataset is :1300
# class_index:195, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:196, Acc1 0.76
# 1300
# Len of new dataset is :1300
# class_index:197, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:198, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:199, Acc1 0.8584615384615385
# 1300
# Len of new dataset is :1300
# class_index:200, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:201, Acc1 0.7730769230769231
# 1300
# Len of new dataset is :1300
# class_index:202, Acc1 0.7915384615384615
# 1300
# Len of new dataset is :1300
# class_index:203, Acc1 0.8738461538461538
# 1300
# Len of new dataset is :1300
# class_index:204, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:205, Acc1 0.8176923076923077
# 1218
# Len of new dataset is :1218
# class_index:206, Acc1 0.8374384236453202
# 1300
# Len of new dataset is :1300
# class_index:207, Acc1 0.8038461538461539
# 1300
# Len of new dataset is :1300
# class_index:208, Acc1 0.713076923076923
# 1300
# Len of new dataset is :1300
# class_index:209, Acc1 0.8353846153846154
# 1300
# Len of new dataset is :1300
# class_index:210, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:211, Acc1 0.8269230769230769
# 1300
# Len of new dataset is :1300
# class_index:212, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:213, Acc1 0.8907692307692308
# 1300
# Len of new dataset is :1300
# class_index:214, Acc1 0.8884615384615384
# 1300
# Len of new dataset is :1300
# class_index:215, Acc1 0.7861538461538462
# 1300
# Len of new dataset is :1300
# class_index:216, Acc1 0.8869230769230769
# 1300
# Len of new dataset is :1300
# class_index:217, Acc1 0.8715384615384615
# 1300
# Len of new dataset is :1300
# class_index:218, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:219, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:220, Acc1 0.7930769230769231
# 969
# Len of new dataset is :969
# class_index:221, Acc1 0.8606811145510835
# 1300
# Len of new dataset is :1300
# class_index:222, Acc1 0.7961538461538461
# 1300
# Len of new dataset is :1300
# class_index:223, Acc1 0.8361538461538461
# 1300
# Len of new dataset is :1300
# class_index:224, Acc1 0.8623076923076923
# 1300
# Len of new dataset is :1300
# class_index:225, Acc1 0.8615384615384616
# 1300
# Len of new dataset is :1300
# class_index:226, Acc1 0.7538461538461538
# 1300
# Len of new dataset is :1300
# class_index:227, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:228, Acc1 0.9215384615384615
# 1300
# Len of new dataset is :1300
# class_index:229, Acc1 0.9138461538461539
# 1300
# Len of new dataset is :1300
# class_index:230, Acc1 0.8215384615384616
# 1300
# Len of new dataset is :1300
# class_index:231, Acc1 0.5161538461538462
# 1300
# Len of new dataset is :1300
# class_index:232, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:233, Acc1 0.7884615384615384
# 1300
# Len of new dataset is :1300
# class_index:234, Acc1 0.8092307692307692
# 1300
# Len of new dataset is :1300
# class_index:235, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:236, Acc1 0.7669230769230769
# 1300
# Len of new dataset is :1300
# class_index:237, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:238, Acc1 0.7323076923076923
# 1300
# Len of new dataset is :1300
# class_index:239, Acc1 0.8884615384615384
# 1300
# Len of new dataset is :1300
# class_index:240, Acc1 0.58
# 1300
# Len of new dataset is :1300
# class_index:241, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:242, Acc1 0.7938461538461539
# 1300
# Len of new dataset is :1300
# class_index:243, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:244, Acc1 0.8469230769230769
# 1300
# Len of new dataset is :1300
# class_index:245, Acc1 0.7984615384615384
# 1300
# Len of new dataset is :1300
# class_index:246, Acc1 0.7907692307692308
# 1300
# Len of new dataset is :1300
# class_index:247, Acc1 0.93
# 1300
# Len of new dataset is :1300
# class_index:248, Acc1 0.45384615384615384
# 1300
# Len of new dataset is :1300
# class_index:249, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:250, Acc1 0.6138461538461538
# 1300
# Len of new dataset is :1300
# class_index:251, Acc1 0.9476923076923077
# 954
# Len of new dataset is :954
# class_index:252, Acc1 0.8322851153039832
# 1300
# Len of new dataset is :1300
# class_index:253, Acc1 0.8392307692307692
# 1300
# Len of new dataset is :1300
# class_index:254, Acc1 0.8969230769230769
# 1300
# Len of new dataset is :1300
# class_index:255, Acc1 0.933076923076923
# 1300
# Len of new dataset is :1300
# class_index:256, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:257, Acc1 0.7830769230769231
# 1300
# Len of new dataset is :1300
# class_index:258, Acc1 0.9061538461538462
# 1300
# Len of new dataset is :1300
# class_index:259, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:260, Acc1 0.9146153846153846
# 1300
# Len of new dataset is :1300
# class_index:261, Acc1 0.9492307692307692
# 1070
# Len of new dataset is :1070
# class_index:262, Acc1 0.8429906542056075
# 1300
# Len of new dataset is :1300
# class_index:263, Acc1 0.8323076923076923
# 1300
# Len of new dataset is :1300
# class_index:264, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:265, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:266, Acc1 0.6007692307692307
# 1300
# Len of new dataset is :1300
# class_index:267, Acc1 0.7576923076923077
# 755
# Len of new dataset is :755
# class_index:268, Acc1 0.8741721854304636
# 1300
# Len of new dataset is :1300
# class_index:269, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:270, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:271, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:272, Acc1 0.806923076923077
# 1300
# Len of new dataset is :1300
# class_index:273, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:274, Acc1 0.8530769230769231
# 1300
# Len of new dataset is :1300
# class_index:275, Acc1 0.9361538461538461
# 1300
# Len of new dataset is :1300
# class_index:276, Acc1 0.9115384615384615
# 1300
# Len of new dataset is :1300
# class_index:277, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:278, Acc1 0.6861538461538461
# 1300
# Len of new dataset is :1300
# class_index:279, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:280, Acc1 0.7784615384615384
# 1300
# Len of new dataset is :1300
# class_index:281, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:282, Acc1 0.42
# 1300
# Len of new dataset is :1300
# class_index:283, Acc1 0.91
# 1300
# Len of new dataset is :1300
# class_index:284, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:285, Acc1 0.7353846153846154
# 1300
# Len of new dataset is :1300
# class_index:286, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:287, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:288, Acc1 0.7576923076923077
# 1300
# Len of new dataset is :1300
# class_index:289, Acc1 0.9646153846153847
# 1300
# Len of new dataset is :1300
# class_index:290, Acc1 0.8569230769230769
# 1300
# Len of new dataset is :1300
# class_index:291, Acc1 0.9284615384615384
# 1300
# Len of new dataset is :1300
# class_index:292, Acc1 0.9576923076923077
# 1300
# Len of new dataset is :1300
# class_index:293, Acc1 0.9346153846153846
# 1300
# Len of new dataset is :1300
# class_index:294, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:295, Acc1 0.8807692307692307
# 1300
# Len of new dataset is :1300
# class_index:296, Acc1 0.9515384615384616
# 1300
# Len of new dataset is :1300
# class_index:297, Acc1 0.9061538461538462
# 1300
# Len of new dataset is :1300
# class_index:298, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:299, Acc1 0.933076923076923
# 1300
# Len of new dataset is :1300
# class_index:300, Acc1 0.9230769230769231
# 1300
# Len of new dataset is :1300
# class_index:301, Acc1 0.9069230769230769
# 1300
# Len of new dataset is :1300
# class_index:302, Acc1 0.7392307692307692
# 1300
# Len of new dataset is :1300
# class_index:303, Acc1 0.77
# 1300
# Len of new dataset is :1300
# class_index:304, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:305, Acc1 0.8869230769230769
# 1300
# Len of new dataset is :1300
# class_index:306, Acc1 0.8630769230769231
# 1300
# Len of new dataset is :1300
# class_index:307, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:308, Acc1 0.8646153846153846
# 1300
# Len of new dataset is :1300
# class_index:309, Acc1 0.8476923076923077
# 1300
# Len of new dataset is :1300
# class_index:310, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:311, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:312, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:313, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:314, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:315, Acc1 0.8438461538461538
# 1300
# Len of new dataset is :1300
# class_index:316, Acc1 0.9038461538461539
# 1300
# Len of new dataset is :1300
# class_index:317, Acc1 0.87
# 1300
# Len of new dataset is :1300
# class_index:318, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:319, Acc1 0.8115384615384615
# 1300
# Len of new dataset is :1300
# class_index:320, Acc1 0.8853846153846154
# 1300
# Len of new dataset is :1300
# class_index:321, Acc1 0.9776923076923076
# 1300
# Len of new dataset is :1300
# class_index:322, Acc1 0.9276923076923077
# 1300
# Len of new dataset is :1300
# class_index:323, Acc1 0.9823076923076923
# 1300
# Len of new dataset is :1300
# class_index:324, Acc1 0.9415384615384615
# 1300
# Len of new dataset is :1300
# class_index:325, Acc1 0.94
# 1300
# Len of new dataset is :1300
# class_index:326, Acc1 0.9453846153846154
# 1300
# Len of new dataset is :1300
# class_index:327, Acc1 0.87
# 1300
# Len of new dataset is :1300
# class_index:328, Acc1 0.9
# 1300
# Len of new dataset is :1300
# class_index:329, Acc1 0.8407692307692308
# 1300
# Len of new dataset is :1300
# class_index:330, Acc1 0.8446153846153847
# 1300
# Len of new dataset is :1300
# class_index:331, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:332, Acc1 0.92
# 1300
# Len of new dataset is :1300
# class_index:333, Acc1 0.9361538461538461
# 1300
# Len of new dataset is :1300
# class_index:334, Acc1 0.9115384615384615
# 1206
# Len of new dataset is :1206
# class_index:335, Acc1 0.8888888888888888
# 1300
# Len of new dataset is :1300
# class_index:336, Acc1 0.9107692307692308
# 1300
# Len of new dataset is :1300
# class_index:337, Acc1 0.8053846153846154
# 1300
# Len of new dataset is :1300
# class_index:338, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:339, Acc1 0.9776923076923076
# 1300
# Len of new dataset is :1300
# class_index:340, Acc1 0.9692307692307692
# 1300
# Len of new dataset is :1300
# class_index:341, Acc1 0.5938461538461538
# 1300
# Len of new dataset is :1300
# class_index:342, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:343, Acc1 0.8976923076923077
# 1300
# Len of new dataset is :1300
# class_index:344, Acc1 0.9307692307692308
# 1300
# Len of new dataset is :1300
# class_index:345, Acc1 0.6261538461538462
# 1300
# Len of new dataset is :1300
# class_index:346, Acc1 0.8723076923076923
# 1300
# Len of new dataset is :1300
# class_index:347, Acc1 0.9592307692307692
# 1300
# Len of new dataset is :1300
# class_index:348, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:349, Acc1 0.8669230769230769
# 1300
# Len of new dataset is :1300
# class_index:350, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:351, Acc1 0.9415384615384615
# 1300
# Len of new dataset is :1300
# class_index:352, Acc1 0.8384615384615385
# 1300
# Len of new dataset is :1300
# class_index:353, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:354, Acc1 0.9423076923076923
# 1300
# Len of new dataset is :1300
# class_index:355, Acc1 0.9184615384615384
# 1300
# Len of new dataset is :1300
# class_index:356, Acc1 0.48615384615384616
# 1300
# Len of new dataset is :1300
# class_index:357, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:358, Acc1 0.6423076923076924
# 1300
# Len of new dataset is :1300
# class_index:359, Acc1 0.7846153846153846
# 1300
# Len of new dataset is :1300
# class_index:360, Acc1 0.8438461538461538
# 1300
# Len of new dataset is :1300
# class_index:361, Acc1 0.9130769230769231
# 1300
# Len of new dataset is :1300
# class_index:362, Acc1 0.8946153846153846
# 1300
# Len of new dataset is :1300
# class_index:363, Acc1 0.9284615384615384
# 1300
# Len of new dataset is :1300
# class_index:364, Acc1 0.9038461538461539
# 1300
# Len of new dataset is :1300
# class_index:365, Acc1 0.9292307692307692
# 1300
# Len of new dataset is :1300
# class_index:366, Acc1 0.9130769230769231
# 1300
# Len of new dataset is :1300
# class_index:367, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:368, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:369, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:370, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:371, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:372, Acc1 0.8592307692307692
# 1300
# Len of new dataset is :1300
# class_index:373, Acc1 0.8207692307692308
# 1300
# Len of new dataset is :1300
# class_index:374, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:375, Acc1 0.9046153846153846
# 1300
# Len of new dataset is :1300
# class_index:376, Acc1 0.9707692307692307
# 1300
# Len of new dataset is :1300
# class_index:377, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:378, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:379, Acc1 0.8392307692307692
# 1300
# Len of new dataset is :1300
# class_index:380, Acc1 0.45615384615384613
# 1300
# Len of new dataset is :1300
# class_index:381, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:382, Acc1 0.8838461538461538
# 1300
# Len of new dataset is :1300
# class_index:383, Acc1 0.916923076923077
# 1300
# Len of new dataset is :1300
# class_index:384, Acc1 0.8023076923076923
# 1300
# Len of new dataset is :1300
# class_index:385, Acc1 0.7230769230769231
# 1300
# Len of new dataset is :1300
# class_index:386, Acc1 0.7730769230769231
# 1300
# Len of new dataset is :1300
# class_index:387, Acc1 0.9669230769230769
# 1300
# Len of new dataset is :1300
# class_index:388, Acc1 0.9823076923076923
# 1300
# Len of new dataset is :1300
# class_index:389, Acc1 0.8061538461538461
# 1165
# Len of new dataset is :1165
# class_index:390, Acc1 0.7467811158798283
# 1300
# Len of new dataset is :1300
# class_index:391, Acc1 0.8569230769230769
# 969
# Len of new dataset is :969
# class_index:392, Acc1 0.9411764705882353
# 1300
# Len of new dataset is :1300
# class_index:393, Acc1 0.933076923076923
# 1300
# Len of new dataset is :1300
# class_index:394, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:395, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:396, Acc1 0.9392307692307692
# 1300
# Len of new dataset is :1300
# class_index:397, Acc1 0.9153846153846154
# 1300
# Len of new dataset is :1300
# class_index:398, Acc1 0.8823076923076923
# 1300
# Len of new dataset is :1300
# class_index:399, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:400, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:401, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:402, Acc1 0.8184615384615385
# 1300
# Len of new dataset is :1300
# class_index:403, Acc1 0.9415384615384615
# 1300
# Len of new dataset is :1300
# class_index:404, Acc1 0.9123076923076923
# 1300
# Len of new dataset is :1300
# class_index:405, Acc1 0.933076923076923
# 1300
# Len of new dataset is :1300
# class_index:406, Acc1 0.8238461538461539
# 1300
# Len of new dataset is :1300
# class_index:407, Acc1 0.8184615384615385
# 1300
# Len of new dataset is :1300
# class_index:408, Acc1 0.8292307692307692
# 1292
# Len of new dataset is :1292
# class_index:409, Acc1 0.598297213622291
# 1300
# Len of new dataset is :1300
# class_index:410, Acc1 0.9261538461538461
# 1300
# Len of new dataset is :1300
# class_index:411, Acc1 0.7707692307692308
# 1300
# Len of new dataset is :1300
# class_index:412, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:413, Acc1 0.7015384615384616
# 1300
# Len of new dataset is :1300
# class_index:414, Acc1 0.7984615384615384
# 1300
# Len of new dataset is :1300
# class_index:415, Acc1 0.6307692307692307
# 1300
# Len of new dataset is :1300
# class_index:416, Acc1 0.8984615384615384
# 1300
# Len of new dataset is :1300
# class_index:417, Acc1 0.9
# 1236
# Len of new dataset is :1236
# class_index:418, Acc1 0.63915857605178
# 1300
# Len of new dataset is :1300
# class_index:419, Acc1 0.5946153846153847
# 1300
# Len of new dataset is :1300
# class_index:420, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:421, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:422, Acc1 0.84
# 1300
# Len of new dataset is :1300
# class_index:423, Acc1 0.7953846153846154
# 1300
# Len of new dataset is :1300
# class_index:424, Acc1 0.7730769230769231
# 1300
# Len of new dataset is :1300
# class_index:425, Acc1 0.9130769230769231
# 1199
# Len of new dataset is :1199
# class_index:426, Acc1 0.8248540450375312
# 1300
# Len of new dataset is :1300
# class_index:427, Acc1 0.7153846153846154
# 1300
# Len of new dataset is :1300
# class_index:428, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:429, Acc1 0.8176923076923077
# 1300
# Len of new dataset is :1300
# class_index:430, Acc1 0.9307692307692308
# 1300
# Len of new dataset is :1300
# class_index:431, Acc1 0.8453846153846154
# 1300
# Len of new dataset is :1300
# class_index:432, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:433, Acc1 0.8238461538461539
# 1300
# Len of new dataset is :1300
# class_index:434, Acc1 0.7307692307692307
# 1300
# Len of new dataset is :1300
# class_index:435, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:436, Acc1 0.6892307692307692
# 1300
# Len of new dataset is :1300
# class_index:437, Acc1 0.9092307692307692
# 1300
# Len of new dataset is :1300
# class_index:438, Acc1 0.7938461538461539
# 1209
# Len of new dataset is :1209
# class_index:439, Acc1 0.9164598842018197
# 1300
# Len of new dataset is :1300
# class_index:440, Acc1 0.7046153846153846
# 1300
# Len of new dataset is :1300
# class_index:441, Acc1 0.8269230769230769
# 1300
# Len of new dataset is :1300
# class_index:442, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:443, Acc1 0.8415384615384616
# 1300
# Len of new dataset is :1300
# class_index:444, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:445, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:446, Acc1 0.7223076923076923
# 1300
# Len of new dataset is :1300
# class_index:447, Acc1 0.7584615384615384
# 1300
# Len of new dataset is :1300
# class_index:448, Acc1 0.8884615384615384
# 1300
# Len of new dataset is :1300
# class_index:449, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:450, Acc1 0.9307692307692308
# 1300
# Len of new dataset is :1300
# class_index:451, Acc1 0.8346153846153846
# 1300
# Len of new dataset is :1300
# class_index:452, Acc1 0.7907692307692308
# 1300
# Len of new dataset is :1300
# class_index:453, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:454, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:455, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:456, Acc1 0.7192307692307692
# 1300
# Len of new dataset is :1300
# class_index:457, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:458, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:459, Acc1 0.7146153846153847
# 1300
# Len of new dataset is :1300
# class_index:460, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:461, Acc1 0.5861538461538461
# 1300
# Len of new dataset is :1300
# class_index:462, Acc1 0.796923076923077
# 1300
# Len of new dataset is :1300
# class_index:463, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:464, Acc1 0.6330769230769231
# 1176
# Len of new dataset is :1176
# class_index:465, Acc1 0.8061224489795918
# 1300
# Len of new dataset is :1300
# class_index:466, Acc1 0.9676923076923077
# 1300
# Len of new dataset is :1300
# class_index:467, Acc1 0.9069230769230769
# 1300
# Len of new dataset is :1300
# class_index:468, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:469, Acc1 0.72
# 1300
# Len of new dataset is :1300
# class_index:470, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:471, Acc1 0.8592307692307692
# 1300
# Len of new dataset is :1300
# class_index:472, Acc1 0.8523076923076923
# 1300
# Len of new dataset is :1300
# class_index:473, Acc1 0.6323076923076923
# 1300
# Len of new dataset is :1300
# class_index:474, Acc1 0.7884615384615384
# 1300
# Len of new dataset is :1300
# class_index:475, Acc1 0.9361538461538461
# 1300
# Len of new dataset is :1300
# class_index:476, Acc1 0.95
# 1300
# Len of new dataset is :1300
# class_index:477, Acc1 0.7807692307692308
# 1300
# Len of new dataset is :1300
# class_index:478, Acc1 0.7638461538461538
# 1300
# Len of new dataset is :1300
# class_index:479, Acc1 0.6723076923076923
# 1300
# Len of new dataset is :1300
# class_index:480, Acc1 0.8815384615384615
# 1186
# Len of new dataset is :1186
# class_index:481, Acc1 0.7462057335581788
# 1300
# Len of new dataset is :1300
# class_index:482, Acc1 0.44384615384615383
# 1300
# Len of new dataset is :1300
# class_index:483, Acc1 0.8961538461538462
# 1300
# Len of new dataset is :1300
# class_index:484, Acc1 0.8207692307692308
# 1300
# Len of new dataset is :1300
# class_index:485, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:486, Acc1 0.84
# 1300
# Len of new dataset is :1300
# class_index:487, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:488, Acc1 0.6130769230769231
# 1300
# Len of new dataset is :1300
# class_index:489, Acc1 0.8215384615384616
# 1300
# Len of new dataset is :1300
# class_index:490, Acc1 0.8376923076923077
# 1194
# Len of new dataset is :1194
# class_index:491, Acc1 0.8425460636515912
# 1300
# Len of new dataset is :1300
# class_index:492, Acc1 0.7561538461538462
# 1300
# Len of new dataset is :1300
# class_index:493, Acc1 0.8576923076923076
# 1300
# Len of new dataset is :1300
# class_index:494, Acc1 0.6215384615384615
# 1300
# Len of new dataset is :1300
# class_index:495, Acc1 0.8769230769230769
# 1300
# Len of new dataset is :1300
# class_index:496, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:497, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:498, Acc1 0.8576923076923076
# 1067
# Len of new dataset is :1067
# class_index:499, Acc1 0.6429240862230553
# 1300
# Len of new dataset is :1300
# class_index:500, Acc1 0.9438461538461539
# 1029
# Len of new dataset is :1029
# class_index:501, Acc1 0.6229348882410107
# 1300
# Len of new dataset is :1300
# class_index:502, Acc1 0.6776923076923077
# 1154
# Len of new dataset is :1154
# class_index:503, Acc1 0.7694974003466204
# 1300
# Len of new dataset is :1300
# class_index:504, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:505, Acc1 0.6776923076923077
# 1300
# Len of new dataset is :1300
# class_index:506, Acc1 0.7661538461538462
# 1216
# Len of new dataset is :1216
# class_index:507, Acc1 0.7294407894736842
# 1300
# Len of new dataset is :1300
# class_index:508, Acc1 0.7123076923076923
# 1300
# Len of new dataset is :1300
# class_index:509, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:510, Acc1 0.9223076923076923
# 1300
# Len of new dataset is :1300
# class_index:511, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:512, Acc1 0.7415384615384616
# 1300
# Len of new dataset is :1300
# class_index:513, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:514, Acc1 0.7307692307692307
# 1300
# Len of new dataset is :1300
# class_index:515, Acc1 0.6853846153846154
# 1300
# Len of new dataset is :1300
# class_index:516, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:517, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:518, Acc1 0.7776923076923077
# 1300
# Len of new dataset is :1300
# class_index:519, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:520, Acc1 0.8807692307692307
# 1187
# Len of new dataset is :1187
# class_index:521, Acc1 0.8550968828980623
# 1300
# Len of new dataset is :1300
# class_index:522, Acc1 0.9015384615384615
# 1300
# Len of new dataset is :1300
# class_index:523, Acc1 0.6461538461538462
# 1300
# Len of new dataset is :1300
# class_index:524, Acc1 0.6907692307692308
# 1300
# Len of new dataset is :1300
# class_index:525, Acc1 0.89
# 1300
# Len of new dataset is :1300
# class_index:526, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:527, Acc1 0.713076923076923
# 1300
# Len of new dataset is :1300
# class_index:528, Acc1 0.8392307692307692
# 1300
# Len of new dataset is :1300
# class_index:529, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:530, Acc1 0.7753846153846153
# 889
# Len of new dataset is :889
# class_index:531, Acc1 0.7840269966254219
# 1300
# Len of new dataset is :1300
# class_index:532, Acc1 0.8153846153846154
# 1300
# Len of new dataset is :1300
# class_index:533, Acc1 0.8946153846153846
# 1300
# Len of new dataset is :1300
# class_index:534, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:535, Acc1 0.8592307692307692
# 1211
# Len of new dataset is :1211
# class_index:536, Acc1 0.6763005780346821
# 1300
# Len of new dataset is :1300
# class_index:537, Acc1 0.9546153846153846
# 1300
# Len of new dataset is :1300
# class_index:538, Acc1 0.7353846153846154
# 1300
# Len of new dataset is :1300
# class_index:539, Acc1 0.75
# 1300
# Len of new dataset is :1300
# class_index:540, Acc1 0.9230769230769231
# 1300
# Len of new dataset is :1300
# class_index:541, Acc1 0.6938461538461539
# 1300
# Len of new dataset is :1300
# class_index:542, Acc1 0.6138461538461538
# 1300
# Len of new dataset is :1300
# class_index:543, Acc1 0.7530769230769231
# 1300
# Len of new dataset is :1300
# class_index:544, Acc1 0.8392307692307692
# 1300
# Len of new dataset is :1300
# class_index:545, Acc1 0.8269230769230769
# 1300
# Len of new dataset is :1300
# class_index:546, Acc1 0.8184615384615385
# 1300
# Len of new dataset is :1300
# class_index:547, Acc1 0.9138461538461539
# 1300
# Len of new dataset is :1300
# class_index:548, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:549, Acc1 0.7461538461538462
# 1136
# Len of new dataset is :1136
# class_index:550, Acc1 0.823943661971831
# 1153
# Len of new dataset is :1153
# class_index:551, Acc1 0.7493495229835212
# 1300
# Len of new dataset is :1300
# class_index:552, Acc1 0.8984615384615384
# 1300
# Len of new dataset is :1300
# class_index:553, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:554, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:555, Acc1 0.8915384615384615
# 1300
# Len of new dataset is :1300
# class_index:556, Acc1 0.7884615384615384
# 1300
# Len of new dataset is :1300
# class_index:557, Acc1 0.8638461538461538
# 1300
# Len of new dataset is :1300
# class_index:558, Acc1 0.6546153846153846
# 1300
# Len of new dataset is :1300
# class_index:559, Acc1 0.7976923076923077
# 1300
# Len of new dataset is :1300
# class_index:560, Acc1 0.92
# 1300
# Len of new dataset is :1300
# class_index:561, Acc1 0.9076923076923077
# 1300
# Len of new dataset is :1300
# class_index:562, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:563, Acc1 0.7876923076923077
# 1300
# Len of new dataset is :1300
# class_index:564, Acc1 0.9238461538461539
# 1300
# Len of new dataset is :1300
# class_index:565, Acc1 0.9138461538461539
# 1300
# Len of new dataset is :1300
# class_index:566, Acc1 0.8776923076923077
# 1222
# Len of new dataset is :1222
# class_index:567, Acc1 0.6211129296235679
# 1300
# Len of new dataset is :1300
# class_index:568, Acc1 0.8661538461538462
# 1300
# Len of new dataset is :1300
# class_index:569, Acc1 0.9046153846153846
# 1300
# Len of new dataset is :1300
# class_index:570, Acc1 0.78
# 1300
# Len of new dataset is :1300
# class_index:571, Acc1 0.8946153846153846
# 1300
# Len of new dataset is :1300
# class_index:572, Acc1 0.7653846153846153
# 1300
# Len of new dataset is :1300
# class_index:573, Acc1 0.9461538461538461
# 1300
# Len of new dataset is :1300
# class_index:574, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:575, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:576, Acc1 0.98
# 1282
# Len of new dataset is :1282
# class_index:577, Acc1 0.7987519500780031
# 1300
# Len of new dataset is :1300
# class_index:578, Acc1 0.6592307692307692
# 1300
# Len of new dataset is :1300
# class_index:579, Acc1 0.8530769230769231
# 1300
# Len of new dataset is :1300
# class_index:580, Acc1 0.8784615384615385
# 1300
# Len of new dataset is :1300
# class_index:581, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:582, Acc1 0.6523076923076923
# 1283
# Len of new dataset is :1283
# class_index:583, Acc1 0.8612626656274357
# 1300
# Len of new dataset is :1300
# class_index:584, Acc1 0.696923076923077
# 980
# Len of new dataset is :980
# class_index:585, Acc1 0.49183673469387756
# 1300
# Len of new dataset is :1300
# class_index:586, Acc1 0.8976923076923077
# 1300
# Len of new dataset is :1300
# class_index:587, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:588, Acc1 0.8176923076923077
# 1300
# Len of new dataset is :1300
# class_index:589, Acc1 0.7276923076923076
# 1034
# Len of new dataset is :1034
# class_index:590, Acc1 0.7843326885880078
# 1300
# Len of new dataset is :1300
# class_index:591, Acc1 0.7138461538461538
# 1300
# Len of new dataset is :1300
# class_index:592, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:593, Acc1 0.7484615384615385
# 1300
# Len of new dataset is :1300
# class_index:594, Acc1 0.9484615384615385
# 1300
# Len of new dataset is :1300
# class_index:595, Acc1 0.7469230769230769
# 891
# Len of new dataset is :891
# class_index:596, Acc1 0.5578002244668911
# 1300
# Len of new dataset is :1300
# class_index:597, Acc1 0.8584615384615385
# 1300
# Len of new dataset is :1300
# class_index:598, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:599, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:600, Acc1 0.4807692307692308
# 1300
# Len of new dataset is :1300
# class_index:601, Acc1 0.7876923076923077
# 1300
# Len of new dataset is :1300
# class_index:602, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:603, Acc1 0.9238461538461539
# 1300
# Len of new dataset is :1300
# class_index:604, Acc1 0.8876923076923077
# 1300
# Len of new dataset is :1300
# class_index:605, Acc1 0.8246153846153846
# 1300
# Len of new dataset is :1300
# class_index:606, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:607, Acc1 0.9730769230769231
# 1300
# Len of new dataset is :1300
# class_index:608, Acc1 0.7861538461538462
# 1300
# Len of new dataset is :1300
# class_index:609, Acc1 0.8846153846153846
# 1285
# Len of new dataset is :1285
# class_index:610, Acc1 0.7540856031128405
# 1300
# Len of new dataset is :1300
# class_index:611, Acc1 0.88
# 1300
# Len of new dataset is :1300
# class_index:612, Acc1 0.9323076923076923
# 1300
# Len of new dataset is :1300
# class_index:613, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:614, Acc1 0.8307692307692308
# 1300
# Len of new dataset is :1300
# class_index:615, Acc1 0.7569230769230769
# 1300
# Len of new dataset is :1300
# class_index:616, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:617, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:618, Acc1 0.5192307692307693
# 1300
# Len of new dataset is :1300
# class_index:619, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:620, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:621, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:622, Acc1 0.85
# 986
# Len of new dataset is :986
# class_index:623, Acc1 0.5578093306288032
# 1300
# Len of new dataset is :1300
# class_index:624, Acc1 0.7653846153846153
# 1300
# Len of new dataset is :1300
# class_index:625, Acc1 0.9215384615384615
# 1300
# Len of new dataset is :1300
# class_index:626, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:627, Acc1 0.8361538461538461
# 1300
# Len of new dataset is :1300
# class_index:628, Acc1 0.8946153846153846
# 1300
# Len of new dataset is :1300
# class_index:629, Acc1 0.7946153846153846
# 1137
# Len of new dataset is :1137
# class_index:630, Acc1 0.7889182058047494
# 1272
# Len of new dataset is :1272
# class_index:631, Acc1 0.625
# 1300
# Len of new dataset is :1300
# class_index:632, Acc1 0.6815384615384615
# 1300
# Len of new dataset is :1300
# class_index:633, Acc1 0.6584615384615384
# 1300
# Len of new dataset is :1300
# class_index:634, Acc1 0.8284615384615385
# 1155
# Len of new dataset is :1155
# class_index:635, Acc1 0.8051948051948052
# 1300
# Len of new dataset is :1300
# class_index:636, Acc1 0.6292307692307693
# 1300
# Len of new dataset is :1300
# class_index:637, Acc1 0.7976923076923077
# 1300
# Len of new dataset is :1300
# class_index:638, Acc1 0.32153846153846155
# 1300
# Len of new dataset is :1300
# class_index:639, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:640, Acc1 0.9592307692307692
# 1300
# Len of new dataset is :1300
# class_index:641, Acc1 0.7269230769230769
# 1300
# Len of new dataset is :1300
# class_index:642, Acc1 0.9030769230769231
# 1300
# Len of new dataset is :1300
# class_index:643, Acc1 0.72
# 1300
# Len of new dataset is :1300
# class_index:644, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:645, Acc1 0.953076923076923
# 1300
# Len of new dataset is :1300
# class_index:646, Acc1 0.8646153846153846
# 1300
# Len of new dataset is :1300
# class_index:647, Acc1 0.7638461538461538
# 1300
# Len of new dataset is :1300
# class_index:648, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:649, Acc1 0.916923076923077
# 1300
# Len of new dataset is :1300
# class_index:650, Acc1 0.6361538461538462
# 1300
# Len of new dataset is :1300
# class_index:651, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:652, Acc1 0.7576923076923077
# 1097
# Len of new dataset is :1097
# class_index:653, Acc1 0.8076572470373746
# 1300
# Len of new dataset is :1300
# class_index:654, Acc1 0.7746153846153846
# 1300
# Len of new dataset is :1300
# class_index:655, Acc1 0.7338461538461538
# 1300
# Len of new dataset is :1300
# class_index:656, Acc1 0.7469230769230769
# 1300
# Len of new dataset is :1300
# class_index:657, Acc1 0.7223076923076923
# 1300
# Len of new dataset is :1300
# class_index:658, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:659, Acc1 0.696923076923077
# 1300
# ...
#   warnings.warn(str(msg))
# class_index:782, Acc1 0.44751381215469616
# 1300
# Len of new dataset is :1300
# class_index:783, Acc1 0.69
# 1300
# Len of new dataset is :1300
# class_index:784, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:785, Acc1 0.8646153846153846
# 1300
# Len of new dataset is :1300
# class_index:786, Acc1 0.8469230769230769
# 1300
# Len of new dataset is :1300
# class_index:787, Acc1 0.7623076923076924
# 1300
# Len of new dataset is :1300
# class_index:788, Acc1 0.7953846153846154
# 1249
# Len of new dataset is :1249
# class_index:789, Acc1 0.8598879103282626
# 1300
# Len of new dataset is :1300
# class_index:790, Acc1 0.7846153846153846
# 1300
# Len of new dataset is :1300
# class_index:791, Acc1 0.8407692307692308
# 1300
# Len of new dataset is :1300
# class_index:792, Acc1 0.6892307692307692
# 1300
# Len of new dataset is :1300
# class_index:793, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:794, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:795, Acc1 0.8484615384615385
# 1300
# Len of new dataset is :1300
# class_index:796, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:797, Acc1 0.7561538461538462
# 1162
# Len of new dataset is :1162
# class_index:798, Acc1 0.8898450946643718
# 1300
# Len of new dataset is :1300
# class_index:799, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:800, Acc1 0.9484615384615385
# 1300
# Len of new dataset is :1300
# class_index:801, Acc1 0.8538461538461538
# 1300
# Len of new dataset is :1300
# class_index:802, Acc1 0.9538461538461539
# 1300
# Len of new dataset is :1300
# class_index:803, Acc1 0.9184615384615384
# 1300
# Len of new dataset is :1300
# class_index:804, Acc1 0.6976923076923077
# 1300
# Len of new dataset is :1300
# class_index:805, Acc1 0.8253846153846154
# 1300
# Len of new dataset is :1300
# class_index:806, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:807, Acc1 0.8146153846153846
# 1300
# Len of new dataset is :1300
# class_index:808, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:809, Acc1 0.6823076923076923
# 1045
# Len of new dataset is :1045
# class_index:810, Acc1 0.5119617224880383
# 1004
# Len of new dataset is :1004
# class_index:811, Acc1 0.6822709163346613
# 1238
# Len of new dataset is :1238
# class_index:812, Acc1 0.9184168012924071
# 1300
# Len of new dataset is :1300
# class_index:813, Acc1 0.47384615384615386
# 1300
# Len of new dataset is :1300
# class_index:814, Acc1 0.8723076923076923
# 1300
# Len of new dataset is :1300
# class_index:815, Acc1 0.8407692307692308
# 1300
# Len of new dataset is :1300
# class_index:816, Acc1 0.8838461538461538
# 1300
# Len of new dataset is :1300
# class_index:817, Acc1 0.6715384615384615
# 1300
# Len of new dataset is :1300
# class_index:818, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:819, Acc1 0.8115384615384615
# 1300
# Len of new dataset is :1300
# class_index:820, Acc1 0.97
# 1153
# Len of new dataset is :1153
# class_index:821, Acc1 0.8941890719861232
# 1300
# Len of new dataset is :1300
# class_index:822, Acc1 0.9007692307692308
# 1300
# Len of new dataset is :1300
# class_index:823, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:824, Acc1 0.5284615384615384
# 1300
# Len of new dataset is :1300
# class_index:825, Acc1 0.8946153846153846
# 1084
# Len of new dataset is :1084
# class_index:826, Acc1 0.7444649446494465
# 1300
# Len of new dataset is :1300
# class_index:827, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:828, Acc1 0.6684615384615384
# 1300
# Len of new dataset is :1300
# class_index:829, Acc1 0.8784615384615385
# 1300
# Len of new dataset is :1300
# class_index:830, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:831, Acc1 0.7715384615384615
# 1300
# Len of new dataset is :1300
# class_index:832, Acc1 0.9646153846153847
# 1300
# Len of new dataset is :1300
# class_index:833, Acc1 0.9123076923076923
# 1300
# Len of new dataset is :1300
# class_index:834, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:835, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:836, Acc1 0.4946153846153846
# 1300
# Len of new dataset is :1300
# class_index:837, Acc1 0.553076923076923
# 1217
# Len of new dataset is :1217
# class_index:838, Acc1 0.5184880854560394
# 1300
# Len of new dataset is :1300
# class_index:839, Acc1 0.8676923076923077
# 1300
# Len of new dataset is :1300
# class_index:840, Acc1 0.7346153846153847
# 931
# Len of new dataset is :931
# class_index:841, Acc1 0.631578947368421
# 1300
# Len of new dataset is :1300
# class_index:842, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:843, Acc1 0.8692307692307693
# 1300
# Len of new dataset is :1300
# class_index:844, Acc1 0.7238461538461538
# 1300
# Len of new dataset is :1300
# class_index:845, Acc1 0.6692307692307692
# 1300
# Len of new dataset is :1300
# class_index:846, Acc1 0.7830769230769231
# 1300
# Len of new dataset is :1300
# class_index:847, Acc1 0.9046153846153846
# 1300
# Len of new dataset is :1300
# class_index:848, Acc1 0.5230769230769231
# 1300
# Len of new dataset is :1300
# class_index:849, Acc1 0.7930769230769231
# 1300
# Len of new dataset is :1300
# class_index:850, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:851, Acc1 0.6023076923076923
# 1300
# Len of new dataset is :1300
# class_index:852, Acc1 0.7676923076923077
# 1300
# Len of new dataset is :1300
# class_index:853, Acc1 0.9246153846153846
# 1264
# Len of new dataset is :1264
# class_index:854, Acc1 0.8916139240506329
# 1300
# Len of new dataset is :1300
# class_index:855, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:856, Acc1 0.7315384615384616
# 976
# Len of new dataset is :976
# class_index:857, Acc1 0.8473360655737705
# 1300
# Len of new dataset is :1300
# class_index:858, Acc1 0.8530769230769231
# 1300
# Len of new dataset is :1300
# class_index:859, Acc1 0.7930769230769231
# 1250
# Len of new dataset is :1250
# class_index:860, Acc1 0.6616
# 1300
# Len of new dataset is :1300
# class_index:861, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:862, Acc1 0.8615384615384616
# 1300
# Len of new dataset is :1300
# class_index:863, Acc1 0.936923076923077
# 1300
# Len of new dataset is :1300
# class_index:864, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:865, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:866, Acc1 0.7946153846153846
# 1300
# Len of new dataset is :1300
# class_index:867, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:868, Acc1 0.6123076923076923
# 1053
# Len of new dataset is :1053
# class_index:869, Acc1 0.7673314339981007
# 1300
# Len of new dataset is :1300
# class_index:870, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:871, Acc1 0.78
# 1160
# Len of new dataset is :1160
# class_index:872, Acc1 0.8198275862068966
# 1300
# Len of new dataset is :1300
# class_index:873, Acc1 0.9207692307692308
# 1300
# Len of new dataset is :1300
# class_index:874, Acc1 0.9307692307692308
# 1300
# Len of new dataset is :1300
# class_index:875, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:876, Acc1 0.5015384615384615
# 1300
# Len of new dataset is :1300
# class_index:877, Acc1 0.8923076923076924
# 1300
# Len of new dataset is :1300
# class_index:878, Acc1 0.7253846153846154
# 1300
# Len of new dataset is :1300
# class_index:879, Acc1 0.7530769230769231
# 1300
# Len of new dataset is :1300
# class_index:880, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:881, Acc1 0.8576923076923076
# 1300
# Len of new dataset is :1300
# class_index:882, Acc1 0.75
# 1300
# Len of new dataset is :1300
# class_index:883, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:884, Acc1 0.7792307692307693
# 1062
# Len of new dataset is :1062
# class_index:885, Acc1 0.4905838041431262
# 1300
# Len of new dataset is :1300
# class_index:886, Acc1 0.9123076923076923
# 1300
# Len of new dataset is :1300
# class_index:887, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:888, Acc1 0.916923076923077
# 1300
# Len of new dataset is :1300
# class_index:889, Acc1 0.7707692307692308
# 1300
# Len of new dataset is :1300
# class_index:890, Acc1 0.9238461538461539
# 1137
# Len of new dataset is :1137
# class_index:891, Acc1 0.8408091468777484
# 1299
# Len of new dataset is :1299
# class_index:892, Acc1 0.7428791377983064
# 1300
# Len of new dataset is :1300
# class_index:893, Acc1 0.7153846153846154
# 1300
# Len of new dataset is :1300
# class_index:894, Acc1 0.7915384615384615
# 1300
# Len of new dataset is :1300
# class_index:895, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:896, Acc1 0.7323076923076923
# 1300
# Len of new dataset is :1300
# class_index:897, Acc1 0.8707692307692307
# 1300
# Len of new dataset is :1300
# class_index:898, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:899, Acc1 0.36
# 1300
# Len of new dataset is :1300
# class_index:900, Acc1 0.9492307692307692
# 1055
# Len of new dataset is :1055
# class_index:901, Acc1 0.8218009478672986
# 1300
# Len of new dataset is :1300
# class_index:902, Acc1 0.583076923076923
# 1300
# Len of new dataset is :1300
# class_index:903, Acc1 0.7346153846153847
# 1300
# Len of new dataset is :1300
# class_index:904, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:905, Acc1 0.7469230769230769
# 1213
# Len of new dataset is :1213
# class_index:906, Acc1 0.6644682605111294
# 1300
# Len of new dataset is :1300
# class_index:907, Acc1 0.666923076923077
# 1300
# Len of new dataset is :1300
# class_index:908, Acc1 0.7561538461538462
# 1300
# Len of new dataset is :1300
# class_index:909, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:910, Acc1 0.6107692307692307
# 1300
# Len of new dataset is :1300
# class_index:911, Acc1 0.47384615384615386
# 1300
# Len of new dataset is :1300
# class_index:912, Acc1 0.7076923076923077
# 1300
# Len of new dataset is :1300
# class_index:913, Acc1 0.8146153846153846
# 1206
# Len of new dataset is :1206
# class_index:914, Acc1 0.8499170812603648
# 1300
# Len of new dataset is :1300
# class_index:915, Acc1 0.9384615384615385
# 1300
# Len of new dataset is :1300
# class_index:916, Acc1 0.9184615384615384
# 1300
# Len of new dataset is :1300
# class_index:917, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:918, Acc1 0.9061538461538462
# 1300
# Len of new dataset is :1300
# class_index:919, Acc1 0.8469230769230769
# 1300
# Len of new dataset is :1300
# class_index:920, Acc1 0.8946153846153846
# 1154
# Len of new dataset is :1154
# class_index:921, Acc1 0.6819757365684576
# 1300
# Len of new dataset is :1300
# class_index:922, Acc1 0.8707692307692307
# 1300
# Len of new dataset is :1300
# class_index:923, Acc1 0.6646153846153846
# 1300
# Len of new dataset is :1300
# class_index:924, Acc1 0.8884615384615384
# 1207
# Len of new dataset is :1207
# class_index:925, Acc1 0.7125103562551781
# 1149
# Len of new dataset is :1149
# class_index:926, Acc1 0.7885117493472585
# 1300
# Len of new dataset is :1300
# class_index:927, Acc1 0.8853846153846154
# 1300
# Len of new dataset is :1300
# class_index:928, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:929, Acc1 0.7407692307692307
# 1300
# Len of new dataset is :1300
# class_index:930, Acc1 0.7838461538461539
# 1300
# Len of new dataset is :1300
# class_index:931, Acc1 0.7976923076923077
# 1300
# Len of new dataset is :1300
# class_index:932, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:933, Acc1 0.9176923076923077
# 1300
# Len of new dataset is :1300
# class_index:934, Acc1 0.8753846153846154
# 1300
# Len of new dataset is :1300
# class_index:935, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:936, Acc1 0.8907692307692308
# 1300
# Len of new dataset is :1300
# class_index:937, Acc1 0.8830769230769231
# 1300
# Len of new dataset is :1300
# class_index:938, Acc1 0.8615384615384616
# 1300
# Len of new dataset is :1300
# class_index:939, Acc1 0.816923076923077
# 1239
# Len of new dataset is :1239
# class_index:940, Acc1 0.8240516545601292
# 1300
# Len of new dataset is :1300
# class_index:941, Acc1 0.86
# 1300
# Len of new dataset is :1300
# class_index:942, Acc1 0.8353846153846154
# 1300
# Len of new dataset is :1300
# class_index:943, Acc1 0.77
# 1300
# Len of new dataset is :1300
# class_index:944, Acc1 0.8638461538461538
# 1300
# Len of new dataset is :1300
# class_index:945, Acc1 0.9084615384615384
# 1125
# Len of new dataset is :1125
# class_index:946, Acc1 0.9404444444444444
# 1300
# Len of new dataset is :1300
# class_index:947, Acc1 0.6361538461538462
# 1300
# Len of new dataset is :1300
# class_index:948, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:949, Acc1 0.8915384615384615
# 1300
# Len of new dataset is :1300
# class_index:950, Acc1 0.8215384615384616
# 1300
# Len of new dataset is :1300
# class_index:951, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:952, Acc1 0.8769230769230769
# 1300
# Len of new dataset is :1300
# class_index:953, Acc1 0.9161538461538462
# 1300
# Len of new dataset is :1300
# class_index:954, Acc1 0.8461538461538461
# 1300
# Len of new dataset is :1300
# class_index:955, Acc1 0.943076923076923
# 1300
# Len of new dataset is :1300
# class_index:956, Acc1 0.9238461538461539
# 1300
# Len of new dataset is :1300
# class_index:957, Acc1 0.9161538461538462
# 1300
# Len of new dataset is :1300
# class_index:958, Acc1 0.9230769230769231
# 1300
# Len of new dataset is :1300
# class_index:959, Acc1 0.9276923076923077
# 1300
# Len of new dataset is :1300
# class_index:960, Acc1 0.7338461538461538
# 1300
# Len of new dataset is :1300
# class_index:961, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:962, Acc1 0.7815384615384615
# 1300
# Len of new dataset is :1300
# class_index:963, Acc1 0.9130769230769231
# 1300
# Len of new dataset is :1300
# class_index:964, Acc1 0.8238461538461539
# 1300
# Len of new dataset is :1300
# class_index:965, Acc1 0.8638461538461538
# 1300
# Len of new dataset is :1300
# class_index:966, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:967, Acc1 0.8446153846153847
# 1300
# Len of new dataset is :1300
# class_index:968, Acc1 0.5738461538461539
# 1193
# Len of new dataset is :1193
# class_index:969, Acc1 0.7393126571668064
# 1300
# Len of new dataset is :1300
# class_index:970, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:971, Acc1 0.8176923076923077
# 1300
# Len of new dataset is :1300
# class_index:972, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:973, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:974, Acc1 0.9607692307692308
# 1300
# Len of new dataset is :1300
# class_index:975, Acc1 0.6076923076923076
# 1300
# Len of new dataset is :1300
# class_index:976, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:977, Acc1 0.6330769230769231
# 1300
# Len of new dataset is :1300
# class_index:978, Acc1 0.5446153846153846
# 1300
# Len of new dataset is :1300
# class_index:979, Acc1 0.7838461538461539
# 1300
# Len of new dataset is :1300
# class_index:980, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:981, Acc1 0.8815384615384615
# 1300
# Len of new dataset is :1300
# class_index:982, Acc1 0.8584615384615385
# 1300
# Len of new dataset is :1300
# class_index:983, Acc1 0.9153846153846154
# 1300
# Len of new dataset is :1300
# class_index:984, Acc1 0.9723076923076923
# 1300
# Len of new dataset is :1300
# class_index:985, Acc1 0.9576923076923077
# 1300
# Len of new dataset is :1300
# class_index:986, Acc1 0.9869230769230769
# 1300
# Len of new dataset is :1300
# class_index:987, Acc1 0.49923076923076926
# 1300
# Len of new dataset is :1300
# class_index:988, Acc1 0.8807692307692307
# 1300
# Len of new dataset is :1300
# class_index:989, Acc1 0.9461538461538461
# 1300
# Len of new dataset is :1300
# class_index:990, Acc1 0.9207692307692308
# 1300
# Len of new dataset is :1300
# class_index:991, Acc1 0.9192307692307692
# 1300
# Len of new dataset is :1300
# class_index:992, Acc1 0.9238461538461539
# 1300
# Len of new dataset is :1300
# class_index:993, Acc1 0.9384615384615385
# 1300
# Len of new dataset is :1300
# class_index:994, Acc1 0.9007692307692308
# 1300
# Len of new dataset is :1300
# class_index:995, Acc1 0.8407692307692308
# 1300
# Len of new dataset is :1300
# class_index:996, Acc1 0.7323076923076923
# 1300
# Len of new dataset is :1300
# class_index:997, Acc1 0.8661538461538462
# 1300
# Len of new dataset is :1300
# class_index:998, Acc1 0.7407692307692307
# 1300
# Len of new dataset is :1300
# class_index:999, Acc1 0.71

# %%
RGB_gt_pred_acc = "./rgb_gt_pred_acc.pickle"
with open(RGB_gt_pred_acc, "wb") as handle:
    pickle.dump(class_y_true_y_pred_acc, handle)

# %%
np.mean([acc for _, _, acc in class_y_true_y_pred_acc.values()])
# Out:
# 0.8058819259092989

# %% [markdown]
# ## Load Gray Image

# %%
gray_class_y_true_y_pred_acc = {}
for class_index in range(1000):
    # Load data
    train_transform = transforms.Compose([                                                                                                                                
        transforms.Resize((224, 224), interpolation=Image.BILINEAR),                                                                                              
        transforms.Grayscale(num_output_channels=3),
        transforms.ToTensor(),                                                                                                                                            
        transforms.Normalize(mean, std)                                                                                                                                   
       ])         
    trainset = imagenet.ImageNet(root="/media/lincolnzjx/HardDisk/Datasets/", 
                                 is_train=True, transform=train_transform)
    len_specific_category = len(trainset.targets_imgs_dict[class_index])
    print(len_specific_category)
    trainset.set_data([class_index], len_specific_category)
    trainloader = torch.utils.data.DataLoader(trainset,
                                              batch_size=batch_size,
                                              shuffle=False,
                                              num_workers=num_workers,
                                              pin_memory=True)
    y_true, y_pred, acc = get_gt_pred_specific_class(trainloader)
    print("class_index:{}, Acc1 {}".format(class_index, acc))
    gray_class_y_true_y_pred_acc[class_index] = [y_true, y_pred, acc]
# Out:
# 1300
# Len of new dataset is :1300
# class_index:0, Acc1 0.3376923076923077
# 1300
# Len of new dataset is :1300
# class_index:1, Acc1 0.038461538461538464
# 1300
# Len of new dataset is :1300
# class_index:2, Acc1 0.6561538461538462
# 1300
# Len of new dataset is :1300
# class_index:3, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:4, Acc1 0.8084615384615385
# 1300
# Len of new dataset is :1300
# class_index:5, Acc1 0.5923076923076923
# 1300
# Len of new dataset is :1300
# class_index:6, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:7, Acc1 0.4623076923076923
# 1300
# Len of new dataset is :1300
# class_index:8, Acc1 0.49153846153846154
# 1300
# Len of new dataset is :1300
# class_index:9, Acc1 0.9138461538461539
# 1300
# Len of new dataset is :1300
# class_index:10, Acc1 0.3169230769230769
# 1300
# Len of new dataset is :1300
# class_index:11, Acc1 0.036153846153846154
# 1300
# Len of new dataset is :1300
# class_index:12, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:13, Acc1 0.8653846153846154
# 1300
# Len of new dataset is :1300
# class_index:14, Acc1 0.002307692307692308
# 1300
# Len of new dataset is :1300
# class_index:15, Acc1 0.1523076923076923
# 1300
# Len of new dataset is :1300
# class_index:16, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:17, Acc1 0.5246153846153846
# 1300
# Len of new dataset is :1300
# class_index:18, Acc1 0.823076923076923
# 1300
# Len of new dataset is :1300
# class_index:19, Acc1 0.8876923076923077
# 1300
# Len of new dataset is :1300
# class_index:20, Acc1 0.8092307692307692
# 1300
# Len of new dataset is :1300
# class_index:21, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:22, Acc1 0.7438461538461538
# 1300
# Len of new dataset is :1300
# class_index:23, Acc1 0.7061538461538461
# 1300
# Len of new dataset is :1300
# class_index:24, Acc1 0.9107692307692308
# 1300
# Len of new dataset is :1300
# class_index:25, Acc1 0.04153846153846154
# 1300
# Len of new dataset is :1300
# class_index:26, Acc1 0.34307692307692306
# 1300
# Len of new dataset is :1300
# class_index:27, Acc1 0.06461538461538462
# 1300
# Len of new dataset is :1300
# class_index:28, Acc1 0.7269230769230769
# 1300
# Len of new dataset is :1300
# class_index:29, Acc1 0.84
# 1300
# Len of new dataset is :1300
# class_index:30, Acc1 0.44076923076923075
# 1300
# Len of new dataset is :1300
# class_index:31, Acc1 0.38769230769230767
# 1300
# Len of new dataset is :1300
# class_index:32, Acc1 0.5907692307692308
# 1300
# Len of new dataset is :1300
# class_index:33, Acc1 0.4369230769230769
# 1300
# Len of new dataset is :1300
# class_index:34, Acc1 0.7176923076923077
# 1300
# Len of new dataset is :1300
# class_index:35, Acc1 0.5246153846153846
# 1300
# Len of new dataset is :1300
# class_index:36, Acc1 0.43846153846153846
# 1300
# Len of new dataset is :1300
# class_index:37, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:38, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:39, Acc1 0.7392307692307692
# 1300
# Len of new dataset is :1300
# class_index:40, Acc1 0.4815384615384615
# 1300
# Len of new dataset is :1300
# class_index:41, Acc1 0.7176923076923077
# 1300
# Len of new dataset is :1300
# class_index:42, Acc1 0.5638461538461539
# 1117
# Len of new dataset is :1117
# class_index:43, Acc1 0.6553267681289168
# 1300
# Len of new dataset is :1300
# class_index:44, Acc1 0.6484615384615384
# 1300
# Len of new dataset is :1300
# class_index:45, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:46, Acc1 0.02076923076923077
# 1300
# Len of new dataset is :1300
# class_index:47, Acc1 0.573076923076923
# 1300
# Len of new dataset is :1300
# class_index:48, Acc1 0.84
# 1300
# Len of new dataset is :1300
# class_index:49, Acc1 0.6746153846153846
# 1300
# Len of new dataset is :1300
# class_index:50, Acc1 0.4823076923076923
# 1266
# Len of new dataset is :1266
# class_index:51, Acc1 0.9107424960505529
# 1300
# Len of new dataset is :1300
# class_index:52, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:53, Acc1 0.48923076923076925
# 1300
# Len of new dataset is :1300
# class_index:54, Acc1 0.5169230769230769
# 1300
# Len of new dataset is :1300
# class_index:55, Acc1 0.031538461538461536
# 1300
# Len of new dataset is :1300
# class_index:56, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:57, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:58, Acc1 0.33076923076923076
# 1300
# Len of new dataset is :1300
# class_index:59, Acc1 0.3230769230769231
# 1300
# Len of new dataset is :1300
# class_index:60, Acc1 0.25846153846153846
# 1300
# Len of new dataset is :1300
# class_index:61, Acc1 0.69
# 1071
# Len of new dataset is :1071
# class_index:62, Acc1 0.353874883286648
# 1300
# Len of new dataset is :1300
# class_index:63, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:64, Acc1 0.08
# 1300
# Len of new dataset is :1300
# class_index:65, Acc1 0.5869230769230769
# 1300
# Len of new dataset is :1300
# class_index:66, Acc1 0.4207692307692308
# 1300
# Len of new dataset is :1300
# class_index:67, Acc1 0.7092307692307692
# 1300
# Len of new dataset is :1300
# class_index:68, Acc1 0.4753846153846154
# 1300
# Len of new dataset is :1300
# class_index:69, Acc1 0.9307692307692308
# 1300
# Len of new dataset is :1300
# class_index:70, Acc1 0.7838461538461539
# 1300
# Len of new dataset is :1300
# class_index:71, Acc1 0.7669230769230769
# 1300
# Len of new dataset is :1300
# class_index:72, Acc1 0.5792307692307692
# 1300
# Len of new dataset is :1300
# class_index:73, Acc1 0.5838461538461538
# 1300
# Len of new dataset is :1300
# class_index:74, Acc1 0.30153846153846153
# 1300
# Len of new dataset is :1300
# class_index:75, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:76, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:77, Acc1 0.6584615384615384
# 1300
# Len of new dataset is :1300
# class_index:78, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:79, Acc1 0.6330769230769231
# 1300
# Len of new dataset is :1300
# class_index:80, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:81, Acc1 0.7853846153846153
# 1300
# Len of new dataset is :1300
# class_index:82, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:83, Acc1 0.8292307692307692
# 1300
# Len of new dataset is :1300
# class_index:84, Acc1 0.3546153846153846
# 1300
# Len of new dataset is :1300
# class_index:85, Acc1 0.7538461538461538
# 1300
# Len of new dataset is :1300
# class_index:86, Acc1 0.49923076923076926
# 1300
# Len of new dataset is :1300
# class_index:87, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:88, Acc1 0.045384615384615384
# 1300
# Len of new dataset is :1300
# class_index:89, Acc1 0.8184615384615385
# 1300
# Len of new dataset is :1300
# class_index:90, Acc1 0.0007692307692307692
# 1300
# Len of new dataset is :1300
# class_index:91, Acc1 0.27307692307692305
# 1300
# Len of new dataset is :1300
# class_index:92, Acc1 0.2907692307692308
# 1300
# Len of new dataset is :1300
# class_index:93, Acc1 0.6484615384615384
# 1300
# Len of new dataset is :1300
# class_index:94, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:95, Acc1 0.25384615384615383
# 1300
# Len of new dataset is :1300
# class_index:96, Acc1 0.44153846153846155
# 1300
# Len of new dataset is :1300
# class_index:97, Acc1 0.56
# 1141
# Len of new dataset is :1141
# class_index:98, Acc1 0.7248028045574058
# 1300
# Len of new dataset is :1300
# class_index:99, Acc1 0.7276923076923076
# 1300
# Len of new dataset is :1300
# class_index:100, Acc1 0.7276923076923076
# 1300
# Len of new dataset is :1300
# class_index:101, Acc1 0.7115384615384616
# 1300
# Len of new dataset is :1300
# class_index:102, Acc1 0.8184615384615385
# 1272
# Len of new dataset is :1272
# class_index:103, Acc1 0.6312893081761006
# 1300
# Len of new dataset is :1300
# class_index:104, Acc1 0.73
# 1300
# Len of new dataset is :1300
# class_index:105, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:106, Acc1 0.8138461538461539
# 1300
# Len of new dataset is :1300
# class_index:107, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:108, Acc1 0.7553846153846154
# 1300
# Len of new dataset is :1300
# class_index:109, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:110, Acc1 0.5984615384615385
# 1300
# Len of new dataset is :1300
# class_index:111, Acc1 0.7923076923076923
# 1300
# Len of new dataset is :1300
# class_index:112, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:113, Acc1 0.5646153846153846
# 1300
# Len of new dataset is :1300
# class_index:114, Acc1 0.5046153846153846
# 1300
# Len of new dataset is :1300
# class_index:115, Acc1 0.3353846153846154
# 1300
# Len of new dataset is :1300
# class_index:116, Acc1 0.693076923076923
# 1300
# Len of new dataset is :1300
# class_index:117, Acc1 0.8953846153846153
# 1300
# Len of new dataset is :1300
# class_index:118, Acc1 0.45615384615384613
# 1300
# Len of new dataset is :1300
# class_index:119, Acc1 0.38769230769230767
# 1300
# Len of new dataset is :1300
# class_index:120, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:121, Acc1 0.2746153846153846
# 1300
# Len of new dataset is :1300
# class_index:122, Acc1 0.31076923076923074
# 1300
# Len of new dataset is :1300
# class_index:123, Acc1 0.6276923076923077
# 1300
# Len of new dataset is :1300
# class_index:124, Acc1 0.3507692307692308
# 1300
# Len of new dataset is :1300
# class_index:125, Acc1 0.6030769230769231
# 1300
# Len of new dataset is :1300
# class_index:126, Acc1 0.7338461538461538
# 1300
# Len of new dataset is :1300
# class_index:127, Acc1 0.6853846153846154
# 1300
# Len of new dataset is :1300
# class_index:128, Acc1 0.6530769230769231
# 1300
# Len of new dataset is :1300
# class_index:129, Acc1 0.7561538461538462
# 1300
# Len of new dataset is :1300
# class_index:130, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:131, Acc1 0.5284615384615384
# 1300
# Len of new dataset is :1300
# class_index:132, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:133, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:134, Acc1 0.5438461538461539
# 1300
# Len of new dataset is :1300
# class_index:135, Acc1 0.7738461538461539
# 1300
# Len of new dataset is :1300
# class_index:136, Acc1 0.08615384615384615
# 1300
# Len of new dataset is :1300
# class_index:137, Acc1 0.8238461538461539
# 1300
# Len of new dataset is :1300
# class_index:138, Acc1 0.8446153846153847
# 1300
# Len of new dataset is :1300
# class_index:139, Acc1 0.7823076923076923
# 1300
# Len of new dataset is :1300
# class_index:140, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:141, Acc1 0.3292307692307692
# 1300
# Len of new dataset is :1300
# class_index:142, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:143, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:144, Acc1 0.8607692307692307
# 1300
# Len of new dataset is :1300
# class_index:145, Acc1 0.8384615384615385
# 1300
# Len of new dataset is :1300
# class_index:146, Acc1 0.8807692307692307
# 1150
# Len of new dataset is :1150
# class_index:147, Acc1 0.7408695652173913
# 1300
# Len of new dataset is :1300
# class_index:148, Acc1 0.8792307692307693
# 1300
# Len of new dataset is :1300
# class_index:149, Acc1 0.7284615384615385
# 1300
# Len of new dataset is :1300
# class_index:150, Acc1 0.7076923076923077
# 1300
# Len of new dataset is :1300
# class_index:151, Acc1 0.5753846153846154
# 772
# Len of new dataset is :772
# class_index:152, Acc1 0.7849740932642487
# 1300
# Len of new dataset is :1300
# class_index:153, Acc1 0.8438461538461538
# 1300
# Len of new dataset is :1300
# class_index:154, Acc1 0.7561538461538462
# 1300
# Len of new dataset is :1300
# class_index:155, Acc1 0.6653846153846154
# 1300
# Len of new dataset is :1300
# class_index:156, Acc1 0.6138461538461538
# 1300
# Len of new dataset is :1300
# class_index:157, Acc1 0.8292307692307692
# 860
# Len of new dataset is :860
# class_index:158, Acc1 0.55
# 1300
# Len of new dataset is :1300
# class_index:159, Acc1 0.13307692307692306
# 1300
# Len of new dataset is :1300
# class_index:160, Acc1 0.8107692307692308
# 1300
# Len of new dataset is :1300
# class_index:161, Acc1 0.7123076923076923
# 1300
# Len of new dataset is :1300
# class_index:162, Acc1 0.5753846153846154
# 1300
# Len of new dataset is :1300
# class_index:163, Acc1 0.5776923076923077
# 1136
# Len of new dataset is :1136
# class_index:164, Acc1 0.6954225352112676
# 732
# Len of new dataset is :732
# class_index:165, Acc1 0.39344262295081966
# 1025
# Len of new dataset is :1025
# class_index:166, Acc1 0.5063414634146342
# 754
# Len of new dataset is :754
# class_index:167, Acc1 0.2612732095490716
# 1290
# Len of new dataset is :1290
# class_index:168, Acc1 0.06124031007751938
# 1300
# Len of new dataset is :1300
# class_index:169, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:170, Acc1 0.5892307692307692
# 1300
# Len of new dataset is :1300
# class_index:171, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:172, Acc1 0.5976923076923077
# 1300
# Len of new dataset is :1300
# class_index:173, Acc1 0.3069230769230769
# 1300
# Len of new dataset is :1300
# class_index:174, Acc1 0.7838461538461539
# 738
# Len of new dataset is :738
# class_index:175, Acc1 0.41192411924119243
# 1300
# Len of new dataset is :1300
# class_index:176, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:177, Acc1 0.6646153846153846
# 1300
# Len of new dataset is :1300
# class_index:178, Acc1 0.8261538461538461
# 1300
# Len of new dataset is :1300
# class_index:179, Acc1 0.5776923076923077
# 1300
# Len of new dataset is :1300
# class_index:180, Acc1 0.4869230769230769
# 1258
# Len of new dataset is :1258
# class_index:181, Acc1 0.8275039745627981
# 1300
# Len of new dataset is :1300
# class_index:182, Acc1 0.5761538461538461
# 1273
# Len of new dataset is :1273
# class_index:183, Acc1 0.7784760408483896
# 1300
# Len of new dataset is :1300
# class_index:184, Acc1 0.13692307692307693
# 1300
# Len of new dataset is :1300
# class_index:185, Acc1 0.2784615384615385
# 1300
# Len of new dataset is :1300
# class_index:186, Acc1 0.32846153846153847
# 1300
# Len of new dataset is :1300
# class_index:187, Acc1 0.4169230769230769
# 977
# Len of new dataset is :977
# class_index:188, Acc1 0.6079836233367452
# 1300
# Len of new dataset is :1300
# class_index:189, Acc1 0.41307692307692306
# 936
# Len of new dataset is :936
# class_index:190, Acc1 0.7980769230769231
# 1300
# Len of new dataset is :1300
# class_index:191, Acc1 0.17923076923076922
# 1300
# Len of new dataset is :1300
# class_index:192, Acc1 0.6323076923076923
# 1300
# Len of new dataset is :1300
# class_index:193, Acc1 0.15615384615384614
# 1156
# Len of new dataset is :1156
# class_index:194, Acc1 0.7603806228373703
# 1300
# Len of new dataset is :1300
# class_index:195, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:196, Acc1 0.6653846153846154
# 1300
# Len of new dataset is :1300
# class_index:197, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:198, Acc1 0.5646153846153846
# 1300
# Len of new dataset is :1300
# class_index:199, Acc1 0.7938461538461539
# 1300
# Len of new dataset is :1300
# class_index:200, Acc1 0.66
# 1300
# Len of new dataset is :1300
# class_index:201, Acc1 0.4276923076923077
# 1300
# Len of new dataset is :1300
# class_index:202, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:203, Acc1 0.8292307692307692
# 1300
# Len of new dataset is :1300
# class_index:204, Acc1 0.5607692307692308
# 1300
# Len of new dataset is :1300
# class_index:205, Acc1 0.7161538461538461
# 1218
# Len of new dataset is :1218
# class_index:206, Acc1 0.7701149425287356
# 1300
# Len of new dataset is :1300
# class_index:207, Acc1 0.49153846153846154
# 1300
# Len of new dataset is :1300
# class_index:208, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:209, Acc1 0.41923076923076924
# 1300
# Len of new dataset is :1300
# class_index:210, Acc1 0.6692307692307692
# 1300
# Len of new dataset is :1300
# class_index:211, Acc1 0.10230769230769231
# 1300
# Len of new dataset is :1300
# class_index:212, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:213, Acc1 0.14384615384615385
# 1300
# Len of new dataset is :1300
# class_index:214, Acc1 0.23461538461538461
# 1300
# Len of new dataset is :1300
# class_index:215, Acc1 0.09769230769230769
# 1300
# Len of new dataset is :1300
# class_index:216, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:217, Acc1 0.7676923076923077
# 1300
# Len of new dataset is :1300
# class_index:218, Acc1 0.14846153846153845
# 1300
# Len of new dataset is :1300
# class_index:219, Acc1 0.6761538461538461
# 1300
# Len of new dataset is :1300
# class_index:220, Acc1 0.6646153846153846
# 969
# Len of new dataset is :969
# class_index:221, Acc1 0.6408668730650154
# 1300
# Len of new dataset is :1300
# class_index:222, Acc1 0.7353846153846154
# 1300
# Len of new dataset is :1300
# class_index:223, Acc1 0.7407692307692307
# 1300
# Len of new dataset is :1300
# class_index:224, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:225, Acc1 0.3553846153846154
# 1300
# Len of new dataset is :1300
# class_index:226, Acc1 0.5315384615384615
# 1300
# Len of new dataset is :1300
# class_index:227, Acc1 0.5592307692307692
# 1300
# Len of new dataset is :1300
# class_index:228, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:229, Acc1 0.813076923076923
# 1300
# Len of new dataset is :1300
# class_index:230, Acc1 0.5438461538461539
# 1300
# Len of new dataset is :1300
# class_index:231, Acc1 0.44076923076923075
# 1300
# Len of new dataset is :1300
# class_index:232, Acc1 0.7076923076923077
# 1300
# Len of new dataset is :1300
# class_index:233, Acc1 0.7315384615384616
# 1300
# Len of new dataset is :1300
# class_index:234, Acc1 0.27615384615384614
# 1300
# Len of new dataset is :1300
# class_index:235, Acc1 0.6276923076923077
# 1300
# Len of new dataset is :1300
# class_index:236, Acc1 0.3423076923076923
# 1300
# Len of new dataset is :1300
# class_index:237, Acc1 0.4107692307692308
# 1300
# Len of new dataset is :1300
# class_index:238, Acc1 0.5
# 1300
# Len of new dataset is :1300
# class_index:239, Acc1 0.4269230769230769
# 1300
# Len of new dataset is :1300
# class_index:240, Acc1 0.2784615384615385
# 1300
# Len of new dataset is :1300
# class_index:241, Acc1 0.34615384615384615
# 1300
# Len of new dataset is :1300
# class_index:242, Acc1 0.4107692307692308
# 1300
# Len of new dataset is :1300
# class_index:243, Acc1 0.6792307692307692
# 1300
# Len of new dataset is :1300
# class_index:244, Acc1 0.7753846153846153
# 1300
# Len of new dataset is :1300
# class_index:245, Acc1 0.7446153846153846
# 1300
# Len of new dataset is :1300
# class_index:246, Acc1 0.7038461538461539
# 1300
# Len of new dataset is :1300
# class_index:247, Acc1 0.7584615384615384
# 1300
# Len of new dataset is :1300
# class_index:248, Acc1 0.43846153846153846
# 1300
# Len of new dataset is :1300
# class_index:249, Acc1 0.6946153846153846
# 1300
# Len of new dataset is :1300
# class_index:250, Acc1 0.51
# 1300
# Len of new dataset is :1300
# class_index:251, Acc1 0.9223076923076923
# 954
# Len of new dataset is :954
# class_index:252, Acc1 0.7683438155136268
# 1300
# Len of new dataset is :1300
# class_index:253, Acc1 0.42615384615384616
# 1300
# Len of new dataset is :1300
# class_index:254, Acc1 0.8023076923076923
# 1300
# Len of new dataset is :1300
# class_index:255, Acc1 0.6184615384615385
# 1300
# Len of new dataset is :1300
# class_index:256, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:257, Acc1 0.6984615384615385
# 1300
# Len of new dataset is :1300
# class_index:258, Acc1 0.8769230769230769
# 1300
# Len of new dataset is :1300
# class_index:259, Acc1 0.6961538461538461
# 1300
# Len of new dataset is :1300
# class_index:260, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:261, Acc1 0.8538461538461538
# 1070
# Len of new dataset is :1070
# class_index:262, Acc1 0.4102803738317757
# 1300
# Len of new dataset is :1300
# class_index:263, Acc1 0.41
# 1300
# Len of new dataset is :1300
# class_index:264, Acc1 0.5892307692307692
# 1300
# Len of new dataset is :1300
# class_index:265, Acc1 0.46384615384615385
# 1300
# Len of new dataset is :1300
# class_index:266, Acc1 0.4553846153846154
# 1300
# Len of new dataset is :1300
# class_index:267, Acc1 0.6823076923076923
# 755
# Len of new dataset is :755
# class_index:268, Acc1 0.7735099337748345
# 1300
# Len of new dataset is :1300
# class_index:269, Acc1 0.6615384615384615
# 1300
# Len of new dataset is :1300
# class_index:270, Acc1 0.7715384615384615
# 1300
# Len of new dataset is :1300
# class_index:271, Acc1 0.3484615384615385
# 1300
# Len of new dataset is :1300
# class_index:272, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:273, Acc1 0.4553846153846154
# 1300
# Len of new dataset is :1300
# class_index:274, Acc1 0.14846153846153845
# 1300
# Len of new dataset is :1300
# class_index:275, Acc1 0.7923076923076923
# 1300
# Len of new dataset is :1300
# class_index:276, Acc1 0.7961538461538461
# 1300
# Len of new dataset is :1300
# class_index:277, Acc1 0.22538461538461538
# 1300
# Len of new dataset is :1300
# class_index:278, Acc1 0.5269230769230769
# 1300
# Len of new dataset is :1300
# class_index:279, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:280, Acc1 0.56
# 1300
# Len of new dataset is :1300
# class_index:281, Acc1 0.5638461538461539
# 1300
# Len of new dataset is :1300
# class_index:282, Acc1 0.2469230769230769
# 1300
# Len of new dataset is :1300
# class_index:283, Acc1 0.8430769230769231
# 1300
# Len of new dataset is :1300
# class_index:284, Acc1 0.8553846153846154
# 1300
# Len of new dataset is :1300
# class_index:285, Acc1 0.7353846153846154
# 1300
# Len of new dataset is :1300
# class_index:286, Acc1 0.7346153846153847
# 1300
# Len of new dataset is :1300
# class_index:287, Acc1 0.6361538461538462
# 1300
# Len of new dataset is :1300
# class_index:288, Acc1 0.7469230769230769
# 1300
# Len of new dataset is :1300
# class_index:289, Acc1 0.926923076923077
# 1300
# Len of new dataset is :1300
# class_index:290, Acc1 0.5984615384615385
# 1300
# Len of new dataset is :1300
# class_index:291, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:292, Acc1 0.8323076923076923
# 1300
# Len of new dataset is :1300
# class_index:293, Acc1 0.7846153846153846
# 1300
# Len of new dataset is :1300
# class_index:294, Acc1 0.7438461538461538
# 1300
# Len of new dataset is :1300
# class_index:295, Acc1 0.7246153846153847
# 1300
# Len of new dataset is :1300
# class_index:296, Acc1 0.8738461538461538
# 1300
# Len of new dataset is :1300
# class_index:297, Acc1 0.7961538461538461
# 1300
# Len of new dataset is :1300
# class_index:298, Acc1 0.553076923076923
# 1300
# Len of new dataset is :1300
# class_index:299, Acc1 0.8561538461538462
# 1300
# Len of new dataset is :1300
# class_index:300, Acc1 0.6323076923076923
# 1300
# Len of new dataset is :1300
# class_index:301, Acc1 0.31076923076923074
# 1300
# Len of new dataset is :1300
# class_index:302, Acc1 0.7076923076923077
# 1300
# Len of new dataset is :1300
# class_index:303, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:304, Acc1 0.07307692307692308
# 1300
# Len of new dataset is :1300
# class_index:305, Acc1 0.7369230769230769
# 1300
# Len of new dataset is :1300
# class_index:306, Acc1 0.7776923076923077
# 1300
# Len of new dataset is :1300
# class_index:307, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:308, Acc1 0.7861538461538462
# 1300
# Len of new dataset is :1300
# class_index:309, Acc1 0.3953846153846154
# 1300
# Len of new dataset is :1300
# class_index:310, Acc1 0.5715384615384616
# 1300
# Len of new dataset is :1300
# class_index:311, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:312, Acc1 0.4153846153846154
# 1300
# Len of new dataset is :1300
# class_index:313, Acc1 0.5923076923076923
# 1300
# Len of new dataset is :1300
# class_index:314, Acc1 0.48384615384615387
# 1300
# Len of new dataset is :1300
# class_index:315, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:316, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:317, Acc1 0.44384615384615383
# 1300
# Len of new dataset is :1300
# class_index:318, Acc1 0.7423076923076923
# 1300
# Len of new dataset is :1300
# class_index:319, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:320, Acc1 0.5292307692307693
# 1300
# Len of new dataset is :1300
# class_index:321, Acc1 0.7892307692307692
# 1300
# Len of new dataset is :1300
# class_index:322, Acc1 0.7084615384615385
# 1300
# Len of new dataset is :1300
# class_index:323, Acc1 0.786923076923077
# 1300
# Len of new dataset is :1300
# class_index:324, Acc1 0.9007692307692308
# 1300
# Len of new dataset is :1300
# class_index:325, Acc1 0.04384615384615385
# 1300
# Len of new dataset is :1300
# class_index:326, Acc1 0.84
# 1300
# Len of new dataset is :1300
# class_index:327, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:328, Acc1 0.83
# 1300
# Len of new dataset is :1300
# class_index:329, Acc1 0.49153846153846154
# 1300
# Len of new dataset is :1300
# class_index:330, Acc1 0.7592307692307693
# 1300
# Len of new dataset is :1300
# class_index:331, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:332, Acc1 0.8376923076923077
# 1300
# Len of new dataset is :1300
# class_index:333, Acc1 0.7938461538461539
# 1300
# Len of new dataset is :1300
# class_index:334, Acc1 0.8692307692307693
# 1206
# Len of new dataset is :1206
# class_index:335, Acc1 0.5514096185737977
# 1300
# Len of new dataset is :1300
# class_index:336, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:337, Acc1 0.5853846153846154
# 1300
# Len of new dataset is :1300
# class_index:338, Acc1 0.5992307692307692
# 1300
# Len of new dataset is :1300
# class_index:339, Acc1 0.4523076923076923
# 1300
# Len of new dataset is :1300
# class_index:340, Acc1 0.9607692307692308
# 1300
# Len of new dataset is :1300
# class_index:341, Acc1 0.5038461538461538
# 1300
# Len of new dataset is :1300
# class_index:342, Acc1 0.6607692307692308
# 1300
# Len of new dataset is :1300
# class_index:343, Acc1 0.8061538461538461
# 1300
# Len of new dataset is :1300
# class_index:344, Acc1 0.7623076923076924
# 1300
# Len of new dataset is :1300
# class_index:345, Acc1 0.5430769230769231
# 1300
# Len of new dataset is :1300
# class_index:346, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:347, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:348, Acc1 0.5638461538461539
# 1300
# Len of new dataset is :1300
# class_index:349, Acc1 0.7784615384615384
# 1300
# Len of new dataset is :1300
# class_index:350, Acc1 0.77
# 1300
# Len of new dataset is :1300
# class_index:351, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:352, Acc1 0.4576923076923077
# 1300
# Len of new dataset is :1300
# class_index:353, Acc1 0.7484615384615385
# 1300
# Len of new dataset is :1300
# class_index:354, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:355, Acc1 0.7830769230769231
# 1300
# Len of new dataset is :1300
# class_index:356, Acc1 0.4115384615384615
# 1300
# Len of new dataset is :1300
# class_index:357, Acc1 0.5938461538461538
# 1300
# Len of new dataset is :1300
# class_index:358, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:359, Acc1 0.546923076923077
# 1300
# Len of new dataset is :1300
# class_index:360, Acc1 0.73
# 1300
# Len of new dataset is :1300
# class_index:361, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:362, Acc1 0.8315384615384616
# 1300
# Len of new dataset is :1300
# class_index:363, Acc1 0.8876923076923077
# 1300
# Len of new dataset is :1300
# class_index:364, Acc1 0.6976923076923077
# 1300
# Len of new dataset is :1300
# class_index:365, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:366, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:367, Acc1 0.6461538461538462
# 1300
# Len of new dataset is :1300
# class_index:368, Acc1 0.7161538461538461
# 1300
# Len of new dataset is :1300
# class_index:369, Acc1 0.6092307692307692
# 1300
# Len of new dataset is :1300
# class_index:370, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:371, Acc1 0.2907692307692308
# 1300
# Len of new dataset is :1300
# class_index:372, Acc1 0.7253846153846154
# 1300
# Len of new dataset is :1300
# class_index:373, Acc1 0.5092307692307693
# 1300
# Len of new dataset is :1300
# class_index:374, Acc1 0.7261538461538461
# 1300
# Len of new dataset is :1300
# class_index:375, Acc1 0.7569230769230769
# 1300
# Len of new dataset is :1300
# class_index:376, Acc1 0.45076923076923076
# 1300
# Len of new dataset is :1300
# class_index:377, Acc1 0.5592307692307692
# 1300
# Len of new dataset is :1300
# class_index:378, Acc1 0.5784615384615385
# 1300
# Len of new dataset is :1300
# class_index:379, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:380, Acc1 0.2376923076923077
# 1300
# Len of new dataset is :1300
# class_index:381, Acc1 0.3792307692307692
# 1300
# Len of new dataset is :1300
# class_index:382, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:383, Acc1 0.7069230769230769
# 1300
# Len of new dataset is :1300
# class_index:384, Acc1 0.6730769230769231
# 1300
# Len of new dataset is :1300
# class_index:385, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:386, Acc1 0.5238461538461539
# 1300
# Len of new dataset is :1300
# class_index:387, Acc1 0.5392307692307692
# 1300
# Len of new dataset is :1300
# class_index:388, Acc1 0.95
# 1300
# Len of new dataset is :1300
# class_index:389, Acc1 0.5238461538461539
# 1165
# Len of new dataset is :1165
# class_index:390, Acc1 0.42145922746781117
# 1300
# Len of new dataset is :1300
# class_index:391, Acc1 0.676923076923077
# 969
# Len of new dataset is :969
# class_index:392, Acc1 0.35500515995872034
# 1300
# Len of new dataset is :1300
# class_index:393, Acc1 0.5446153846153846
# 1300
# Len of new dataset is :1300
# class_index:394, Acc1 0.7384615384615385
# 1300
# Len of new dataset is :1300
# class_index:395, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:396, Acc1 0.8615384615384616
# 1300
# Len of new dataset is :1300
# class_index:397, Acc1 0.72
# 1300
# Len of new dataset is :1300
# class_index:398, Acc1 0.7730769230769231
# 1300
# Len of new dataset is :1300
# class_index:399, Acc1 0.7946153846153846
# 1300
# Len of new dataset is :1300
# class_index:400, Acc1 0.6692307692307692
# 1300
# Len of new dataset is :1300
# class_index:401, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:402, Acc1 0.7653846153846153
# 1300
# Len of new dataset is :1300
# class_index:403, Acc1 0.9161538461538462
# 1300
# Len of new dataset is :1300
# class_index:404, Acc1 0.8430769230769231
# 1300
# Len of new dataset is :1300
# class_index:405, Acc1 0.9346153846153846
# 1300
# Len of new dataset is :1300
# class_index:406, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:407, Acc1 0.26461538461538464
# 1300
# Len of new dataset is :1300
# class_index:408, Acc1 0.7261538461538461
# 1292
# Len of new dataset is :1292
# class_index:409, Acc1 0.6253869969040248
# 1300
# Len of new dataset is :1300
# class_index:410, Acc1 0.7369230769230769
# 1300
# Len of new dataset is :1300
# class_index:411, Acc1 0.47923076923076924
# 1300
# Len of new dataset is :1300
# class_index:412, Acc1 0.5546153846153846
# 1300
# Len of new dataset is :1300
# class_index:413, Acc1 0.6123076923076923
# 1300
# Len of new dataset is :1300
# class_index:414, Acc1 0.713076923076923
# 1300
# Len of new dataset is :1300
# class_index:415, Acc1 0.21076923076923076
# 1300
# Len of new dataset is :1300
# class_index:416, Acc1 0.7169230769230769
# 1300
# Len of new dataset is :1300
# class_index:417, Acc1 0.6746153846153846
# 1236
# Len of new dataset is :1236
# class_index:418, Acc1 0.5250809061488673
# 1300
# Len of new dataset is :1300
# class_index:419, Acc1 0.36846153846153845
# 1300
# Len of new dataset is :1300
# class_index:420, Acc1 0.7907692307692308
# 1300
# Len of new dataset is :1300
# class_index:421, Acc1 0.6661538461538462
# 1300
# Len of new dataset is :1300
# class_index:422, Acc1 0.8153846153846154
# 1300
# Len of new dataset is :1300
# class_index:423, Acc1 0.7546153846153846
# 1300
# Len of new dataset is :1300
# class_index:424, Acc1 0.7776923076923077
# 1300
# Len of new dataset is :1300
# class_index:425, Acc1 0.8776923076923077
# 1199
# Len of new dataset is :1199
# class_index:426, Acc1 0.7781484570475397
# 1300
# Len of new dataset is :1300
# class_index:427, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:428, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:429, Acc1 0.6738461538461539
# 1300
# Len of new dataset is :1300
# class_index:430, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:431, Acc1 0.7823076923076923
# 1300
# Len of new dataset is :1300
# class_index:432, Acc1 0.7015384615384616
# 1300
# Len of new dataset is :1300
# class_index:433, Acc1 0.5346153846153846
# 1300
# Len of new dataset is :1300
# class_index:434, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:435, Acc1 0.6469230769230769
# 1300
# Len of new dataset is :1300
# class_index:436, Acc1 0.7076923076923077
# 1300
# Len of new dataset is :1300
# class_index:437, Acc1 0.8630769230769231
# 1300
# Len of new dataset is :1300
# class_index:438, Acc1 0.7823076923076923
# 1209
# Len of new dataset is :1209
# class_index:439, Acc1 0.7154673283705542
# 1300
# Len of new dataset is :1300
# class_index:440, Acc1 0.5353846153846153
# 1300
# Len of new dataset is :1300
# class_index:441, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:442, Acc1 0.6030769230769231
# 1300
# Len of new dataset is :1300
# class_index:443, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:444, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:445, Acc1 0.5738461538461539
# 1300
# Len of new dataset is :1300
# class_index:446, Acc1 0.6130769230769231
# 1300
# Len of new dataset is :1300
# class_index:447, Acc1 0.7207692307692307
# 1300
# Len of new dataset is :1300
# class_index:448, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:449, Acc1 0.7230769230769231
# 1300
# Len of new dataset is :1300
# class_index:450, Acc1 0.8053846153846154
# 1300
# Len of new dataset is :1300
# class_index:451, Acc1 0.7638461538461538
# 1300
# Len of new dataset is :1300
# class_index:452, Acc1 0.686923076923077
# 1300
# Len of new dataset is :1300
# class_index:453, Acc1 0.6107692307692307
# 1300
# Len of new dataset is :1300
# class_index:454, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:455, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:456, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:457, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:458, Acc1 0.8361538461538461
# 1300
# Len of new dataset is :1300
# class_index:459, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:460, Acc1 0.7153846153846154
# 1300
# Len of new dataset is :1300
# class_index:461, Acc1 0.4523076923076923
# 1300
# Len of new dataset is :1300
# class_index:462, Acc1 0.6253846153846154
# 1300
# Len of new dataset is :1300
# class_index:463, Acc1 0.5069230769230769
# 1300
# Len of new dataset is :1300
# class_index:464, Acc1 0.5823076923076923
# 1176
# Len of new dataset is :1176
# class_index:465, Acc1 0.7704081632653061
# 1300
# Len of new dataset is :1300
# class_index:466, Acc1 0.9569230769230769
# 1300
# Len of new dataset is :1300
# class_index:467, Acc1 0.46
# 1300
# Len of new dataset is :1300
# class_index:468, Acc1 0.4584615384615385
# 1300
# Len of new dataset is :1300
# class_index:469, Acc1 0.6523076923076923
# 1300
# Len of new dataset is :1300
# class_index:470, Acc1 0.46923076923076923
# 1300
# Len of new dataset is :1300
# class_index:471, Acc1 0.8161538461538461
# 1300
# Len of new dataset is :1300
# class_index:472, Acc1 0.5507692307692308
# 1300
# Len of new dataset is :1300
# class_index:473, Acc1 0.553076923076923
# 1300
# Len of new dataset is :1300
# class_index:474, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:475, Acc1 0.9338461538461539
# 1300
# Len of new dataset is :1300
# class_index:476, Acc1 0.8046153846153846
# 1300
# Len of new dataset is :1300
# class_index:477, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:478, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:479, Acc1 0.6846153846153846
# 1300
# Len of new dataset is :1300
# class_index:480, Acc1 0.78
# 1186
# Len of new dataset is :1186
# class_index:481, Acc1 0.7293423271500843
# 1300
# Len of new dataset is :1300
# class_index:482, Acc1 0.43923076923076926
# 1300
# Len of new dataset is :1300
# class_index:483, Acc1 0.8284615384615385
# 1300
# Len of new dataset is :1300
# class_index:484, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:485, Acc1 0.5815384615384616
# 1300
# Len of new dataset is :1300
# class_index:486, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:487, Acc1 0.6223076923076923
# 1300
# Len of new dataset is :1300
# class_index:488, Acc1 0.5984615384615385
# 1300
# Len of new dataset is :1300
# class_index:489, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:490, Acc1 0.76
# 1194
# Len of new dataset is :1194
# class_index:491, Acc1 0.48408710217755446
# 1300
# Len of new dataset is :1300
# class_index:492, Acc1 0.5792307692307692
# 1300
# Len of new dataset is :1300
# class_index:493, Acc1 0.7153846153846154
# 1300
# Len of new dataset is :1300
# class_index:494, Acc1 0.5330769230769231
# 1300
# Len of new dataset is :1300
# class_index:495, Acc1 0.7769230769230769
# 1300
# Len of new dataset is :1300
# class_index:496, Acc1 0.4076923076923077
# 1300
# Len of new dataset is :1300
# class_index:497, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:498, Acc1 0.7661538461538462
# 1067
# Len of new dataset is :1067
# class_index:499, Acc1 0.5388940955951266
# 1300
# Len of new dataset is :1300
# class_index:500, Acc1 0.8407692307692308
# 1029
# Len of new dataset is :1029
# class_index:501, Acc1 0.6044703595724004
# 1300
# Len of new dataset is :1300
# class_index:502, Acc1 0.3861538461538462
# 1154
# Len of new dataset is :1154
# class_index:503, Acc1 0.7322357019064125
# 1300
# Len of new dataset is :1300
# class_index:504, Acc1 0.6530769230769231
# 1300
# Len of new dataset is :1300
# class_index:505, Acc1 0.6915384615384615
# 1300
# Len of new dataset is :1300
# class_index:506, Acc1 0.7307692307692307
# 1216
# Len of new dataset is :1216
# class_index:507, Acc1 0.7269736842105263
# 1300
# Len of new dataset is :1300
# class_index:508, Acc1 0.7307692307692307
# 1300
# Len of new dataset is :1300
# class_index:509, Acc1 0.29923076923076924
# 1300
# Len of new dataset is :1300
# class_index:510, Acc1 0.7184615384615385
# 1300
# Len of new dataset is :1300
# class_index:511, Acc1 0.7761538461538462
# 1300
# Len of new dataset is :1300
# class_index:512, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:513, Acc1 0.6746153846153846
# 1300
# Len of new dataset is :1300
# class_index:514, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:515, Acc1 0.6784615384615384
# 1300
# Len of new dataset is :1300
# class_index:516, Acc1 0.5623076923076923
# 1300
# Len of new dataset is :1300
# class_index:517, Acc1 0.7415384615384616
# 1300
# Len of new dataset is :1300
# class_index:518, Acc1 0.6646153846153846
# 1300
# Len of new dataset is :1300
# class_index:519, Acc1 0.5907692307692308
# 1300
# Len of new dataset is :1300
# class_index:520, Acc1 0.7292307692307692
# 1187
# Len of new dataset is :1187
# class_index:521, Acc1 0.8053917438921652
# 1300
# Len of new dataset is :1300
# class_index:522, Acc1 0.3223076923076923
# 1300
# Len of new dataset is :1300
# class_index:523, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:524, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:525, Acc1 0.8546153846153847
# 1300
# Len of new dataset is :1300
# class_index:526, Acc1 0.6146153846153846
# 1300
# Len of new dataset is :1300
# class_index:527, Acc1 0.683076923076923
# 1300
# Len of new dataset is :1300
# class_index:528, Acc1 0.8423076923076923
# 1300
# Len of new dataset is :1300
# class_index:529, Acc1 0.5353846153846153
# 1300
# Len of new dataset is :1300
# class_index:530, Acc1 0.6430769230769231
# 889
# Len of new dataset is :889
# class_index:531, Acc1 0.7637795275590551
# 1300
# Len of new dataset is :1300
# class_index:532, Acc1 0.7430769230769231
# 1300
# Len of new dataset is :1300
# class_index:533, Acc1 0.7146153846153847
# 1300
# Len of new dataset is :1300
# class_index:534, Acc1 0.7715384615384615
# 1300
# Len of new dataset is :1300
# class_index:535, Acc1 0.8238461538461539
# 1211
# Len of new dataset is :1211
# class_index:536, Acc1 0.6184971098265896
# 1300
# Len of new dataset is :1300
# class_index:537, Acc1 0.8715384615384615
# 1300
# Len of new dataset is :1300
# class_index:538, Acc1 0.6861538461538461
# 1300
# Len of new dataset is :1300
# class_index:539, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:540, Acc1 0.8346153846153846
# 1300
# Len of new dataset is :1300
# class_index:541, Acc1 0.5446153846153846
# 1300
# Len of new dataset is :1300
# class_index:542, Acc1 0.5207692307692308
# 1300
# Len of new dataset is :1300
# class_index:543, Acc1 0.7323076923076923
# 1300
# Len of new dataset is :1300
# class_index:544, Acc1 0.7192307692307692
# 1300
# Len of new dataset is :1300
# class_index:545, Acc1 0.8123076923076923
# 1300
# Len of new dataset is :1300
# class_index:546, Acc1 0.7623076923076924
# 1300
# Len of new dataset is :1300
# class_index:547, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:548, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:549, Acc1 0.59
# 1136
# Len of new dataset is :1136
# class_index:550, Acc1 0.8169014084507042
# 1153
# Len of new dataset is :1153
# class_index:551, Acc1 0.5533391153512576
# 1300
# Len of new dataset is :1300
# class_index:552, Acc1 0.7115384615384616
# 1300
# Len of new dataset is :1300
# class_index:553, Acc1 0.71
# 1300
# Len of new dataset is :1300
# class_index:554, Acc1 0.6946153846153846
# 1300
# Len of new dataset is :1300
# class_index:555, Acc1 0.4115384615384615
# 1300
# Len of new dataset is :1300
# class_index:556, Acc1 0.6815384615384615
# 1300
# Len of new dataset is :1300
# class_index:557, Acc1 0.6653846153846154
# 1300
# Len of new dataset is :1300
# class_index:558, Acc1 0.4707692307692308
# 1300
# Len of new dataset is :1300
# class_index:559, Acc1 0.7492307692307693
# 1300
# Len of new dataset is :1300
# class_index:560, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:561, Acc1 0.8507692307692307
# 1300
# Len of new dataset is :1300
# class_index:562, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:563, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:564, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:565, Acc1 0.8492307692307692
# 1300
# Len of new dataset is :1300
# class_index:566, Acc1 0.79
# 1222
# Len of new dataset is :1222
# class_index:567, Acc1 0.5368248772504092
# 1300
# Len of new dataset is :1300
# class_index:568, Acc1 0.7684615384615384
# 1300
# Len of new dataset is :1300
# class_index:569, Acc1 0.78
# 1300
# Len of new dataset is :1300
# class_index:570, Acc1 0.7438461538461538
# 1300
# Len of new dataset is :1300
# class_index:571, Acc1 0.82
# 1300
# Len of new dataset is :1300
# class_index:572, Acc1 0.7846153846153846
# 1300
# Len of new dataset is :1300
# class_index:573, Acc1 0.8415384615384616
# 1300
# Len of new dataset is :1300
# class_index:574, Acc1 0.8830769230769231
# 1300
# Len of new dataset is :1300
# class_index:575, Acc1 0.8969230769230769
# 1300
# Len of new dataset is :1300
# class_index:576, Acc1 0.9523076923076923
# 1282
# Len of new dataset is :1282
# class_index:577, Acc1 0.6630265210608425
# 1300
# Len of new dataset is :1300
# class_index:578, Acc1 0.5407692307692308
# 1300
# Len of new dataset is :1300
# class_index:579, Acc1 0.8346153846153846
# 1300
# Len of new dataset is :1300
# class_index:580, Acc1 0.7607692307692308
# 1300
# Len of new dataset is :1300
# class_index:581, Acc1 0.7453846153846154
# 1300
# Len of new dataset is :1300
# class_index:582, Acc1 0.39692307692307693
# 1283
# Len of new dataset is :1283
# class_index:583, Acc1 0.8355416991426344
# 1300
# Len of new dataset is :1300
# class_index:584, Acc1 0.5338461538461539
# 980
# Len of new dataset is :980
# class_index:585, Acc1 0.4153061224489796
# 1300
# Len of new dataset is :1300
# class_index:586, Acc1 0.8807692307692307
# 1300
# Len of new dataset is :1300
# class_index:587, Acc1 0.4823076923076923
# 1300
# Len of new dataset is :1300
# class_index:588, Acc1 0.6246153846153846
# 1300
# Len of new dataset is :1300
# class_index:589, Acc1 0.666923076923077
# 1034
# Len of new dataset is :1034
# class_index:590, Acc1 0.6179883945841392
# 1300
# Len of new dataset is :1300
# class_index:591, Acc1 0.52
# 1300
# Len of new dataset is :1300
# class_index:592, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:593, Acc1 0.6992307692307692
# 1300
# Len of new dataset is :1300
# class_index:594, Acc1 0.8692307692307693
# 1300
# Len of new dataset is :1300
# class_index:595, Acc1 0.49153846153846154
# 891
# Len of new dataset is :891
# class_index:596, Acc1 0.3984287317620651
# 1300
# Len of new dataset is :1300
# class_index:597, Acc1 0.7638461538461538
# 1300
# Len of new dataset is :1300
# class_index:598, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:599, Acc1 0.6776923076923077
# 1300
# Len of new dataset is :1300
# class_index:600, Acc1 0.4576923076923077
# 1300
# Len of new dataset is :1300
# class_index:601, Acc1 0.7707692307692308
# 1300
# Len of new dataset is :1300
# class_index:602, Acc1 0.61
# 1300
# Len of new dataset is :1300
# class_index:603, Acc1 0.8507692307692307
# 1300
# Len of new dataset is :1300
# class_index:604, Acc1 0.87
# 1300
# Len of new dataset is :1300
# class_index:605, Acc1 0.77
# 1300
# Len of new dataset is :1300
# class_index:606, Acc1 0.69
# 1300
# Len of new dataset is :1300
# class_index:607, Acc1 0.4592307692307692
# 1300
# Len of new dataset is :1300
# class_index:608, Acc1 0.5146153846153846
# 1300
# Len of new dataset is :1300
# class_index:609, Acc1 0.8723076923076923
# 1285
# Len of new dataset is :1285
# class_index:610, Acc1 0.6684824902723735
# 1300
# Len of new dataset is :1300
# class_index:611, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:612, Acc1 0.8623076923076923
# 1300
# Len of new dataset is :1300
# class_index:613, Acc1 0.6438461538461538
# 1300
# Len of new dataset is :1300
# class_index:614, Acc1 0.6046153846153847
# 1300
# Len of new dataset is :1300
# class_index:615, Acc1 0.7084615384615385
# 1300
# Len of new dataset is :1300
# class_index:616, Acc1 0.7315384615384616
# 1300
# Len of new dataset is :1300
# class_index:617, Acc1 0.7846153846153846
# 1300
# Len of new dataset is :1300
# class_index:618, Acc1 0.5153846153846153
# 1300
# Len of new dataset is :1300
# class_index:619, Acc1 0.5023076923076923
# 1300
# Len of new dataset is :1300
# class_index:620, Acc1 0.33
# 1300
# Len of new dataset is :1300
# class_index:621, Acc1 0.58
# 1300
# Len of new dataset is :1300
# class_index:622, Acc1 0.8284615384615385
# 986
# Len of new dataset is :986
# class_index:623, Acc1 0.46247464503042596
# 1300
# Len of new dataset is :1300
# class_index:624, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:625, Acc1 0.08076923076923077
# 1300
# Len of new dataset is :1300
# class_index:626, Acc1 0.5453846153846154
# 1300
# Len of new dataset is :1300
# class_index:627, Acc1 0.8192307692307692
# 1300
# Len of new dataset is :1300
# class_index:628, Acc1 0.8961538461538462
# 1300
# Len of new dataset is :1300
# class_index:629, Acc1 0.46384615384615385
# 1137
# Len of new dataset is :1137
# class_index:630, Acc1 0.7264731750219877
# 1272
# Len of new dataset is :1272
# class_index:631, Acc1 0.5188679245283019
# 1300
# Len of new dataset is :1300
# class_index:632, Acc1 0.6492307692307693
# 1300
# Len of new dataset is :1300
# class_index:633, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:634, Acc1 0.6638461538461539
# 1155
# Len of new dataset is :1155
# class_index:635, Acc1 0.6519480519480519
# 1300
# Len of new dataset is :1300
# class_index:636, Acc1 0.5876923076923077
# 1300
# Len of new dataset is :1300
# class_index:637, Acc1 0.6284615384615385
# 1300
# Len of new dataset is :1300
# class_index:638, Acc1 0.14615384615384616
# 1300
# Len of new dataset is :1300
# class_index:639, Acc1 0.6230769230769231
# 1300
# Len of new dataset is :1300
# class_index:640, Acc1 0.916923076923077
# 1300
# Len of new dataset is :1300
# class_index:641, Acc1 0.2623076923076923
# 1300
# Len of new dataset is :1300
# class_index:642, Acc1 0.69
# 1300
# Len of new dataset is :1300
# class_index:643, Acc1 0.6346153846153846
# 1300
# Len of new dataset is :1300
# class_index:644, Acc1 0.5653846153846154
# 1300
# Len of new dataset is :1300
# class_index:645, Acc1 0.7553846153846154
# 1300
# Len of new dataset is :1300
# class_index:646, Acc1 0.7723076923076924
# 1300
# Len of new dataset is :1300
# class_index:647, Acc1 0.7015384615384616
# 1300
# Len of new dataset is :1300
# class_index:648, Acc1 0.8038461538461539
# 1300
# Len of new dataset is :1300
# class_index:649, Acc1 0.8846153846153846
# 1300
# Len of new dataset is :1300
# class_index:650, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:651, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:652, Acc1 0.6723076923076923
# 1097
# Len of new dataset is :1097
# class_index:653, Acc1 0.7976298997265269
# 1300
# Len of new dataset is :1300
# class_index:654, Acc1 0.7715384615384615
# 1300
# Len of new dataset is :1300
# class_index:655, Acc1 0.5692307692307692
# 1300
# Len of new dataset is :1300
# class_index:656, Acc1 0.7407692307692307
# 1300
# Len of new dataset is :1300
# class_index:657, Acc1 0.696923076923077
# 1300
# Len of new dataset is :1300
# ...
#   warnings.warn(str(msg))
# class_index:782, Acc1 0.3701657458563536
# 1300
# Len of new dataset is :1300
# class_index:783, Acc1 0.683076923076923
# 1300
# Len of new dataset is :1300
# class_index:784, Acc1 0.34923076923076923
# 1300
# Len of new dataset is :1300
# class_index:785, Acc1 0.8253846153846154
# 1300
# Len of new dataset is :1300
# class_index:786, Acc1 0.8284615384615385
# 1300
# Len of new dataset is :1300
# class_index:787, Acc1 0.5846153846153846
# 1300
# Len of new dataset is :1300
# class_index:788, Acc1 0.7430769230769231
# 1249
# Len of new dataset is :1249
# class_index:789, Acc1 0.6196957566052842
# 1300
# Len of new dataset is :1300
# class_index:790, Acc1 0.5823076923076923
# 1300
# Len of new dataset is :1300
# class_index:791, Acc1 0.803076923076923
# 1300
# Len of new dataset is :1300
# class_index:792, Acc1 0.5953846153846154
# 1300
# Len of new dataset is :1300
# class_index:793, Acc1 0.7161538461538461
# 1300
# Len of new dataset is :1300
# class_index:794, Acc1 0.7376923076923076
# 1300
# Len of new dataset is :1300
# class_index:795, Acc1 0.7553846153846154
# 1300
# Len of new dataset is :1300
# class_index:796, Acc1 0.7084615384615385
# 1300
# Len of new dataset is :1300
# class_index:797, Acc1 0.5307692307692308
# 1162
# Len of new dataset is :1162
# class_index:798, Acc1 0.8597246127366609
# 1300
# Len of new dataset is :1300
# class_index:799, Acc1 0.6415384615384615
# 1300
# Len of new dataset is :1300
# class_index:800, Acc1 0.6269230769230769
# 1300
# Len of new dataset is :1300
# class_index:801, Acc1 0.46384615384615385
# 1300
# Len of new dataset is :1300
# class_index:802, Acc1 0.8669230769230769
# 1300
# Len of new dataset is :1300
# class_index:803, Acc1 0.7361538461538462
# 1300
# Len of new dataset is :1300
# class_index:804, Acc1 0.6446153846153846
# 1300
# Len of new dataset is :1300
# class_index:805, Acc1 0.7553846153846154
# 1300
# Len of new dataset is :1300
# class_index:806, Acc1 0.6076923076923076
# 1300
# Len of new dataset is :1300
# class_index:807, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:808, Acc1 0.6038461538461538
# 1300
# Len of new dataset is :1300
# class_index:809, Acc1 0.4046153846153846
# 1045
# Len of new dataset is :1045
# class_index:810, Acc1 0.44593301435406696
# 1004
# Len of new dataset is :1004
# class_index:811, Acc1 0.5896414342629482
# 1238
# Len of new dataset is :1238
# class_index:812, Acc1 0.8578352180936996
# 1300
# Len of new dataset is :1300
# class_index:813, Acc1 0.4330769230769231
# 1300
# Len of new dataset is :1300
# class_index:814, Acc1 0.7576923076923077
# 1300
# Len of new dataset is :1300
# class_index:815, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:816, Acc1 0.6184615384615385
# 1300
# Len of new dataset is :1300
# class_index:817, Acc1 0.5615384615384615
# 1300
# Len of new dataset is :1300
# class_index:818, Acc1 0.6061538461538462
# 1300
# Len of new dataset is :1300
# class_index:819, Acc1 0.6153846153846154
# 1300
# Len of new dataset is :1300
# class_index:820, Acc1 0.9492307692307692
# 1153
# Len of new dataset is :1153
# class_index:821, Acc1 0.8664353859496965
# 1300
# Len of new dataset is :1300
# class_index:822, Acc1 0.8369230769230769
# 1300
# Len of new dataset is :1300
# class_index:823, Acc1 0.7007692307692308
# 1300
# Len of new dataset is :1300
# class_index:824, Acc1 0.40923076923076923
# 1300
# Len of new dataset is :1300
# class_index:825, Acc1 0.7792307692307693
# 1084
# Len of new dataset is :1084
# class_index:826, Acc1 0.690959409594096
# 1300
# Len of new dataset is :1300
# class_index:827, Acc1 0.5930769230769231
# 1300
# Len of new dataset is :1300
# class_index:828, Acc1 0.65
# 1300
# Len of new dataset is :1300
# class_index:829, Acc1 0.8476923076923077
# 1300
# Len of new dataset is :1300
# class_index:830, Acc1 0.5438461538461539
# 1300
# Len of new dataset is :1300
# class_index:831, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:832, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:833, Acc1 0.8515384615384616
# 1300
# Len of new dataset is :1300
# class_index:834, Acc1 0.64
# 1300
# Len of new dataset is :1300
# class_index:835, Acc1 0.8438461538461538
# 1300
# Len of new dataset is :1300
# class_index:836, Acc1 0.5107692307692308
# 1300
# Len of new dataset is :1300
# class_index:837, Acc1 0.4546153846153846
# 1217
# Len of new dataset is :1217
# class_index:838, Acc1 0.27855382087099423
# 1300
# Len of new dataset is :1300
# class_index:839, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:840, Acc1 0.5069230769230769
# 931
# Len of new dataset is :931
# class_index:841, Acc1 0.560687432867884
# 1300
# Len of new dataset is :1300
# class_index:842, Acc1 0.5538461538461539
# 1300
# Len of new dataset is :1300
# class_index:843, Acc1 0.833076923076923
# 1300
# Len of new dataset is :1300
# class_index:844, Acc1 0.7023076923076923
# 1300
# Len of new dataset is :1300
# class_index:845, Acc1 0.6338461538461538
# 1300
# Len of new dataset is :1300
# class_index:846, Acc1 0.7
# 1300
# Len of new dataset is :1300
# class_index:847, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:848, Acc1 0.49538461538461537
# 1300
# Len of new dataset is :1300
# class_index:849, Acc1 0.7315384615384616
# 1300
# Len of new dataset is :1300
# class_index:850, Acc1 0.7584615384615384
# 1300
# Len of new dataset is :1300
# class_index:851, Acc1 0.61
# 1300
# Len of new dataset is :1300
# class_index:852, Acc1 0.18384615384615385
# 1300
# Len of new dataset is :1300
# class_index:853, Acc1 0.7876923076923077
# 1264
# Len of new dataset is :1264
# class_index:854, Acc1 0.6487341772151899
# 1300
# Len of new dataset is :1300
# class_index:855, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:856, Acc1 0.5076923076923077
# 976
# Len of new dataset is :976
# class_index:857, Acc1 0.5409836065573771
# 1300
# Len of new dataset is :1300
# class_index:858, Acc1 0.6623076923076923
# 1300
# Len of new dataset is :1300
# class_index:859, Acc1 0.7184615384615385
# 1250
# Len of new dataset is :1250
# class_index:860, Acc1 0.6112
# 1300
# Len of new dataset is :1300
# class_index:861, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:862, Acc1 0.4238461538461539
# 1300
# Len of new dataset is :1300
# class_index:863, Acc1 0.8384615384615385
# 1300
# Len of new dataset is :1300
# class_index:864, Acc1 0.6053846153846154
# 1300
# Len of new dataset is :1300
# class_index:865, Acc1 0.31846153846153846
# 1300
# Len of new dataset is :1300
# class_index:866, Acc1 0.7661538461538462
# 1300
# Len of new dataset is :1300
# class_index:867, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:868, Acc1 0.41923076923076924
# 1053
# Len of new dataset is :1053
# class_index:869, Acc1 0.7502374169040835
# 1300
# Len of new dataset is :1300
# class_index:870, Acc1 0.7646153846153846
# 1300
# Len of new dataset is :1300
# class_index:871, Acc1 0.7192307692307692
# 1160
# Len of new dataset is :1160
# class_index:872, Acc1 0.821551724137931
# 1300
# Len of new dataset is :1300
# class_index:873, Acc1 0.8984615384615384
# 1300
# Len of new dataset is :1300
# class_index:874, Acc1 0.88
# 1300
# Len of new dataset is :1300
# class_index:875, Acc1 0.6638461538461539
# 1300
# Len of new dataset is :1300
# class_index:876, Acc1 0.4207692307692308
# 1300
# Len of new dataset is :1300
# class_index:877, Acc1 0.8630769230769231
# 1300
# Len of new dataset is :1300
# class_index:878, Acc1 0.7615384615384615
# 1300
# Len of new dataset is :1300
# class_index:879, Acc1 0.6607692307692308
# 1300
# Len of new dataset is :1300
# class_index:880, Acc1 0.7461538461538462
# 1300
# Len of new dataset is :1300
# class_index:881, Acc1 0.85
# 1300
# Len of new dataset is :1300
# class_index:882, Acc1 0.6353846153846154
# 1300
# Len of new dataset is :1300
# class_index:883, Acc1 0.6315384615384615
# 1300
# Len of new dataset is :1300
# class_index:884, Acc1 0.7838461538461539
# 1062
# Len of new dataset is :1062
# class_index:885, Acc1 0.3032015065913371
# 1300
# Len of new dataset is :1300
# class_index:886, Acc1 0.816923076923077
# 1300
# Len of new dataset is :1300
# class_index:887, Acc1 0.5776923076923077
# 1300
# Len of new dataset is :1300
# class_index:888, Acc1 0.8861538461538462
# 1300
# Len of new dataset is :1300
# class_index:889, Acc1 0.6515384615384615
# 1300
# Len of new dataset is :1300
# class_index:890, Acc1 0.6892307692307692
# 1137
# Len of new dataset is :1137
# class_index:891, Acc1 0.7370272647317502
# 1299
# Len of new dataset is :1299
# class_index:892, Acc1 0.6851424172440339
# 1300
# Len of new dataset is :1300
# class_index:893, Acc1 0.5415384615384615
# 1300
# Len of new dataset is :1300
# class_index:894, Acc1 0.67
# 1300
# Len of new dataset is :1300
# class_index:895, Acc1 0.79
# 1300
# Len of new dataset is :1300
# class_index:896, Acc1 0.7476923076923077
# 1300
# Len of new dataset is :1300
# class_index:897, Acc1 0.8638461538461538
# 1300
# Len of new dataset is :1300
# class_index:898, Acc1 0.44846153846153847
# 1300
# Len of new dataset is :1300
# class_index:899, Acc1 0.3076923076923077
# 1300
# Len of new dataset is :1300
# class_index:900, Acc1 0.933076923076923
# 1055
# Len of new dataset is :1055
# class_index:901, Acc1 0.7677725118483413
# 1300
# Len of new dataset is :1300
# class_index:902, Acc1 0.3946153846153846
# 1300
# Len of new dataset is :1300
# class_index:903, Acc1 0.54
# 1300
# Len of new dataset is :1300
# class_index:904, Acc1 0.6753846153846154
# 1300
# Len of new dataset is :1300
# class_index:905, Acc1 0.7261538461538461
# 1213
# Len of new dataset is :1213
# class_index:906, Acc1 0.5927452596867271
# 1300
# Len of new dataset is :1300
# class_index:907, Acc1 0.6069230769230769
# 1300
# Len of new dataset is :1300
# class_index:908, Acc1 0.6923076923076923
# 1300
# Len of new dataset is :1300
# class_index:909, Acc1 0.6215384615384615
# 1300
# Len of new dataset is :1300
# class_index:910, Acc1 0.28384615384615386
# 1300
# Len of new dataset is :1300
# class_index:911, Acc1 0.37538461538461537
# 1300
# Len of new dataset is :1300
# class_index:912, Acc1 0.5807692307692308
# 1300
# Len of new dataset is :1300
# class_index:913, Acc1 0.696923076923077
# 1206
# Len of new dataset is :1206
# class_index:914, Acc1 0.8043117744610282
# 1300
# Len of new dataset is :1300
# class_index:915, Acc1 0.81
# 1300
# Len of new dataset is :1300
# class_index:916, Acc1 0.8915384615384615
# 1300
# Len of new dataset is :1300
# class_index:917, Acc1 0.5423076923076923
# 1300
# Len of new dataset is :1300
# class_index:918, Acc1 0.9184615384615384
# 1300
# Len of new dataset is :1300
# class_index:919, Acc1 0.7992307692307692
# 1300
# Len of new dataset is :1300
# class_index:920, Acc1 0.6761538461538461
# 1154
# Len of new dataset is :1154
# class_index:921, Acc1 0.6577123050259965
# 1300
# Len of new dataset is :1300
# class_index:922, Acc1 0.6861538461538461
# 1300
# Len of new dataset is :1300
# class_index:923, Acc1 0.31846153846153846
# 1300
# Len of new dataset is :1300
# class_index:924, Acc1 0.007692307692307693
# 1207
# Len of new dataset is :1207
# class_index:925, Acc1 0.19469759734879868
# 1149
# Len of new dataset is :1149
# class_index:926, Acc1 0.23846823324630112
# 1300
# Len of new dataset is :1300
# class_index:927, Acc1 0.5907692307692308
# 1300
# Len of new dataset is :1300
# class_index:928, Acc1 0.5107692307692308
# 1300
# Len of new dataset is :1300
# class_index:929, Acc1 0.3253846153846154
# 1300
# Len of new dataset is :1300
# class_index:930, Acc1 0.10538461538461538
# 1300
# Len of new dataset is :1300
# class_index:931, Acc1 0.28692307692307695
# 1300
# Len of new dataset is :1300
# class_index:932, Acc1 0.46615384615384614
# 1300
# Len of new dataset is :1300
# class_index:933, Acc1 0.12538461538461537
# 1300
# Len of new dataset is :1300
# class_index:934, Acc1 0.1676923076923077
# 1300
# Len of new dataset is :1300
# class_index:935, Acc1 0.20692307692307693
# 1300
# Len of new dataset is :1300
# class_index:936, Acc1 0.46615384615384614
# 1300
# Len of new dataset is :1300
# class_index:937, Acc1 0.2815384615384615
# 1300
# Len of new dataset is :1300
# class_index:938, Acc1 0.7823076923076923
# 1300
# Len of new dataset is :1300
# class_index:939, Acc1 0.2123076923076923
# 1239
# Len of new dataset is :1239
# class_index:940, Acc1 0.14285714285714285
# 1300
# Len of new dataset is :1300
# class_index:941, Acc1 0.2569230769230769
# 1300
# Len of new dataset is :1300
# class_index:942, Acc1 0.2569230769230769
# 1300
# Len of new dataset is :1300
# class_index:943, Acc1 0.06
# 1300
# Len of new dataset is :1300
# class_index:944, Acc1 0.6307692307692307
# 1300
# Len of new dataset is :1300
# class_index:945, Acc1 0.24615384615384617
# 1125
# Len of new dataset is :1125
# class_index:946, Acc1 0.5351111111111111
# 1300
# Len of new dataset is :1300
# class_index:947, Acc1 0.6407692307692308
# 1300
# Len of new dataset is :1300
# class_index:948, Acc1 0.12153846153846154
# 1300
# Len of new dataset is :1300
# class_index:949, Acc1 0.03538461538461538
# 1300
# Len of new dataset is :1300
# class_index:950, Acc1 0.03769230769230769
# 1300
# Len of new dataset is :1300
# class_index:951, Acc1 0.15307692307692308
# 1300
# Len of new dataset is :1300
# class_index:952, Acc1 0.43923076923076926
# 1300
# Len of new dataset is :1300
# class_index:953, Acc1 0.7507692307692307
# 1300
# Len of new dataset is :1300
# class_index:954, Acc1 0.4023076923076923
# 1300
# Len of new dataset is :1300
# class_index:955, Acc1 0.35
# 1300
# Len of new dataset is :1300
# class_index:956, Acc1 0.5653846153846154
# 1300
# Len of new dataset is :1300
# class_index:957, Acc1 0.13692307692307693
# 1300
# Len of new dataset is :1300
# class_index:958, Acc1 0.8669230769230769
# 1300
# Len of new dataset is :1300
# class_index:959, Acc1 0.5207692307692308
# 1300
# Len of new dataset is :1300
# class_index:960, Acc1 0.5346153846153846
# 1300
# Len of new dataset is :1300
# class_index:961, Acc1 0.5323076923076923
# 1300
# Len of new dataset is :1300
# class_index:962, Acc1 0.07615384615384616
# 1300
# Len of new dataset is :1300
# class_index:963, Acc1 0.023846153846153847
# 1300
# Len of new dataset is :1300
# class_index:964, Acc1 0.03
# 1300
# Len of new dataset is :1300
# class_index:965, Acc1 0.47
# 1300
# Len of new dataset is :1300
# class_index:966, Acc1 0.4938461538461538
# 1300
# Len of new dataset is :1300
# class_index:967, Acc1 0.4815384615384615
# 1300
# Len of new dataset is :1300
# class_index:968, Acc1 0.6161538461538462
# 1193
# Len of new dataset is :1193
# class_index:969, Acc1 0.40737636211232187
# 1300
# Len of new dataset is :1300
# class_index:970, Acc1 0.7184615384615385
# 1300
# Len of new dataset is :1300
# class_index:971, Acc1 0.7330769230769231
# 1300
# Len of new dataset is :1300
# class_index:972, Acc1 0.6707692307692308
# 1300
# Len of new dataset is :1300
# class_index:973, Acc1 0.4646153846153846
# 1300
# Len of new dataset is :1300
# class_index:974, Acc1 0.9315384615384615
# 1300
# Len of new dataset is :1300
# class_index:975, Acc1 0.36230769230769233
# 1300
# Len of new dataset is :1300
# class_index:976, Acc1 0.48538461538461536
# 1300
# Len of new dataset is :1300
# class_index:977, Acc1 0.32846153846153847
# 1300
# Len of new dataset is :1300
# class_index:978, Acc1 0.4346153846153846
# 1300
# Len of new dataset is :1300
# class_index:979, Acc1 0.42846153846153845
# 1300
# Len of new dataset is :1300
# class_index:980, Acc1 0.7576923076923077
# 1300
# Len of new dataset is :1300
# class_index:981, Acc1 0.7630769230769231
# 1300
# Len of new dataset is :1300
# class_index:982, Acc1 0.7692307692307693
# 1300
# Len of new dataset is :1300
# class_index:983, Acc1 0.7915384615384615
# 1300
# Len of new dataset is :1300
# class_index:984, Acc1 0.027692307692307693
# 1300
# Len of new dataset is :1300
# class_index:985, Acc1 0.8738461538461538
# 1300
# Len of new dataset is :1300
# class_index:986, Acc1 0.11692307692307692
# 1300
# Len of new dataset is :1300
# class_index:987, Acc1 0.29384615384615387
# 1300
# Len of new dataset is :1300
# class_index:988, Acc1 0.6823076923076923
# 1300
# Len of new dataset is :1300
# class_index:989, Acc1 0.2569230769230769
# 1300
# Len of new dataset is :1300
# class_index:990, Acc1 0.24461538461538462
# 1300
# Len of new dataset is :1300
# class_index:991, Acc1 0.8569230769230769
# 1300
# Len of new dataset is :1300
# class_index:992, Acc1 0.13923076923076924
# 1300
# Len of new dataset is :1300
# class_index:993, Acc1 0.6807692307692308
# 1300
# Len of new dataset is :1300
# class_index:994, Acc1 0.6269230769230769
# 1300
# Len of new dataset is :1300
# class_index:995, Acc1 0.8015384615384615
# 1300
# Len of new dataset is :1300
# class_index:996, Acc1 0.6046153846153847
# 1300
# Len of new dataset is :1300
# class_index:997, Acc1 0.43
# 1300
# Len of new dataset is :1300
# class_index:998, Acc1 0.24769230769230768
# 1300
# Len of new dataset is :1300
# class_index:999, Acc1 0.6907692307692308

# %%
gray_gt_pred_acc = "./gray_pred_acc.pickle"
with open(gray_gt_pred_acc, "wb") as handle:
    pickle.dump(gray_class_y_true_y_pred_acc, handle)

# %%
np.mean([acc for _, _, acc in gray_class_y_true_y_pred_acc.values()])
# Out:
# 0.6241224084233481
