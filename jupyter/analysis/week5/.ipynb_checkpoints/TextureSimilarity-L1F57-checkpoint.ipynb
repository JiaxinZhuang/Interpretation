# %%
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Import module

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import sys
sys.path.append("../../../src/")
sys.path.append("../..")

import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 600
import numpy as np
from torchvision import transforms
from PIL import Image
from collections import Counter

from aux.utils import zscore, get_DISTS, get_top_k
from aux.visualization import plot_cov_matrix
import model
from datasets import imagenet
from loss import FilterLoss

from aux.utils import get_DISTS
from aux.visualization import visualize_features_map_for_comparision

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
width = height =  224

# %%
def load_imgs_from_path(data_dir, height, width):
    """Load imgs directly from path.
    Returns:
        data: [batch_size, 3, height, width]
        data_paths: [batch_size]
    """
    data = []
    data_paths = []
    for _, path in enumerate(os.listdir(data_dir)):
        file_path = os.path.join(data_dir, path)
        img = Image.open(file_path).convert("RGB").resize((width, height))
        img = np.array(img).astype("float32")
        data.append(img)
        data_paths.append(file_path)
    data = np.array(data)
    return data, data_paths

def preprocess_imgs_with_scale(data):
    """Convert numpy to tensor.
    """
    ref_imgs  = torch.tensor(data) / 255.0
    ref_imgs = ref_imgs.permute((0, 3, 1, 2))
    return ref_imgs

# %% [markdown]
# # Load Brodatz

# %%
brodatz_data_dir = "/media/lincolnzjx/HardDisk/Datasets/Brodatz/"

# %%
brodatz_data, brodatz_paths = load_imgs_from_path(brodatz_data_dir, height, 
                                                  width)
ref_imgs = preprocess_imgs_with_scale(brodatz_data)
print(ref_imgs.size())
# Out:
# torch.Size([64, 3, 224, 224])

# %% [markdown]
# # Load Optimzed data

# %%
save_dir = "/home/lincolnzjx/Desktop/Interpretation/saved/pack"
################### Hyper-Parameter #######################
exp = "40116"
epoch = "70200"
##########################################################
ab_path = os.path.join(save_dir, exp, epoch)

# %%
opt_data, opt_paths = load_imgs_from_path(ab_path, height, width)
opt_ref_imgs = preprocess_imgs_with_scale(opt_data)
print(opt_ref_imgs.size())
# Out:
# torch.Size([30, 3, 224, 224])

# %%
dist_matrix = get_DISTS(opt_ref_imgs, ref_imgs, device=device)

# %%
fig, ax = plt.subplots()
cax = ax.matshow(dist_matrix)
fig.colorbar(cax)

# %%
rows = dist_matrix.shape[0]
top5s = []
for index in range(rows):
    top5, top5_distance = get_top_k(dist_matrix, filter_index=index, top_k=3, 
                                    descend=True)
    top5s.append(top5)
    print("Img-{} Similar Index: {},\nDistance: {}".format(
         index, top5, top5_distance))
# Out:
# Img-0 Similar Index: [59 27 61],
# Distance: [0.48704183 0.48718691 0.49078834]
# Img-1 Similar Index: [42 25 20],
# Distance: [0.46010566 0.48085696 0.50551498]
# Img-2 Similar Index: [59 19 25],
# Distance: [0.45735401 0.45779598 0.46480101]
# Img-3 Similar Index: [27 61 19],
# Distance: [0.50231355 0.50444293 0.50450194]
# Img-4 Similar Index: [27 19 61],
# Distance: [0.47633821 0.47831273 0.47923577]
# Img-5 Similar Index: [27 42 61],
# Distance: [0.50712854 0.50728452 0.50855005]
# Img-6 Similar Index: [37 25 31],
# Distance: [0.43905944 0.44164598 0.4473384 ]
# Img-7 Similar Index: [19 61 38],
# Distance: [0.45512688 0.46119422 0.47275156]
# Img-8 Similar Index: [42 25 27],
# Distance: [0.47516632 0.50084376 0.51114076]
# Img-9 Similar Index: [42 19 61],
# Distance: [0.49417889 0.51164502 0.51164854]
# Img-10 Similar Index: [59 25 20],
# Distance: [0.47652668 0.49084669 0.50376511]
# Img-11 Similar Index: [25 27 19],
# Distance: [0.46586823 0.478598   0.47927266]
# Img-12 Similar Index: [10 27 39],
# Distance: [0.43370181 0.44242984 0.44243872]
# Img-13 Similar Index: [19 61 59],
# Distance: [0.47962826 0.48144817 0.49289215]
# Img-14 Similar Index: [27 19 61],
# Distance: [0.4823842  0.48348027 0.48429072]
# Img-15 Similar Index: [25 42 38],
# Distance: [0.46593565 0.47130364 0.48764426]
# Img-16 Similar Index: [42 10 31],
# Distance: [0.48382419 0.48815286 0.48875201]
# Img-17 Similar Index: [42 25 20],
# Distance: [0.47388518 0.50514954 0.51238841]
# Img-18 Similar Index: [19 10 42],
# Distance: [0.47881639 0.47948849 0.48050117]
# Img-19 Similar Index: [27 19 61],
# Distance: [0.48995507 0.49029666 0.49220431]
# Img-20 Similar Index: [19 59 42],
# Distance: [0.46255898 0.46763688 0.46767193]
# Img-21 Similar Index: [61 59 19],
# Distance: [0.49026799 0.49079305 0.49155915]
# Img-22 Similar Index: [42 27 19],
# Distance: [0.47911823 0.50964534 0.51101124]
# Img-23 Similar Index: [61 19 38],
# Distance: [0.45557463 0.45707649 0.46115488]
# Img-24 Similar Index: [61 27 19],
# Distance: [0.42842782 0.42869002 0.43034321]
# Img-25 Similar Index: [42 25 27],
# Distance: [0.47429359 0.48681325 0.49227422]
# Img-26 Similar Index: [59 25  6],
# Distance: [0.4480561  0.4482621  0.45481944]
# Img-27 Similar Index: [27 19 61],
# Distance: [0.45199478 0.45295727 0.4578681 ]
# Img-28 Similar Index: [11 25 27],
# Distance: [0.46411544 0.46530122 0.46828747]
# Img-29 Similar Index: [11 31  6],
# Distance: [0.45978212 0.46307546 0.46686804]

# %%
counter = Counter(np.array(top5s).flatten().tolist())

# %%
counter.most_common(19)
# Out:
# [(19, 16),
#  (27, 14),
#  (61, 13),
#  (42, 11),
#  (25, 11),
#  (59, 7),
#  (20, 3),
#  (31, 3),
#  (38, 3),
#  (10, 3),
#  (6, 2),
#  (11, 2),
#  (37, 1),
#  (39, 1)]

# %%
print(brodatz_paths[0])
print(brodatz_paths[39])
print(brodatz_paths[53])
print(brodatz_paths[55])
# Out:
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/1.2.13.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/1.1.13.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/1.3.13.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/1.2.11.tiff

# %%
print(brodatz_paths[27])
print(brodatz_paths[19])
print(brodatz_paths[61])
print(brodatz_paths[38])
# Out:
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/texmos3.p512.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/texmos3b.p512.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/texmos2.p512.tiff
# /media/lincolnzjx/HardDisk/Datasets/Brodatz/texmos1.p512.tiff
