# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
cd ../
# Out:
# /home/lincolnzjx/Desktop/Interpretation

# %%
pwd
# Out:
# '/home/lincolnzjx/Desktop/Interpretation'

# %%
def main(cuda, exp, alpha, beta, gamma, selected_layer, selected_filter,
         class_index, num_class, re_size, dataset, backbone, img_index, mode,
         inter, defensed):
    resume = "037-0"
    server = 'desktop'
    n_epochs = 10000
    seed = -1
    eval_frequency = 50
    delta = 0
    batch_size = 1 if mode else num_class
    lr = 1
    
    # !CUDA_VISIBLE_DEVICES=$cuda python -u -W ignore src/trainer.py \
        --experiment_index $exp\
        --alpha=$alpha \
        --gamma=$gamma \
        --beta=$beta \
        --selected_layer=$selected_layer \
        --selected_filter=$selected_filter \
        --num_class=$num_class \
        --class_index=$class_index \
        --server $server\
        --dataset $dataset\
        --n_epochs $n_epochs \
        --eval_frequency=$eval_frequency \
        --re_size $re_size \
        --backbone=$backbone \
        --optimizer=SGD \
        --learning_rate $lr \
        --delta=$delta \
        --resume $resume \
        --mode=keep \
        --inter $inter \
        --regularization=L1 \
        --seed $seed \
        --img_index $img_index\
        --batch_size $batch_size\
        --inter $inter\
        --defensed $defensed

# %% [markdown]
# # Read From excel

# %%
excel_path = "./src/exps.xlsx"
sheet = "ImageNet"
excepts = []

# %% [markdown]
# # ALL YOU NEED TO SET HERE!!

# %%
exp_index = "x091900"

# %% [markdown]
# # Main

# %%
xlsx = pd.ExcelFile(excel_path)
excel = pd.read_excel(xlsx, sheet, dtype={"exp": str, 
                                          "Done": str,
                                          "selected_layer": int,
                                          "selected_filter": int, 
                                          "Alpha": int,
                                          "Beta": int,
                                          "Gamma": int,
                                          "cuda": int,
                                          "class_index": int,
                                          "num_class": int,
                                          "re_size": int,
                                          "dataset": str,
                                          "backbone": str, 
                                          "mode":str,
                                          "inter":str}).values

for data in excel:
    exp, done, selected_layer, selected_filter, alpha, beta, gamma, cuda, \
        class_index, num_class, re_size, dataset, backbone, mode, inter,\
        defensed = data
    if exp != exp_index:
        continue
        
    exp = exp.replace("x", "")
    if exp in excepts:
        print("=> Skip")
    else:
        if done == "N":
            for img_index in range(30):
                if img_index != -1:
                    print("=> RUN on ", cuda, exp, selected_layer, selected_filter, 
                          class_index, "img_index ", img_index)
                    main(cuda, exp, alpha, beta, gamma, selected_layer, 
                         selected_filter, class_index, num_class, re_size, dataset,
                         backbone, img_index, mode, inter, defensed)
# Out:
# => RUN on  0 091900 1 16 950 img_index  0
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 0
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4095: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10061-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4193 <<<
# Finish Training
# >> Functoin: main costs 0:03:21.253935
# => RUN on  0 091900 1 16 950 img_index  1
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 1
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4679: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Epoch  4415: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10110-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4513 <<<
# Finish Training
# >> Functoin: main costs 0:03:41.132339
# => RUN on  0 091900 1 16 950 img_index  3
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 3
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  6053: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10134-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 6148 <<<
# Finish Training
# >> Functoin: main costs 0:04:59.181795
# => RUN on  0 091900 1 16 950 img_index  4
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 4
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3905: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10162-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3966 <<<
# Finish Training
# >> Functoin: main costs 0:03:14.845259
# => RUN on  0 091900 1 16 950 img_index  5
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 5
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4594: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10166-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4692 <<<
# Finish Training
# >> Functoin: main costs 0:03:50.339657
# => RUN on  0 091900 1 16 950 img_index  6
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 6
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4038: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10178-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4136 <<<
# Finish Training
# >> Functoin: main costs 0:03:24.490849
# => RUN on  0 091900 1 16 950 img_index  7
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 7
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5248: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10179-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5346 <<<
# Finish Training
# >> Functoin: main costs 0:04:20.261898
# => RUN on  0 091900 1 16 950 img_index  8
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 8
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5364: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10184-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5462 <<<
# Finish Training
# >> Functoin: main costs 0:04:26.744449
# => RUN on  0 091900 1 16 950 img_index  9
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 9
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4822: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10192-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4917 <<<
# Finish Training
# >> Functoin: main costs 0:04:00.547034
# => RUN on  0 091900 1 16 950 img_index  10
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 10
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5133: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10204-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5230 <<<
# Finish Training
# >> Functoin: main costs 0:04:17.221227
# => RUN on  0 091900 1 16 950 img_index  11
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 11
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5090: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10205-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5187 <<<
# Finish Training
# >> Functoin: main costs 0:04:15.795272
# => RUN on  0 091900 1 16 950 img_index  12
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 12
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4035: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_1021-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3934 <<<
# Finish Training
# >> Functoin: main costs 0:03:16.987036
# => RUN on  0 091900 1 16 950 img_index  13
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 13
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3916: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10213-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4014 <<<
# Finish Training
# >> Functoin: main costs 0:03:19.177079
# => RUN on  0 091900 1 16 950 img_index  14
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 14
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4782: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10217-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4881 <<<
# Finish Training
# >> Functoin: main costs 0:03:59.275045
# => RUN on  0 091900 1 16 950 img_index  15
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 15
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4364: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10232-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4460 <<<
# Finish Training
# >> Functoin: main costs 0:03:38.393381
# => RUN on  0 091900 1 16 950 img_index  16
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 16
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5146: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10258-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5245 <<<
# Finish Training
# >> Functoin: main costs 0:04:16.666527
# => RUN on  0 091900 1 16 950 img_index  17
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 17
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# ...
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 24
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4090: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10436-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4021 <<<
# Finish Training
# >> Functoin: main costs 0:03:20.914426
# => RUN on  0 091900 1 16 950 img_index  25
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 25
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5569: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10465-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5664 <<<
# Finish Training
# >> Functoin: main costs 0:04:34.841103
# => RUN on  0 091900 1 16 950 img_index  26
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 26
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4431: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10482-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4529 <<<
# Finish Training
# >> Functoin: main costs 0:03:41.677211
# => RUN on  0 091900 1 16 950 img_index  27
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 27
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  5702: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10485-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 5801 <<<
# Finish Training
# >> Functoin: main costs 0:04:44.331210
# => RUN on  0 091900 1 16 950 img_index  28
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 28
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4015: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10491-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4107 <<<
# Finish Training
# >> Functoin: main costs 0:03:23.776230
# => RUN on  0 091900 1 16 950 img_index  29
# ==================== basic setting start ====================
# experiment_index    : 091900
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : True
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 29
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091900
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: True with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4643: reducing learning rate of group 0 to 1.0000e-01.
# Plot mode is => img_scale
# Color map is => jet
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091900/feature_map/layer-1-n07747607_10545-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4742 <<<
# Finish Training
# >> Functoin: main costs 0:03:53.029373

# %% [markdown]
# # Visualization

# %%
import pickle

# %%
# statistic_path = "/home/lincolnzjx/Desktop/Interpretation/saved/generated/091900/n07747607_10061_statistics.pl"
statistic_path = "/home/lincolnzjx/Desktop/Interpretation/saved/generated/091900/n07747607_1021_statistics.pl"

# %%
with open(statistic_path, "rb") as handle:
    statistic = pickle.load(handle)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-9dafe2cba7ee> in <module>
# ----> 1 with open(statistic_path, "rb") as handle:
#       2     statistic = pickle.load(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/lincolnzjx/Desktop/Interpretation/saved/generated/091900/n07747607_1021_statistics.pl'

# %%
epoch = statistic["epoch"]
loss = statistic["losses"]
selected_filter_loss = statistic["selected_filter_loss"]
rest_filter_loss = statistic["rest_fileter_loss"]
rest_filter_loss_interact = statistic["rest_filter_loss_interact"]
regularization_loss = statistic["regularization_loss"]
lr = statistic["lr"]
best = statistic["best"][0]

metric_statistic = statistic["metric_statistic"]
rmses_mean = [ms["rmses_mean"] for ms in metric_statistic]
ssim_sel_mean = [ms["ssim_sel_mean"] for ms in metric_statistic]
ssim_res_mean = [ms["ssim_res_mean"] for ms in metric_statistic]

print("sf: min:{:.3f} max:{:.3f}".format(min(selected_filter_loss), max(selected_filter_loss)))
print("rf: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss), max(rest_filter_loss)))
print("rfi: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss_interact), max(rest_filter_loss_interact)))
print("rg: min:{:.3f} max:{:.3f}".format(min(regularization_loss), max(regularization_loss)))
print("rmse: min:{:.3f} max:{:.3f}".format(min(rmses_mean), max(rmses_mean)))
print("ssim_sel: min:{:.3f}, max:{:.3f}".format(min(ssim_sel_mean), max(ssim_sel_mean)))
print("ssim_res: min:{:.3f}, max:{:.3f}".format(min(ssim_res_mean), max(ssim_res_mean)))
print("-"*50)
for key, name in best.items():
    if key != "processed_images":
        print(key, name)


fig = plt.figure(figsize=(3, 21))
fig.add_axes(sharex=True)
# plt.xlim((0, max(epoch)+1))

ax = plt.subplot(711)
plt.plot(epoch, selected_filter_loss, label="selected_filter_loss")
plt.legend(loc='best')

plt.subplot(712)
plt.plot(epoch, rest_filter_loss, label="rest_filter_loss")
plt.plot(epoch, rest_filter_loss_interact, label="rest_filter_loss_interact")
plt.legend(loc='best')

plt.subplot(713)
plt.plot(epoch, regularization_loss, label="regularization")
plt.legend(loc='best')

plt.subplot(714)
plt.plot(epoch, loss, label="train_loss")
plt.legend(loc='best')

plt.subplot(715)
plt.plot(epoch, lr, label="lr")
plt.legend(loc='best')

plt.subplot(716)
plt.plot(epoch, rmses_mean, label="rmse")
plt.legend(loc='best')

plt.subplot(717)
plt.plot(epoch, ssim_sel_mean, label="ssim_sel")
plt.plot(epoch, ssim_res_mean, label="ssim_res")
plt.legend(loc='best')

plt.suptitle('Training Process')
plt.show()
