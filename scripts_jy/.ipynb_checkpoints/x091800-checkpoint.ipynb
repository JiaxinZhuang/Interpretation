# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
cd ../
# Out:
# /home/lincolnzjx/Desktop/Interpretation

# %%
pwd
# Out:
# '/home/lincolnzjx/Desktop/Interpretation'

# %%
def main(cuda, exp, alpha, beta, gamma, selected_layer, selected_filter,
         class_index, num_class, re_size, dataset, backbone, img_index, mode,
         inter):
    resume = "037-0"
    server = 'desktop'
    n_epochs = 10000
    seed = -1
    eval_frequency = 50
    delta = 0
    batch_size = 1 if mode else num_class
    lr = 1
    
    # !CUDA_VISIBLE_DEVICES=$cuda python -u -W ignore src/trainer.py \
        --experiment_index $exp\
        --alpha=$alpha \
        --gamma=$gamma \
        --beta=$beta \
        --selected_layer=$selected_layer \
        --selected_filter=$selected_filter \
        --num_class=$num_class \
        --class_index=$class_index \
        --server $server\
        --dataset $dataset\
        --n_epochs $n_epochs \
        --eval_frequency=$eval_frequency \
        --re_size $re_size \
        --backbone=$backbone \
        --optimizer=SGD \
        --learning_rate $lr \
        --delta=$delta \
        --resume $resume \
        --mode=keep \
        --inter=False \
        --regularization=L1 \
        --seed $seed \
        --img_index $img_index\
        --batch_size $batch_size

# %% [markdown]
# # Read From excel

# %%
excel_path = "./src/exps.xlsx"
sheet = "ImageNet"
excepts = []

# %% [markdown]
# # ALL YOU NEED TO SET HERE!!

# %%
exp_index = "x091800"

# %% [markdown]
# # Main

# %%
xlsx = pd.ExcelFile(excel_path)
excel = pd.read_excel(xlsx, sheet, dtype={"exp": str, 
                                          "Done": str,
                                          "selected_layer": int,
                                          "selected_filter": int, 
                                          "Alpha": int,
                                          "Beta": int,
                                          "Gamma": int,
                                          "cuda": int,
                                          "class_index": int,
                                          "num_class": int,
                                          "re_size": int,
                                          "dataset": str,
                                          "backbone": str, 
                                          "mode":str}).values

for data in excel:
    exp, done, selected_layer, selected_filter, alpha, beta, gamma, cuda, \
        class_index, num_class, re_size, dataset, backbone, mode, inter = data
    if exp != exp_index:
        continue
        
    exp = exp.replace("x", "")
    if exp in excepts:
        print("=> Skip")
    else:
        if done == "N":
            for img_index in range(30):
                if img_index != -1:
                    print("=> RUN on ", cuda, exp, selected_layer, selected_filter, 
                          class_index, "img_index ", img_index)
                    main(cuda, exp, alpha, beta, gamma, selected_layer, 
                         selected_filter, class_index, num_class, re_size, dataset,
                         backbone, img_index, mode, inter)
# Out:
# => RUN on  0 091800 1 16 950 img_index  0
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 0
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3300: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3371: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3422: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3473: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3524: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3575: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3626: reducing learning rate of group 0 to 1.0000e-07.
# Plot mode is => img_scale
# Color map is => jet
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# => max, min 6.9162555 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10061-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3674 <<<
# Finish Training
# >> Functoin: main costs 0:00:27.740928
# => RUN on  0 091800 1 16 950 img_index  1
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 1
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Epoch  3372: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3423: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3474: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3525: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3576: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3627: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3678: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# => max, min 13.857485 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10068-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3726 <<<
# Finish Training
# >> Functoin: main costs 0:00:27.565876
# => RUN on  0 091800 1 16 950 img_index  2
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 2
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3644: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3696: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3747: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3798: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3849: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3900: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3951: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# => max, min 14.892541 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10110-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3999 <<<
# Finish Training
# >> Functoin: main costs 0:00:28.712835
# => RUN on  0 091800 1 16 950 img_index  3
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 3
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4535: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  4587: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  4638: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  4689: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  4740: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  4791: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  4842: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# => max, min 16.351267 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10134-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4890 <<<
# Finish Training
# >> Functoin: main costs 0:00:32.372537
# => RUN on  0 091800 1 16 950 img_index  4
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 4
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3281: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3366: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3417: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3468: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3519: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3570: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3621: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# => max, min 9.921285 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10162-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3669 <<<
# Finish Training
# >> Functoin: main costs 0:00:27.647680
# => RUN on  0 091800 1 16 950 img_index  5
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 5
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3853: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3921: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3972: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  4023: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  4074: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  4125: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  4176: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# => max, min 10.505928 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10166-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4224 <<<
# Finish Training
# >> Functoin: main costs 0:00:29.096106
# => RUN on  0 091800 1 16 950 img_index  6
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 6
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3293: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3344: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3395: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3446: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3497: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3548: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3599: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# => max, min 10.341464 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10178-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3647 <<<
# Finish Training
# >> Functoin: main costs 0:00:26.935767
# => RUN on  0 091800 1 16 950 img_index  7
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 7
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3692: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3776: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3827: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3878: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3929: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3980: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  4031: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# => max, min 9.792038 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10179-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4079 <<<
# Finish Training
# >> Functoin: main costs 0:00:28.967582
# => RUN on  0 091800 1 16 950 img_index  8
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 8
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4254: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  4333: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  4384: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  4435: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  4486: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  4537: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  4588: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# => max, min 10.410644 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10184-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4636 <<<
# Finish Training
# >> Functoin: main costs 0:00:31.109066
# => RUN on  0 091800 1 16 950 img_index  9
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 9
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3591: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3659: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3710: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3761: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3812: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3863: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3914: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# => max, min 10.0237875 0.0
# ...
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# => max, min 13.9761715 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10465-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4743 <<<
# Finish Training
# >> Functoin: main costs 0:00:31.587698
# => RUN on  0 091800 1 16 950 img_index  26
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 26
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  4091: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  4146: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  4197: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  4248: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  4299: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  4350: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  4401: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# => max, min 8.542269 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10485-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 4449 <<<
# Finish Training
# >> Functoin: main costs 0:00:31.297691
# => RUN on  0 091800 1 16 950 img_index  28
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 28
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3443: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3494: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3545: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3596: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3647: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3698: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3749: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# => max, min 11.385772 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10491-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3797 <<<
# Finish Training
# >> Functoin: main costs 0:00:27.976044
# => RUN on  0 091800 1 16 950 img_index  29
# ==================== basic setting start ====================
# experiment_index    : 091800
# cuda                : 0
# num_workers         : 2
# dataset             : ImageNet
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 037-0
# n_epochs            : 10000
# learning_rate       : 1.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 50
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0.0001
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg16
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 16
# selected_layer      : 1
# alpha               : 100.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [950]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 29
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# > Don't use seed
# Save generated on ./saved/generated/091800
# Using device cuda
# Alpha is 100.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:ImageNet - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 1th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:1.0000
# Resume from model from exp: 037 at epoch 0
# Network(
#   (model): VGG16(
#     (features): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  3481: reducing learning rate of group 0 to 1.0000e-01.
# Epoch  3538: reducing learning rate of group 0 to 1.0000e-02.
# Epoch  3589: reducing learning rate of group 0 to 1.0000e-03.
# Epoch  3640: reducing learning rate of group 0 to 1.0000e-04.
# Epoch  3691: reducing learning rate of group 0 to 1.0000e-05.
# Epoch  3742: reducing learning rate of group 0 to 1.0000e-06.
# Epoch  3793: reducing learning rate of group 0 to 1.0000e-07.
# Directory has been created ./saved/generated/091800/feature_map/
# Plot mode is => img_scale
# Color map is => jet
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# => max, min 10.312041 0.0
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to ./saved/generated/091800/feature_map/layer-1-n07747607_10545-Comparision.png
# Figure(900x600)
# >>> EarlyStopping at epoch: 3841 <<<
# Finish Training
# >> Functoin: main costs 0:00:28.321450

# %% [markdown]
# # Visualization

# %%
import pickle

# %%
statistic_path = "/home/lincolnzjx/Desktop/Interpretation/saved/generated/091800/n07747607_10061_statistics.pl"

# %%
with open(statistic_path, "rb") as handle:
    statistic = pickle.load(handle)

# %%
epoch = statistic["epoch"]
loss = statistic["losses"]
selected_filter_loss = statistic["selected_filter_loss"]
rest_filter_loss = statistic["rest_fileter_loss"]
rest_filter_loss_interact = statistic["rest_filter_loss_interact"]
regularization_loss = statistic["regularization_loss"]
lr = statistic["lr"]

metric_statistic = statistic["metric_statistic"]
rmses_mean = [ms["rmses_mean"] for ms in metric_statistic]
ssim_sel_mean = [ms["ssim_sel_mean"] for ms in metric_statistic]
ssim_res_mean = [ms["ssim_res_mean"] for ms in metric_statistic]

print("sf: min:{:.3f} max:{:.3f}".format(min(selected_filter_loss), max(selected_filter_loss)))
print("rf: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss), max(rest_filter_loss)))
print("rfi: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss_interact), max(rest_filter_loss_interact)))
print("rg: min:{:.3f} max:{:.3f}".format(min(regularization_loss), max(regularization_loss)))
print("rmse: min:{:.3f}".format(min(rmses_mean)))
print("ssim_sel: min:{:.3f}, max:{:.3f}".format(min(ssim_res_mean), max(ssim_sel_mean)))
print("ssim_res: max:{:.3f}".format(max(ssim_res_mean)))


fig = plt.figure(figsize=(3, 16))
fig.add_axes(sharex=True)
# plt.xlim((0, max(epoch)+1))

ax = plt.subplot(511)
plt.plot(epoch, selected_filter_loss, label="selected_filter_loss")
plt.legend(loc='best')

plt.subplot(512)
plt.plot(epoch, rest_filter_loss, label="rest_filter_loss")
plt.plot(epoch, rest_filter_loss_interact, label="rest_filter_loss_interact")
plt.legend(loc='best')

plt.subplot(513)
plt.plot(epoch, loss, label="train_loss")
plt.legend(loc='best')

plt.subplot(514)
plt.plot(epoch, lr, label="lr")
plt.legend(loc='best')

plt.subplot(515)
plt.plot(epoch, ssim_sel_mean, label="ssim_sel")
plt.plot(epoch, ssim_res_mean, label="ssim_res")
plt.legend(loc='best')

plt.suptitle('Training Process')
plt.show()
# Out:
# sf: min:0.000 max:0.000
# rf: min:0.222 max:0.274
# rfi: min:0.066 max:0.091
# rg: min:0.233 max:0.925
# rmse: min:0.000
# ssim_sel: min:0.612, max:1.000
# ssim_res: max:0.709

# %% [markdown]
# #
