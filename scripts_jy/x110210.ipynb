# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import glob
import seaborn as sns
import numpy as np

# %%
cd ../
# Out:
# /home/lincolnzjx/Desktop/Interpretation

# %%
pwd
# Out:
# '/home/lincolnzjx/Desktop/Interpretation'

# %%
def main(cuda, exp, alpha, beta, gamma, selected_layer, selected_filter,
         class_index, num_class, re_size, dataset, backbone, img_index, mode,
         inter, defensed):
    resume = "072200-22"
    server = 'desktop'
    n_epochs = 10000
    seed = -1
    eval_frequency = 1000
    delta = 0
    batch_size = 1 if mode else num_class
    lr = 10
    
    # !CUDA_VISIBLE_DEVICES=$cuda python -u -W ignore src/trainer.py \
        --experiment_index $exp\
        --alpha=$alpha \
        --gamma=$gamma \
        --beta=$beta \
        --selected_layer=$selected_layer \
        --selected_filter=$selected_filter \
        --num_class=$num_class \
        --class_index=$class_index \
        --server $server\
        --dataset $dataset\
        --n_epochs $n_epochs \
        --eval_frequency=$eval_frequency \
        --re_size $re_size \
        --backbone=$backbone \
        --optimizer=SGD \
        --learning_rate $lr \
        --delta=$delta \
        --resume $resume \
        --mode=keep \
        --inter=False \
        --regularization=L1 \
        --seed $seed \
        --img_index $img_index\
        --batch_size $batch_size\
        --inter $inter\
        --defensed $defensed\
        --scheduler

# %% [markdown]
# # Read From excel

# %%
excel_path = "./src/exps.xlsx"
sheet = "mnist"
excepts = []

# %% [markdown]
# # ALL YOU NEED TO SET HERE!!

# %%
exp_index = "x110210"

# %% [markdown]
# # Main

# %%
xlsx = pd.ExcelFile(excel_path)
excel = pd.read_excel(xlsx, sheet, dtype={"exp": str, 
                                          "Done": str,
                                          "selected_layer": int,
                                          "selected_filter": int, 
                                          "Alpha": int,
                                          "Beta": int,
                                          "Gamma": int,
                                          "cuda": int,
                                          "class_index": int,
                                          "num_class": int,
                                          "re_size": int,
                                          "dataset": str,
                                          "backbone": str, 
                                          "mode":str}).values

for data in excel:
    exp, done, selected_layer, selected_filter, alpha, beta, gamma, cuda, \
        class_index, num_class, re_size, dataset, backbone, mode, inter, \
        defensed = data
    if exp != exp_index:
        continue
        
    exp = exp.replace("x", "")
    if exp in excepts:
        print("=> Skip")
    else:
        if done == "N":
            for img_index in range(30):
#                 if img_index == 0:
                print("=> RUN on ", cuda, exp, selected_layer, selected_filter, 
                      class_index, "img_index ", img_index)
                main(0, exp, alpha, beta, gamma, selected_layer, 
                     selected_filter, class_index, num_class, re_size, dataset,
                     backbone, img_index, mode, inter, defensed)
# Out:
# => RUN on  0 110210 19 41 0 img_index  0
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 0
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   202: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   403: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   604: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   805: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1006: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1207: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1408: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1609: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1810: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2011: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2212: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2413: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2614: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2815: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3016: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3217: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3418: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3619: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3820: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4021: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4222: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4423: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4624: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4825: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5026: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5227: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5428: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5629: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5830: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_0_0_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 4.563098e-06, 'rmses_std': 0.0, 'ssim_sel_mean': 1.0, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.84007746, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_0-Comparision.png
# >>> EarlyStopping at epoch: 0 <<<
# Finish Training
# >> Functoin: main costs 0:01:47.522701
# => RUN on  0 110210 19 41 0 img_index  1
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 1
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   224: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   425: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   626: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   827: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1028: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1229: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1430: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1631: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1832: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2033: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2234: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2435: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2636: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2837: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3038: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3239: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3440: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3641: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3842: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4043: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4244: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4445: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4646: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4847: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5048: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5249: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5450: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5651: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5852: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_1_22_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.0023846244, 'rmses_std': 0.0, 'ssim_sel_mean': 0.9950471, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.8532691, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_1-Comparision.png
# >>> EarlyStopping at epoch: 22 <<<
# Finish Training
# >> Functoin: main costs 0:01:45.977075
# => RUN on  0 110210 19 41 0 img_index  2
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 2
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   202: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   403: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   604: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   805: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1006: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1207: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1408: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1609: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1810: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2011: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2212: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2413: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2614: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2815: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3016: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3217: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3418: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3619: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3820: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4021: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4222: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4423: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4624: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4825: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5026: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5227: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5428: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5629: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5830: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_2_0_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 5.7011843e-05, 'rmses_std': 0.0, 'ssim_sel_mean': 0.99999684, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.86891294, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_2-Comparision.png
# >>> EarlyStopping at epoch: 0 <<<
# Finish Training
# >> Functoin: main costs 0:01:45.502778
# => RUN on  0 110210 19 41 0 img_index  3
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 3
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   212: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   413: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   614: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   815: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1016: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1217: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1418: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1619: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1820: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2021: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2222: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2423: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2624: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2825: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3026: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3227: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3428: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3629: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3830: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4031: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4232: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4433: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4634: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4835: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5036: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5237: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5438: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5639: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5840: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_3_10_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.00010355217, 'rmses_std': 0.0, 'ssim_sel_mean': 0.9999872, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.84877056, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_3-Comparision.png
# >>> EarlyStopping at epoch: 10 <<<
# Finish Training
# >> Functoin: main costs 0:01:46.044211
# => RUN on  0 110210 19 41 0 img_index  4
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 4
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   223: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   424: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   625: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   826: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1027: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1228: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1429: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1630: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1831: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2032: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2233: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2434: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2635: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2836: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3037: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3238: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3439: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3640: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3841: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4042: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4243: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4444: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4645: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4846: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5047: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5248: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5449: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5650: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5851: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_4_21_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.0, 'rmses_std': 0.0, 'ssim_sel_mean': 1.0, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.8507818, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_4-Comparision.png
# >>> EarlyStopping at epoch: 21 <<<
# Finish Training
# >> Functoin: main costs 0:01:46.296060
# => RUN on  0 110210 19 41 0 img_index  5
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 5
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch   202: reducing learning rate of group 0 to 5.0000e+00.
# Epoch   403: reducing learning rate of group 0 to 2.5000e+00.
# Epoch   604: reducing learning rate of group 0 to 1.2500e+00.
# Epoch   805: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  1006: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  1207: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  1408: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  1609: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  1810: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  2011: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  2212: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  2413: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2614: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2815: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3016: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3217: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3418: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3619: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3820: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4021: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4222: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4423: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4624: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4825: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5026: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5227: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5428: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5629: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5830: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_5_0_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 2.448048e-07, 'rmses_std': 0.0, 'ssim_sel_mean': 1.0, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.81555104, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_5-Comparision.png
# >>> EarlyStopping at epoch: 0 <<<
# Finish Training
# >> Functoin: main costs 0:01:45.992725
# => RUN on  0 110210 19 41 0 img_index  6
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 6
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  2294: reducing learning rate of group 0 to 5.0000e+00.
# Epoch  2519: reducing learning rate of group 0 to 2.5000e+00.
# Epoch  2724: reducing learning rate of group 0 to 1.2500e+00.
# Epoch  2936: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  3137: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  3338: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  3539: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  3740: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  3941: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  4142: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  4343: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  4544: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  4745: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  4946: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  5147: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  5348: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  5549: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  5750: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  5951: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  6152: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  6353: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  6554: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  6755: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  6956: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  7157: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  7358: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  7559: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  7760: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  7961: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_6_4948_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.03857719, 'rmses_std': 0.0, 'ssim_sel_mean': 0.7936758, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.9992239, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_6-Comparision.png
# >>> EarlyStopping at epoch: 4948 <<<
# Finish Training
# >> Functoin: main costs 0:01:57.142727
# => RUN on  0 110210 19 41 0 img_index  7
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 7
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  1330: reducing learning rate of group 0 to 5.0000e+00.
# Epoch  2141: reducing learning rate of group 0 to 2.5000e+00.
# Epoch  2535: reducing learning rate of group 0 to 1.2500e+00.
# Epoch  2949: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  3236: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  4213: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  4643: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  5039: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  5367: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  5643: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  5922: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  6175: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  6421: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  6622: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  6823: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  7225: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  7426: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  7627: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  7828: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  8029: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  8230: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  8431: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  8632: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  8833: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  9034: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  9235: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  9436: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  9637: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  9838: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_7_9946_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.03552001, 'rmses_std': 0.0, 'ssim_sel_mean': 0.9928983, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.9856468, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# ...
# Epoch  2426: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  2627: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  2828: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  3029: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  3230: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  3431: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  3632: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  3833: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  4034: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  4235: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  4436: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  4637: reducing learning rate of group 0 to 1.1921e-06.
# Epoch  4838: reducing learning rate of group 0 to 5.9605e-07.
# Epoch  5039: reducing learning rate of group 0 to 2.9802e-07.
# Epoch  5240: reducing learning rate of group 0 to 1.4901e-07.
# Epoch  5441: reducing learning rate of group 0 to 7.4506e-08.
# Epoch  5642: reducing learning rate of group 0 to 3.7253e-08.
# Epoch  5843: reducing learning rate of group 0 to 1.8626e-08.
# ./saved/generated/110210/0_12_13_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.001236323, 'rmses_std': 0.0, 'ssim_sel_mean': 0.99821156, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.8524286, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_12-Comparision.png
# >>> EarlyStopping at epoch: 13 <<<
# Finish Training
# >> Functoin: main costs 0:01:46.419558
# => RUN on  0 110210 19 41 0 img_index  13
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 13
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  2802: reducing learning rate of group 0 to 5.0000e+00.
# Epoch  5123: reducing learning rate of group 0 to 2.5000e+00.
# ./saved/generated/110210/0_13_9952_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.096971825, 'rmses_std': 0.0, 'ssim_sel_mean': 0.9329122, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.9849875, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_13-Comparision.png
# >>> EarlyStopping at epoch: 9952 <<<
# Finish Training
# >> Functoin: main costs 0:01:50.980029
# => RUN on  0 110210 19 41 0 img_index  14
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 14
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  1124: reducing learning rate of group 0 to 5.0000e+00.
# Epoch  2181: reducing learning rate of group 0 to 2.5000e+00.
# Epoch  2792: reducing learning rate of group 0 to 1.2500e+00.
# Epoch  3515: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  4057: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  5006: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  5878: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  6140: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  6764: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  7104: reducing learning rate of group 0 to 9.7656e-03.
# Epoch  7343: reducing learning rate of group 0 to 4.8828e-03.
# Epoch  7556: reducing learning rate of group 0 to 2.4414e-03.
# Epoch  7776: reducing learning rate of group 0 to 1.2207e-03.
# Epoch  7980: reducing learning rate of group 0 to 6.1035e-04.
# Epoch  8301: reducing learning rate of group 0 to 3.0518e-04.
# Epoch  8502: reducing learning rate of group 0 to 1.5259e-04.
# Epoch  8703: reducing learning rate of group 0 to 7.6294e-05.
# Epoch  8904: reducing learning rate of group 0 to 3.8147e-05.
# Epoch  9105: reducing learning rate of group 0 to 1.9073e-05.
# Epoch  9306: reducing learning rate of group 0 to 9.5367e-06.
# Epoch  9507: reducing learning rate of group 0 to 4.7684e-06.
# Epoch  9708: reducing learning rate of group 0 to 2.3842e-06.
# Epoch  9909: reducing learning rate of group 0 to 1.1921e-06.
# ./saved/generated/110210/0_14_9349_best.png
# (1, 224, 224, 1)
# defaultdict(<class 'list'>, {'rmses_mean': 0.03067259, 'rmses_std': 0.0, 'ssim_sel_mean': 0.96411145, 'ssim_sel_std': 0.0, 'ssim_res_mean': 0.9930226, 'ssim_res_std': 0.0, 'ssim_sum': 0.0})
# Directory has been created /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# Successfully Save pdf to /media/lincolnzjx/HardDisk/myGithub/Interpretation/generated/110210/feature_map/layer-19-0_14-Comparision.png
# >>> EarlyStopping at epoch: 9349 <<<
# Finish Training
# >> Functoin: main costs 0:01:48.512644
# => RUN on  0 110210 19 41 0 img_index  15
# ==================== basic setting start ====================
# experiment_index    : 110210
# cuda                : 0
# num_workers         : 2
# dataset             : mnist
# data_dir            : /media/lincolnzjx/HardDisk/Datasets/
# resume              : 072200-22
# n_epochs            : 10000
# learning_rate       : 10.0
# batch_size          : 1
# seed                : -1
# eval_frequency      : 1000
# log_dir             : ./saved/logdirs
# model_dir           : ./saved/models
# generated_dir       : ./saved/generated
# eps                 : 1e-07
# weight_decay        : 0
# momentum            : 0.9
# input_size          : 224
# backbone            : vgg11
# re_size             : 224
# optimizer           : SGD
# warmup_epochs       : -1
# initialization      : default
# prof                : False
# print_freq          : 10
# selected_filter     : 41
# selected_layer      : 19
# alpha               : 1.0
# beta                : 1.0
# gamma               : 1.0
# class_index         : [0]
# num_class           : 30
# mode                : keep
# dropout             : True
# clip_grad           : False
# inter               : False
# rho                 : 0
# conv_bias           : True
# linear_bias         : True
# regularization      : L1
# smoothing           : None
# delta               : 0.0
# regular_ex          : 1
# img_index           : 15
# rescale             : False
# server              : desktop
# freeze              : False
# dali                : False
# save_predict        : False
# local_rank          : 0
# world_size          : 1
# distributed         : False
# dist_url            : tcp://127.0.0.1:23456
# guidedReLU          : False
# defensed            : False
# embedding_size      : 3
# avg                 : False
# scheduler           : True
# ==================== basic setting end ====================
# >< init_environment with seed: -1
# Using GPU ID 0
# Save generated on ./saved/generated/110210
# Using device cuda
# Alpha is 1.0, Beta is 1.0, Gamma is 1.0
# Whether to use inter: False with rho: 0
# Whether to use regularization: L1
# Whether to use Smoothing: None with delta: 0.0
# >> Dataset:mnist - Input size: 224
# Len of new dataset is :30
# Used single image mode.
# Only Keep 19th layers before.
# Loss using mode: keep
# Using optimizer SGD with lr:10.0000
# Resume from model from exp: 072200 at epoch 22
# Network(
#   (model): VGG11(
#     (features): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (12): ReLU(inplace=True)
#       (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (14): ReLU(inplace=True)
#       (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (17): ReLU(inplace=True)
#       (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (19): ReLU(inplace=True)
#     )
#   )
# )
# Epoch  1384: reducing learning rate of group 0 to 5.0000e+00.
# Epoch  2427: reducing learning rate of group 0 to 2.5000e+00.
# Epoch  3153: reducing learning rate of group 0 to 1.2500e+00.
# Epoch  4112: reducing learning rate of group 0 to 6.2500e-01.
# Epoch  4836: reducing learning rate of group 0 to 3.1250e-01.
# Epoch  5333: reducing learning rate of group 0 to 1.5625e-01.
# Epoch  5649: reducing learning rate of group 0 to 7.8125e-02.
# Epoch  6293: reducing learning rate of group 0 to 3.9062e-02.
# Epoch  6715: reducing learning rate of group 0 to 1.9531e-02.
# Epoch  7539: reducing learning rate of group 0 to 9.7656e-03.

# %%
pwd

# %% [markdown]
# # Visualization

# %%
import pickle

# %%
# statistic_dir = "/data/wanying/Interpretation1010/saved/generated/110210/*.pl"
statistic_dir = "/home/lincolnzjx/Desktop/Interpretation/saved/generated/110210/0_*.pl"

selected_filter_losses = []
rest_filter_losses = []
rest_filter_loss_interactes = []
regularization_losses = []
rest_filter_loss_interact = []
lres = []
rmses_meanes = []
ssim_sel_meanes = []
ssim_res_meanes = []
losses = []

for item in glob.glob(statistic_dir):
    # load data 
    with open(item, "rb") as handle:
          statistic = pickle.load(handle)
    epoch = statistic["epoch"]
    print(epoch)
    loss = statistic["losses"]
    selected_filter_loss = statistic["selected_filter_loss"]
    rest_filter_loss = statistic["rest_fileter_loss"]
    rest_filter_loss_interact = statistic["rest_filter_loss_interact"]
    regularization_loss = statistic["regularization_loss"]
    lr = statistic["lr"]
    # best = statistic["best"][0]
    
    metric_statistic = statistic["metric_statistic"]
    rmses_mean = [ms["rmses_mean"] for ms in metric_statistic]
    ssim_sel_mean = [ms["ssim_sel_mean"] for ms in metric_statistic]
    ssim_res_mean = [ms["ssim_res_mean"] for ms in metric_statistic]
    
    selected_filter_losses.append(selected_filter_loss)
    rest_filter_losses.append(rest_filter_loss)
    rest_filter_loss_interactes.append(rest_filter_loss_interact)
    regularization_losses.append(regularization_loss)
    lres.append(regularization_loss)
    rmses_meanes.append(rmses_mean)
    ssim_sel_meanes.append(ssim_sel_mean)
    ssim_res_meanes.append(ssim_res_mean)
    losses.append(loss)
    # print("sf: min:{:.3f} max:{:.3f}".format(min(selected_filter_loss), max(selected_filter_loss)))
    # print("rf: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss), max(rest_filter_loss)))
    # print("rfi: min:{:.3f} max:{:.3f}".format(min(rest_filter_loss_interact), max(rest_filter_loss_interact)))
    # print("rg: min:{:.3f} max:{:.3f}".format(min(regularization_loss), max(regularization_loss)))
    # print("rmse: min:{:.3f} max:{:.3f}".format(min(rmses_mean), max(rmses_mean)))
    # print("ssim_sel: min:{:.3f}, max:{:.3f}".format(min(ssim_sel_mean), max(ssim_sel_mean)))
    # print("ssim_res: min:{:.3f}, max:{:.3f}".format(min(ssim_res_mean), max(ssim_res_mean)))
    # print("-"*50)
    # for key, name in best.items():
    #     if key != "processed_images":
    #         print(key, name)
    
fig = plt.figure(figsize=(3, 21))
fig.add_axes(sharex=True)
x = epoch

ax = plt.subplot(711)
# plt.plot(epoch, selected_filter_loss, label="selected_filter_loss")
y = np.mean(selected_filter_losses, axis=0)
yerr = np.std(selected_filter_losses, axis=0)
plt.errorbar(epoch, y, yerr=yerr, label="selected_filter_loss")
# plt.errorbar(, , yerr=yerr, label='both limits (default)')
plt.legend(loc='best')
    
plt.subplot(712)
y = np.mean(rest_filter_losses, axis=0)
yerr = np.std(rest_filter_losses, axis=0)
plt.errorbar(x, y, yerr=yerr, label="rest_filter_loss")
y = np.mean(rest_filter_loss_interactes, axis=0)
yerr = np.std(rest_filter_loss_interactes, axis=0)
plt.errorbar(x, y, yerr=yerr, label="rest_filter_loss_interact")
# plt.plot(epoch, rest_filter_loss_interact, label="rest_filter_loss_interact")
plt.legend(loc='best')

plt.subplot(713)
y = np.mean(regularization_losses, axis=0)
yerr = np.std(regularization_losses, axis=0)
plt.errorbar(epoch, regularization_loss, label="regularization")
plt.legend(loc='best')

plt.subplot(714)
y = np.mean(losses, axis=0)
yerr = np.std(losses, axis=0)
plt.errorbar(epoch, y, yerr=yerr, label="train_loss")
plt.legend(loc='best')

plt.subplot(715)
y = np.mean(lres, axis=0)
yerr = np.std(lres, axis=0)
plt.errorbar(epoch, y, label="lr")
plt.legend(loc='best')

plt.subplot(716)
y = np.mean(rmses_meanes, axis=0)
yerr = np.std(rmses_meanes, axis=0)
plt.errorbar(epoch, y, yerr=yerr, label="rmse")
plt.legend(loc='best')

plt.subplot(717)
y = np.mean(ssim_sel_meanes, axis=0)
yerr = np.std(ssim_sel_meanes, axis=0)
plt.errorbar(epoch, y, yerr=yerr, label="ssim_sel")
y = np.mean(ssim_res_meanes, axis=0)
yerr = np.std(ssim_res_meanes, axis=0)
plt.errorbar(epoch, y, yerr=yerr, label="ssim_res")
plt.legend(loc='best')

plt.suptitle('Training Process')
plt.show()

# %%
np.mean(selected_filter_losses, axis=1)

# %%
for idx, item in enumerate(selected_filter_losses):
    print(idx, item)
